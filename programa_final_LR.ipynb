# %% [markdown]
# # Predicció de Resultats de Tennis amb Regressió Logística
#
# Aquest notebook implementa un model de predicció de resultats de partits de tennis utilitzant Regressió Logística. El treball inclou:
#
# 1. **Càrrega i preparació de dades**: Filtrat per superfície i ordenació temporal
# 2. **Càlcul de característiques Elo**: Sistema de ranking dinàmic per jugadors
# 3. **Entrenament de models de Regressió Logística**: Amb validació temporal i calibratge
# 4. **Prediccions per ronda**: Evaluació del model en cada fase d'un torneig (Wimbledon 2025)
#
# ## Estructura del treball
#
# - **Part 1**: Model inicial amb validació temporal (80% train / 20% test)
# - **Part 2**: Optimització d'hiperparàmetres i calibratge
# - **Part 3**: Prediccions per ronda amb reentrenament incremental

# %% [markdown]
# ## 1. Càrrega i preparació de dades
#
# Primer de tot, carreguem el dataset i el filtrem per la superfície d'interès (herba, Surface=2).

# %%
import pandas as pd
import numpy as np

df_origin = pd.read_csv('wimbeldon_dataset_all_surfaces_v2.csv')
df_origin.head()
# Out:
# C:\Users\ikerr\AppData\Local\Temp\ipykernel_32660\3639339061.py:4: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_origin = pd.read_csv('wimbeldon_dataset_all_surfaces_v2.csv')
#    ATP  Location                          Tournament        Date  \
# 0    2   Chennai                     Gold Flake Open  2000-01-03
# 1    1  Adelaide  Australian Hardcourt Championships  2000-01-03
# 2    2   Chennai                     Gold Flake Open  2000-01-03
# 3    2   Chennai                     Gold Flake Open  2000-01-03
# 4    2   Chennai                     Gold Flake Open  2000-01-03
#
#           Series  Court  Surface      Round  Best of      Winner  ...  \
# 0  International      1        3  1st Round      3.0   Agenor R.  ...
# 1  International      1        3  1st Round      3.0   Norman M.  ...
# 2  International      1        3  1st Round      3.0  Golmard J.  ...
# 3  International      1        3  1st Round      3.0  Jonsson F.  ...
# 4  International      1        3  1st Round      3.0  Pioline C.  ...
#
#   OddsProbDiff  WinRateA_x_Rank WinRateB_x_Rank  EfficiencyDiff  EloA_Global  \
# 0          0.0         0.005319        0.000500        0.004819       1500.0
# 1          0.0         0.003226        0.033333       -0.030108       1500.0
# 2          0.0         0.026316        0.002500        0.023816       1500.0
# 3          0.0         0.003937        0.004854       -0.000917       1500.0
# 4          0.0         0.035714        0.001208        0.034507       1500.0
#
#    EloB_Global  EloA_Surface  EloB_Surface  EloDiff_Global  EloDiff_Surface
# 0       1500.0        1500.0        1500.0             0.0              0.0
# 1       1500.0        1500.0        1500.0             0.0              0.0
# 2       1500.0        1500.0        1500.0             0.0              0.0
# 3       1500.0        1500.0        1500.0             0.0              0.0
# 4       1500.0        1500.0        1500.0             0.0              0.0
#
# [5 rows x 100 columns]

# %%
# Ens tenim que quedar amb només les dades de tots aquests partits que la seva data és anterior al 2025-06-29
df = df_origin.copy()
#df = df_origin[df_origin['Date'] < '2025-06-29'].copy()
df = df[df['Surface'] == 2].copy()  # Filtrar per herba (Surface = 2)

df.tail()
#print("Mida del df: ", len(df))
# Out:
#        ATP Location Tournament        Date      Series  Court  Surface  \
# 68317   36   London  Wimbledon  2025-07-09  Grand Slam      1        2
# 68318   36   London  Wimbledon  2025-07-09  Grand Slam      1        2
# 68319   36   London  Wimbledon  2025-07-11  Grand Slam      1        2
# 68320   36   London  Wimbledon  2025-07-11  Grand Slam      1        2
# 68321   36   London  Wimbledon  2025-07-13  Grand Slam      1        2
#
#                Round  Best of       Winner  ... OddsProbDiff  WinRateA_x_Rank  \
# 68317  Quarterfinals      5.0  Djokovic N.  ...    -0.776578         0.022762
# 68318  Quarterfinals      5.0    Sinner J.  ...    -0.489858         0.058861
# 68319     Semifinals      5.0    Sinner J.  ...    -0.352403         0.139292
# 68320     Semifinals      5.0   Alcaraz C.  ...     0.615975         0.401007
# 68321      The Final      5.0    Sinner J.  ...    -0.051668         0.401338
#
#       WinRateB_x_Rank  EfficiencyDiff  EloA_Global  EloB_Global  EloA_Surface  \
# 68317        0.139271       -0.116509  1788.861188  2026.536109   1556.528325
# 68318        0.759777       -0.700916  1786.399787  2185.560132   1541.645698
# 68319        0.760446       -0.621154  2033.029427  2188.482031   1977.139810
# 68320        0.120921        0.280086  2162.047337  1922.449366   1797.524462
# 68321        0.761111       -0.359773  2168.483549  2197.765504   1807.254728
#
#        EloB_Surface  EloDiff_Global  EloDiff_Surface
# 68317   1975.161612     -237.674922      -418.633287
# 68318   1688.214627     -399.160345      -146.568929
# 68319   1695.432680     -155.452604       281.707130
# 68320   1731.007990      239.597971        66.516471
# 68321   1715.473177      -29.281955        91.781551
#
# [5 rows x 100 columns]

# %% [markdown]
# ## 2. Model de Regressió Logística inicial amb validació temporal
#
# Aquest model utilitza una divisió temporal (80% train / 20% test) per avaluar el rendiment del model de Regressió Logística amb calibratge isotònic.

# %%
from collections import defaultdict
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import brier_score_loss
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split, TimeSeriesSplit

features = [
    'LogRankDiff',      # ranking
    'DiffWR',           # diferencia de winrate históric en herva
    'DiffForm',         # últims 10
    'H2HDiff',          # head-to-head
    'OddsProbDiff',     # diferencia de probabilitat implícita de quotas
    'DiffRest',         # dies de rest
    'EfficiencyDiff',   # winrate / rank → jugador que rendeix per sobre del seu ranking
    'RankDiff',         # diferencia de ranking
    'EloDiff_Global',   # diferencia de elo global
    'EloDiff_Surface'   # diferencia de elo en superfície
]

df = df.sort_values("Date", ascending=True).reset_index(drop=True)

# Divisió temporal (80% train / 20% test)
X = df[features]
y = df["WinnerBinary"]
split_idx = int(len(df) * 0.8)
X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

# Escalat de les característiques (important per regressió logística)
scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

# Model base de Regressió Logística
base_model = LogisticRegression(
    C=1.0,                    # Paràmetre de regularització inversa. Valors més petits indiquen regularització més forta.
    max_iter=1000,            # Nombre màxim d'iteracions per convergir. 1000 és un valor segur per a conjunts de dades mitjans.
    class_weight='balanced',  # Equilibra els pesos de les classes automàticament per compensar classes desequilibrades.
    random_state=42,          # Llavor per a la reproductibilitat dels resultats.
    solver='lbfgs'            # Algoritme d'optimització. 'lbfgs' és bo per a problemes petits/medians i funciona bé amb regularització L2.
)

# Calibratge isotònic per millorar la calibració de les probabilitats
tscv = TimeSeriesSplit(n_splits=5)
model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

# Prediccions i avaluació
pred = model.predict(X_test_sc)
prob_model_con_tscv = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob_model_con_tscv)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 0.6684
# Brier Score: 0.2094
#               precision    recall  f1-score   support
#
#            0     0.6563    0.6519    0.6541       744
#            1     0.6795    0.6837    0.6816       803
#
#     accuracy                         0.6684      1547
#    macro avg     0.6679    0.6678    0.6678      1547
# weighted avg     0.6683    0.6684    0.6683      1547
#
# ================================================================================

# %% [markdown]
# ### 2.1. Anàlisi d'importància de característiques
#
# Per a regressió logística, podem analitzar la importància de les característiques a través dels coeficients del model. Els coeficients més grans en valor absolut indiquen característiques més importants.

# %%
# Extreure el model de regressió logística del calibratge
lr_model = model.calibrated_classifiers_[0].estimator

# Obtenir els coeficients del model
coefficients = lr_model.coef_[0]
feature_importance = pd.DataFrame({
    'Feature': features,
    'Coefficient': coefficients,
    'Abs_Coefficient': np.abs(coefficients)
}).sort_values('Abs_Coefficient', ascending=False)

print("Importància de característiques (segons valor absolut dels coeficients):")
print("="*80)
print(feature_importance)

# Visualització de la importància
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.barh(range(len(feature_importance)), feature_importance['Abs_Coefficient'])
plt.yticks(range(len(feature_importance)), feature_importance['Feature'])
plt.xlabel('Valor Absolut del Coeficient')
plt.title('Importància de Característiques - Regressió Logística')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# Out:
# Importància de característiques (segons valor absolut dels coeficients):
# ================================================================================
#            Feature  Coefficient  Abs_Coefficient
# 8   EloDiff_Global     0.495080         0.495080
# 4     OddsProbDiff     0.360596         0.360596
# 9  EloDiff_Surface     0.350185         0.350185
# 0      LogRankDiff    -0.179984         0.179984
# 1           DiffWR    -0.083374         0.083374
# 2         DiffForm    -0.072513         0.072513
# 3          H2HDiff    -0.070538         0.070538
# 5         DiffRest    -0.059603         0.059603
# 7         RankDiff    -0.050871         0.050871
# 6   EfficiencyDiff     0.035377         0.035377

# %% [markdown]
# ## 3. Càlcul de característiques Elo
#
# El sistema Elo és un mètode de ranking dinàmic que actualitza la puntuació dels jugadors segons els resultats dels partits. Implementem un sistema avançat amb:
#
# - **Elo Global**: Ranking general del jugador
# - **Elo per Superfície**: Ranking específic per tipus de superfície (herba, terra, etc.)
# - **Actualització dinàmica**: El K factor varia segons la diferència d'Elo entre jugadors
# - **Importància del torneig**: Els torneigs majors (Grand Slam, Masters) tenen més pes

# %%
from collections import defaultdict

# ============================
# 1. MAPEO SUPERFICIES SI ESTÁN NUMERIZADAS
# ============================

# Si Surface es numérica (LabelEncoder), necesitamos mapearlo a strings
surface_map = {
    0: "Hard",
    1: "Clay",
    2: "Grass",
    3: "Carpet"
}

# Detectar si Surface es numérica
if np.issubdtype(df["Surface"].dtype, np.number):
    df["SurfaceText"] = df["Surface"].map(surface_map)
else:
    df["SurfaceText"] = df["Surface"]

# ============================
# 2. ORDEN CORRECTO DE RONDAS
# ============================

round_order = {
    "1st Round": 1,
    "2nd Round": 2,
    "3rd Round": 3,
    "4th Round": 4,
    "Round of 16": 5,
    "Quarterfinals": 6,
    "Semifinals": 7,
    "The Final": 8
}

df["RoundOrder"] = df["Round"].map(round_order)

# Ordenar completamente en orden real cronológico
df = df.sort_values(["Date", "Tournament", "RoundOrder"]).reset_index(drop=True)

# ============================
# 3. CONFIGURACIÓN DEL ELO
# ============================

ELO_START = 1500
DECAY_GLOBAL = 0.9995
DECAY_SURFACE = 0.999

def dynamic_k(diff):
    """K depende de diferencia de Elo (más cerca → más grande K)."""
    if diff < 25:
        return 40
    elif diff < 75:
        return 32
    elif diff < 150:
        return 24
    else:
        return 16

# Importancia del torneo
tournament_weights = {
    "ATP250": 1.00,
    "ATP500": 1.10,
    "Masters 1000": 1.20,
    "Grand Slam": 1.30,
    "International": 1.00   # por compatibilidad con tus datos antiguos
}

# ============================
# 4. INICIALIZAR ELO
# ============================

elo_global = defaultdict(lambda: ELO_START)
elo_surface = defaultdict(lambda: {"Hard": ELO_START, "Clay": ELO_START, "Grass": ELO_START, "Carpet": ELO_START})

# Columnas de salida
df["EloA_Global"] = 0.0
df["EloB_Global"] = 0.0
df["EloA_Surface"] = 0.0
df["EloB_Surface"] = 0.0

# ============================
# 5. EXPECTED SCORE
# ============================

def expected_score(r1, r2):
    return 1 / (1 + 10 ** ((r2 - r1) / 400))

# ============================
# 6. CALCULAR ELO SIN DATA LEAKAGE
# ============================

for i, row in df.iterrows():
    
    A = row["PlayerA"]
    B = row["PlayerB"]
    surf = row["SurfaceText"]
    series = row["Series"]

    # --- Decaimiento temporal (antes del partido)
    elo_global[A] *= DECAY_GLOBAL
    elo_global[B] *= DECAY_GLOBAL
    elo_surface[A][surf] *= DECAY_SURFACE
    elo_surface[B][surf] *= DECAY_SURFACE

    # --- Elo ANTES DEL PARTIDO (features pre-partido)
    eloA_g = elo_global[A]
    eloB_g = elo_global[B]
    eloA_s = elo_surface[A][surf]
    eloB_s = elo_surface[B][surf]

    df.at[i, "EloA_Global"] = eloA_g
    df.at[i, "EloB_Global"] = eloB_g
    df.at[i, "EloA_Surface"] = eloA_s
    df.at[i, "EloB_Surface"] = eloB_s

    # --- Resultado del partido
    winner = row["WinnerBinary"]
    scoreA = 1 if winner == 1 else 0
    scoreB = 1 - scoreA

    # --- Expected score
    expA_g = expected_score(eloA_g, eloB_g)
    expA_s = expected_score(eloA_s, eloB_s)

    # --- K dinámico + importancia de torneo
    diff = abs(eloA_g - eloB_g)
    K = dynamic_k(diff)
    weight = tournament_weights.get(series, 1.00)
    K_final = K * weight

    # --- Actualización GLOBAL
    elo_global[A] = eloA_g + K_final * (scoreA - expA_g)
    elo_global[B] = eloB_g + K_final * (scoreB - (1 - expA_g))

    # --- Actualización SUPERFICIE
    elo_surface[A][surf] = eloA_s + K_final * (scoreA - expA_s)
    elo_surface[B][surf] = eloB_s + K_final * (scoreB - (1 - expA_s))

# ============================
# 7. DIFERENCIAS FINALES COMO FEATURES
# ============================

df["EloDiff_Global"] = df["EloA_Global"] - df["EloB_Global"]
df["EloDiff_Surface"] = df["EloA_Surface"] - df["EloB_Surface"]

df.head()
# Out:
#    ATP Location        Tournament        Date         Series  Court  Surface  \
# 0   33    Halle  Gerry Weber Open  2000-06-12  International      1        2
# 1   33    Halle  Gerry Weber Open  2000-06-12  International      1        2
# 2   33    Halle  Gerry Weber Open  2000-06-12  International      1        2
# 3   33    Halle  Gerry Weber Open  2000-06-12  International      1        2
# 4   33    Halle  Gerry Weber Open  2000-06-12  International      1        2
#
#        Round  Best of         Winner  ... WinRateB_x_Rank  EfficiencyDiff  \
# 0  1st Round      3.0     Federer R.  ...        0.014519       -0.007000
# 1  1st Round      3.0  Kafelnikov Y.  ...        0.018256        0.108060
# 2  1st Round      3.0     Larsson M.  ...        0.014406        0.043134
# 3  1st Round      3.0        Moya C.  ...        0.012255       -0.010076
# 4  1st Round      3.0       Chang M.  ...        0.009685        0.010723
#
#   EloA_Global  EloB_Global  EloA_Surface  EloB_Surface  EloDiff_Global  \
# 0     1499.25      1499.25        1498.5        1498.5             0.0
# 1     1499.25      1499.25        1498.5        1498.5             0.0
# 2     1499.25      1499.25        1498.5        1498.5             0.0
# 3     1499.25      1499.25        1498.5        1498.5             0.0
# 4     1499.25      1499.25        1498.5        1498.5             0.0
#
#    EloDiff_Surface  SurfaceText  RoundOrder
# 0              0.0        Grass           1
# 1              0.0        Grass           1
# 2              0.0        Grass           1
# 3              0.0        Grass           1
# 4              0.0        Grass           1
#
# [5 rows x 102 columns]

# %% [markdown]
# ## 4. Optimització d'hiperparàmetres i calibratge
#
# Aquesta secció optimitza el paràmetre de regularització C de la Regressió Logística utilitzant una divisió 70% train / 10% validation / 20% test. Després aplica calibratge isotònic per millorar la calibració de les probabilitats.

# %%
from sklearn.preprocessing import LabelEncoder

le_series = LabelEncoder()
df["Series"] = le_series.fit_transform(df["Series"])

# ======== FEATURES ========
features = [
    # Diferencias estadísticas base
    'LogRankDiff',
    'DiffWR',
    'DiffForm',
    'H2HDiff',
    'OddsProbDiff',
    'DiffRest',
    'EfficiencyDiff',
    'RankDiff',

    # Elo avanzado
    'EloDiff_Global',
    'EloDiff_Surface',

    # Contexto
    'Series',       # codificada con LabelEncoder
    'RoundOrder'    # orden real de la ronda
]

# Aseguramos orden temporal
df = df.sort_values("Date", ascending=True).reset_index(drop=True)

X = df[features]
y = df["WinnerBinary"].values

n = len(df)
idx_train_end = int(n * 0.7)   # 70% train
idx_val_end   = int(n * 0.8)   # 10% val (70–80)
# 20% restante = test

X_train = X.iloc[:idx_train_end]
y_train = y[:idx_train_end]

X_val   = X.iloc[idx_train_end:idx_val_end]
y_val   = y[idx_train_end:idx_val_end]

X_test  = X.iloc[idx_val_end:]
y_test  = y[idx_val_end:]

print("Tamaños:")
print("Train:", X_train.shape, "Val:", X_val.shape, "Test:", X_test.shape)

# ======== ESCALADO (solo con TRAIN) ========
scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_val_sc   = scaler.transform(X_val)
X_test_sc  = scaler.transform(X_test)
# Out:
# Tamaños:
# Train: (5413, 12) Val: (774, 12) Test: (1547, 12)

# %% [markdown]
# ### 4.1. Búsqueda del millor paràmetre C
#
# El paràmetre C controla la regularització: valors més petits indiquen més regularització (model més simple), mentre que valors més grans permeten que el model s'ajusti millor als dades d'entrenament. Avaluem diferents valors de C per trobar el que minimitza el Brier Score en el conjunt de validació.

# %%
from copy import deepcopy

# Valores a probar para el parámetro C (regularización inversa)
C_grid = [0.1, 0.5, 1.0, 2.0, 5.0, 10.0]

results = []

for C_val in C_grid:
    print(f"\nEntrenando modelo con C = {C_val}")

    model_tmp = LogisticRegression(
        C=C_val,
        max_iter=1000,
        class_weight='balanced',
        random_state=42,
        solver='lbfgs'
    )

    model_tmp.fit(X_train_sc, y_train)

    prob_val = model_tmp.predict_proba(X_val_sc)[:, 1]
    pred_val = (prob_val >= 0.5).astype(int)

    acc_val = accuracy_score(y_val, pred_val)
    brier_val = brier_score_loss(y_val, prob_val)

    results.append((C_val, acc_val, brier_val))
    print(f"VAL → ACC={acc_val:.4f}, BRIER={brier_val:.4f}")

# Elegir el mejor por Brier y, en empate, por accuracy
results_sorted = sorted(results, key=lambda x: (x[2], -x[1]))
best_C, best_acc_val, best_brier_val = results_sorted[0]

print("\n==============================")
print("MEJOR C EN VALIDACIÓN:")
print(f"C={best_C}, ACC_VAL={best_acc_val:.4f}, BRIER_VAL={best_brier_val:.4f}")
print("==============================")
# Out:
# Entrenando modelo con C = 0.1
# VAL → ACC=0.6822, BRIER=0.2090
#
# Entrenando modelo con C = 0.5
# VAL → ACC=0.6809, BRIER=0.2096
#
# Entrenando modelo con C = 1.0
# VAL → ACC=0.6796, BRIER=0.2100
#
# Entrenando modelo con C = 2.0
# VAL → ACC=0.6783, BRIER=0.2104
#
# Entrenando modelo con C = 5.0
# VAL → ACC=0.6822, BRIER=0.2106
#
# Entrenando modelo con C = 10.0
# VAL → ACC=0.6822, BRIER=0.2108
#
# ==============================
# MEJOR C EN VALIDACIÓN:
# C=0.1, ACC_VAL=0.6822, BRIER_VAL=0.2090
# ==============================

# %% [markdown]
# ### 4.2. Model final sense calibratge
#
# Entrenem el model amb el millor C trobat, utilitzant train+validation, i l'avaluem en el test.

# %%
# ======== REENTRENAR SCALER EN TRAIN+VAL ========
X_train_val = pd.concat([X_train, X_val], axis=0)
y_train_val = np.concatenate([y_train, y_val])

scaler_final = StandardScaler()
X_train_val_sc = scaler_final.fit_transform(X_train_val)
X_test_sc_final = scaler_final.transform(X_test)

# ======== MODELO REGRESIÓN LOGÍSTICA FINAL (SIN CALIBRACIÓN) ========
base_model_final = LogisticRegression(
    C=best_C,
    max_iter=1000,
    class_weight='balanced',
    random_state=42,
    solver='lbfgs'
)

base_model_final.fit(X_train_val_sc, y_train_val)

# ======== EVALUACIÓN SIN CALIBRACIÓN ========
prob_test_base = base_model_final.predict_proba(X_test_sc_final)[:, 1]
pred_test_base = (prob_test_base >= 0.5).astype(int)

acc_base = accuracy_score(y_test, pred_test_base)
brier_base = brier_score_loss(y_test, prob_test_base)

print("\n===== RESULTADOS SIN CALIBRACIÓN =====")
print(f"Accuracy TEST: {acc_base:.4f}")
print(f"Brier TEST:    {brier_base:.4f}")
print(classification_report(y_test, pred_test_base, digits=4))
print("=======================================")
# Out:
# ===== RESULTADOS SIN CALIBRACIÓN =====
# Accuracy TEST: 0.6787
# Brier TEST:    0.2063
#               precision    recall  f1-score   support
#
#            0     0.6631    0.6747    0.6689       744
#            1     0.6937    0.6824    0.6880       803
#
#     accuracy                         0.6787      1547
#    macro avg     0.6784    0.6786    0.6784      1547
# weighted avg     0.6790    0.6787    0.6788      1547
#
# =======================================

# %% [markdown]
# ### 4.3. Model final amb calibratge isotònic
#
# El calibratge isotònic millora la calibració de les probabilitats del model. Observem com afecta el rendiment.

# %%
# ======== CALIBRACIÓN ISOTÓNICA SOBRE TRAIN+VAL ========
cal_model = CalibratedClassifierCV(
    estimator=deepcopy(base_model_final),
    method="isotonic",
    cv=5
)

cal_model.fit(X_train_val_sc, y_train_val)

prob_test_cal = cal_model.predict_proba(X_test_sc_final)[:, 1]
pred_test_cal = (prob_test_cal >= 0.5).astype(int)

acc_cal = accuracy_score(y_test, pred_test_cal)
brier_cal = brier_score_loss(y_test, prob_test_cal)

print("\n===== RESULTADOS CON CALIBRACIÓN ISOTÓNICA =====")
print(f"Accuracy TEST: {acc_cal:.4f}")
print(f"Brier TEST:    {brier_cal:.4f}")
print(classification_report(y_test, pred_test_cal, digits=4))
print("================================================")
# Out:
# ===== RESULTADOS CON CALIBRACIÓN ISOTÓNICA =====
# Accuracy TEST: 0.6761
# Brier TEST:    0.2089
#               precision    recall  f1-score   support
#
#            0     0.6627    0.6653    0.6640       744
#            1     0.6887    0.6862    0.6875       803
#
#     accuracy                         0.6761      1547
#    macro avg     0.6757    0.6757    0.6757      1547
# weighted avg     0.6762    0.6761    0.6762      1547
#
# ================================================

# %% [markdown]
# ## 5. Prediccions per ronda (Wimbledon 2025)
#
# En aquesta secció avaluem el model en cada ronda del torneig de Wimbledon 2025. El model es reentrena incrementalment després de cada ronda, afegint les dades de la ronda anterior al conjunt d'entrenament. Això simula com funcionaria en un escenari real on el model aprén a mesura que el torneig progressa.

# %%
# Preparació de dades per ronda
train = df[df['Date'] < '2025-06-29'].copy()
test = df[(df['Date'] >= '2025-06-29') & (df['Date'] <= '2025-07-13')].copy()

print("Mida train: ", len(train))
print("Mida test: ", len(test))

train.tail()
# Out:
# Mida train:  7607
# Mida test:  127
#       ATP    Location                Tournament        Date  Series  Court  \
# 7602   35    Mallorca    Mallorca Championships  2025-06-27       0      1
# 7603   34  Eastbourne  Eastbourne International  2025-06-27       0      1
# 7604   34  Eastbourne  Eastbourne International  2025-06-27       0      1
# 7605   34  Eastbourne  Eastbourne International  2025-06-28       0      1
# 7606   35    Mallorca    Mallorca Championships  2025-06-28       0      1
#
#       Surface       Round  Best of         Winner  ... WinRateB_x_Rank  \
# 7602        2  Semifinals      3.0  Griekspoor T.  ...        0.015519
# 7603        2  Semifinals      3.0    Brooksby J.  ...        0.026619
# 7604        2  Semifinals      3.0       Fritz T.  ...        0.119745
# 7605        2   The Final      3.0       Fritz T.  ...        0.119915
# 7606        2   The Final      3.0  Griekspoor T.  ...        0.005221
#
#       EfficiencyDiff  EloA_Global  EloB_Global  EloA_Surface  EloB_Surface  \
# 7602        0.006743  1580.733744  1584.770096   1546.867135   1558.348816
# 7603       -0.022634  1547.382539  1578.021479   1528.754762   1543.804755
# 7604       -0.101207  1480.253671  1684.879730   1462.178174   1646.372594
# 7605       -0.115902  1564.007473  1687.802223   1543.901959   1648.838114
# 7606        0.010367  1603.735487  1526.599706   1576.110430   1501.686108
#
#       EloDiff_Global  EloDiff_Surface  SurfaceText  RoundOrder
# 7602       -4.036352       -11.481682        Grass           7
# 7603      -30.638940       -15.049993        Grass           7
# 7604     -204.626059      -184.194419        Grass           7
# 7605     -123.794750      -104.936155        Grass           8
# 7606       77.135780        74.424322        Grass           8
#
# [5 rows x 102 columns]

# %%
# Separar per rondes
first_round = test[test['Round'] == '1st Round']
second_round = test[test['Round'] == '2nd Round']
third_round = test[test['Round'] == '3rd Round']
fourth_round = test[test['Round'] == '4th Round']
quarter_finals = test[test['Round'] == 'Quarterfinals']
semi_finals = test[test['Round'] == 'Semifinals']
finals = test[test['Round'] == 'The Final']

print("Mida first round: ", len(first_round))
print("Mida second round: ", len(second_round))
print("Mida third round: ", len(third_round))
print("Mida fourth round: ", len(fourth_round))
print("Mida quarter finals: ", len(quarter_finals))
print("Mida semi finals: ", len(semi_finals))
print("Mida finals: ", len(finals))
# Out:
# Mida first round:  64
# Mida second round:  32
# Mida third round:  16
# Mida fourth round:  8
# Mida quarter finals:  4
# Mida semi finals:  2
# Mida finals:  1

# %% [markdown]
# ### 5.1. Funció d'anàlisi de prediccions
#
# Funció auxiliar per analitzar les prediccions fila a fila, mostrant detalls de cada partit i identificant les prediccions fallides.

# %%
from IPython.display import display

def analyze_predictions(
    df,
    y_true,
    y_pred,
    y_prob,
    date_col="Date",
    player_a_col="PlayerA",
    player_b_col="PlayerB",
    true_col_name="WinnerBinary"
):

    # Copia de las columnas de contexto
    results_df = df[[date_col, player_a_col, player_b_col]].copy()
    results_df[true_col_name] = y_true

    # Añadir predicciones y probabilidades
    results_df["Predicted"] = y_pred
    results_df["Probability"] = y_prob

    # Aciertos / fallos
    results_df["Correct"] = (results_df[true_col_name] == results_df["Predicted"])
    results_df["Result"] = results_df["Correct"].map({True: "✓ Correct", False: "✗ Failed"})

    # Resumen global
    total = len(results_df)
    correct = results_df["Correct"].sum()
    incorrect = total - correct
    acc = correct / total if total > 0 else 0.0

    print("RESULTADOS DETALLADOS POR FILA:")
    print("=" * 100)
    print(f"\nTotal de predicciones: {total}")
    print(f"Correctas: {correct} ({acc*100:.2f}%)")
    print(f"Fallidas: {incorrect} ({(1-acc)*100:.2f}%)")
    print("\n" + "=" * 100 + "\n")

    # Mostrar todas las filas
    pd.set_option("display.max_rows", None)
    pd.set_option("display.width", None)
    pd.set_option("display.max_columns", None)

    display(results_df[[date_col, player_a_col, player_b_col,
                        true_col_name, "Predicted", "Probability", "Result"]])

    # Mostrar solo fallos
    print("\n" + "=" * 100)
    print("PREDICCIONES FALLIDAS:")
    print("=" * 100)
    failed_df = results_df[~results_df["Correct"]]

    if len(failed_df) > 0:
        display(failed_df[[date_col, player_a_col, player_b_col,
                           true_col_name, "Predicted", "Probability"]])
    else:
        print("¡Todas las predicciones han sido correctas!")

    return results_df, failed_df

# %% [markdown]
# ### 5.2. Primera ronda
#
# Comencem a predir els valors de la primera ronda del torneig.

# %%
features = [
    # Diferencias estadísticas base
    'LogRankDiff',
    'DiffWR',
    'DiffForm',
    'H2HDiff',
    'OddsProbDiff',
    'DiffRest',
    'EfficiencyDiff',
    'RankDiff',

    # Elo avanzado
    'EloDiff_Global',
    'EloDiff_Surface',

    # Contexto
    'Series',       # codificada con LabelEncoder
    'RoundOrder'    # orden real de la ronda
]

X_train = train[features].fillna(0)
X_test = first_round[features].fillna(0)
y_train = train['WinnerBinary']
y_test = first_round['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = LogisticRegression(
    C=1.0,                    # Paràmetre de regularització inversa. Valors més petits indiquen regularització més forta.
    max_iter=1000,            # Nombre màxim d'iteracions per convergir. 1000 és un valor segur per a conjunts de dades mitjans.
    class_weight='balanced',  # Equilibra els pesos de les classes automàticament per compensar classes desequilibrades.
    random_state=42,          # Llavor per a la reproductibilitat dels resultats.
    solver='lbfgs'            # Algoritme d'optimització. 'lbfgs' és bo per a problemes petits/medians i funciona bé amb regularització L2.
)

tscv = TimeSeriesSplit(n_splits=5)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 0.6406
# Brier Score: 0.2502
#               precision    recall  f1-score   support
#
#            0     0.6364    0.6562    0.6462        32
#            1     0.6452    0.6250    0.6349        32
#
#     accuracy                         0.6406        64
#    macro avg     0.6408    0.6406    0.6405        64
# weighted avg     0.6408    0.6406    0.6405        64
#
# ================================================================================

# %%
results_df, failed_df = analyze_predictions(
    df=first_round,
    y_true=first_round["WinnerBinary"].values,
    y_pred=pred,
    y_prob=prob,
    date_col="Date",
    player_a_col="PlayerA",
    player_b_col="PlayerB",
    true_col_name="WinnerBinary"
)
# Out:
# RESULTADOS DETALLADOS POR FILA:
# ====================================================================================================
#
# Total de predicciones: 64
# Correctas: 41 (64.06%)
# Fallidas: 23 (35.94%)
#
# ====================================================================================================
#             Date               PlayerA               PlayerB  WinnerBinary  \
# 7607  2025-06-30           Brooksby J.         Griekspoor T.             1
# 7608  2025-06-30              Bonzi B.           Medvedev D.             1
# 7609  2025-06-30           Fearnley J.            Fonseca J.             0
# 7610  2025-06-30          Khachanov K.           McDonald M.             1
# 7611  2025-06-30             Moller E.             Tiafoe F.             0
# 7612  2025-06-30          Mannarino A.          O Connell C.             1
# 7613  2025-06-30           Altmaier D.             Diallo G.             0
# 7614  2025-06-30              Royer V.          Tsitsipas S.             1
# 7615  2025-06-30            Dellien H.            Lehecka J.             0
# 7616  2025-06-30              Riedi L.             Tarvet O.             0
# 7617  2025-06-30              Djere L.             Rublev A.             0
# 7618  2025-06-30             Harris B.            Lajovic D.             1
# 7619  2025-06-30        Basavareddy N.               Tien L.             0
# 7620  2025-06-30      Bautista Agut R.             Norrie C.             0
# 7621  2025-06-30            Alcaraz C.            Fognini F.             1
# 7622  2025-06-30            Misolic F.           Struff J.L.             0
# 7623  2025-06-30            Kopriva V.           Thompson J.             0
# 7624  2025-06-30               Fery A.            Popyrin A.             1
# 7625  2025-06-30              Quinn E.             Searle H.             1
# 7626  2025-06-30  Davidovich Fokina A.               Holt B.             1
# 7627  2025-06-30           Bellucci M.           Crawford O.             1
# 7628  2025-06-30              Bergs Z.             Harris L.             0
# 7629  2025-06-30    Auger-Aliassime F.          Duckworth J.             1
# 7630  2025-06-30         Berrettini M.          Majchrzak K.             0
# 7631  2025-06-30              Garin C.            Rodesch C.             1
# 7632  2025-06-30             Borges N.          Cerundolo F.             1
# 7633  2025-06-30            Darderi L.          Safiullin R.             1
# 7634  2025-06-30              Jarry N.               Rune H.             1
# 7635  2025-07-01            Humbert U.            Monfils G.             0
# 7636  2025-07-01             Navone M.         Shapovalov D.             1
# 7637  2025-07-01           Djokovic N.             Muller A.             1
# 7638  2025-07-01             Bublik A.              Munar J.             0
# 7639  2025-07-01            Tseng C.H.              Vukic A.             0
# 7640  2025-07-01          Fucsovics M.          Kovacevic A.             1
# 7641  2025-07-01             Cazaux A.             Walton A.             1
# 7642  2025-07-01             Clarke J.              Evans D.             0
# 7643  2025-07-01         Kecmanovic M.          Michelsen A.             1
# 7644  2025-07-01          Mochizuki S.           Zeppieri G.             1
# 7645  2025-07-01              Giron M.      Ugo Carabelli C.             1
# 7646  2025-07-01             Gaston H.             Mensik J.             0
# 7647  2025-07-01              Fritz T.            Mpetshi G.             1
# 7648  2025-07-01        Rinderknech A.             Zverev A.             1
# 7649  2025-07-01            Cobolli F.           Zhukayev B.             1
# 7650  2025-07-01            De Jong J.            Eubanks C.             1
# 7651  2025-07-01            Arnaldi M.  Van De Zandschulp B.             0
# 7652  2025-07-01             Goffin D.           Hijikata R.             0
# 7653  2025-07-01               Bolt A.            Shelton B.             0
# 7654  2025-07-01           Comesana F.             Moutet C.             0
# 7655  2025-07-01         Etcheverry T.   Pinnington Jones J.             0
# 7656  2025-07-01              Halys Q.           Holmgren A.             0
# 7657  2025-07-01              Nardi L.             Sinner J.             0
# 7658  2025-07-01             Opelka R.         Shevchenko A.             1
# 7659  2025-07-01              Faria J.             Sonego L.             0
# 7660  2025-07-01             Monday J.               Paul T.             0
# 7661  2025-07-01          Loffhagen G.           Martinez P.             0
# 7662  2025-07-01              Cilic M.          Collignon R.             1
# 7663  2025-07-01            Dzumhur D.             Machac T.             0
# 7664  2025-07-01         Medjedovic H.              Ofner S.             0
# 7665  2025-07-01    Carballes Baena R.          De Minaur A.             0
# 7666  2025-07-01           Marozsan F.             McCabe J.             1
# 7667  2025-07-01               Baez S.             Draper J.             0
# 7668  2025-07-01           Dimitrov G.           Nishioka Y.             1
# 7669  2025-07-01       Basilashvili N.            Musetti L.             1
# 7678  2025-07-02                 Bu Y.          Nakashima B.             0
#
#       Predicted  Probability     Result
# 7607          0     0.235622   ✗ Failed
# 7608          0     0.045020   ✗ Failed
# 7609          0     0.382720  ✓ Correct
# 7610          1     0.793425  ✓ Correct
# 7611          0     0.060210  ✓ Correct
# 7612          1     0.692129  ✓ Correct
# 7613          0     0.232009  ✓ Correct
# 7614          0     0.189610   ✗ Failed
# 7615          0     0.061988  ✓ Correct
# 7616          0     0.494500  ✓ Correct
# 7617          0     0.162554  ✓ Correct
# 7618          1     0.689990  ✓ Correct
# 7619          0     0.288611  ✓ Correct
# 7620          1     0.638061   ✗ Failed
# 7621          1     0.973214  ✓ Correct
# 7622          0     0.340738  ✓ Correct
# 7623          0     0.232820  ✓ Correct
# 7624          0     0.103124   ✗ Failed
# 7625          1     0.797743  ✓ Correct
# 7626          1     0.797743  ✓ Correct
# 7627          1     0.721135  ✓ Correct
# 7628          1     0.734258   ✗ Failed
# 7629          1     0.824345  ✓ Correct
# 7630          1     0.913441   ✗ Failed
# 7631          1     0.678708  ✓ Correct
# 7632          0     0.322725   ✗ Failed
# 7633          0     0.307659   ✗ Failed
# 7634          0     0.160269   ✗ Failed
# 7635          1     0.751392   ✗ Failed
# 7636          0     0.189610   ✗ Failed
# 7637          1     0.973214  ✓ Correct
# 7638          1     0.879320   ✗ Failed
# 7639          0     0.262005  ✓ Correct
# 7640          1     0.784998  ✓ Correct
# 7641          1     0.569525  ✓ Correct
# 7642          0     0.171940  ✓ Correct
# 7643          0     0.262005   ✗ Failed
# 7644          1     0.672897  ✓ Correct
# 7645          1     0.834922  ✓ Correct
# 7646          0     0.189610  ✓ Correct
# 7647          1     0.913441  ✓ Correct
# 7648          0     0.045020   ✗ Failed
# 7649          1     0.824345  ✓ Correct
# 7650          0     0.447396   ✗ Failed
# 7651          1     0.579007   ✗ Failed
# 7652          1     0.599214   ✗ Failed
# 7653          0     0.162554  ✓ Correct
# 7654          0     0.326204  ✓ Correct
# 7655          1     0.764514   ✗ Failed
# 7656          1     0.900143   ✗ Failed
# 7657          0     0.017143  ✓ Correct
# 7658          1     0.758249  ✓ Correct
# 7659          0     0.230304  ✓ Correct
# 7660          0     0.045020  ✓ Correct
# 7661          1     0.559420   ✗ Failed
# 7662          1     0.913441  ✓ Correct
# 7663          0     0.259204  ✓ Correct
# 7664          1     0.689990   ✗ Failed
# 7665          0     0.060210  ✓ Correct
# 7666          1     0.692129  ✓ Correct
# 7667          0     0.045020  ✓ Correct
# 7668          1     0.873037  ✓ Correct
# 7669          0     0.149406   ✗ Failed
# 7678          0     0.189610  ✓ Correct
# ====================================================================================================
# PREDICCIONES FALLIDAS:
# ====================================================================================================
#             Date           PlayerA               PlayerB  WinnerBinary  \
# 7607  2025-06-30       Brooksby J.         Griekspoor T.             1
# 7608  2025-06-30          Bonzi B.           Medvedev D.             1
# 7614  2025-06-30          Royer V.          Tsitsipas S.             1
# 7620  2025-06-30  Bautista Agut R.             Norrie C.             0
# 7624  2025-06-30           Fery A.            Popyrin A.             1
# 7628  2025-06-30          Bergs Z.             Harris L.             0
# 7630  2025-06-30     Berrettini M.          Majchrzak K.             0
# 7632  2025-06-30         Borges N.          Cerundolo F.             1
# 7633  2025-06-30        Darderi L.          Safiullin R.             1
# 7634  2025-06-30          Jarry N.               Rune H.             1
# 7635  2025-07-01        Humbert U.            Monfils G.             0
# 7636  2025-07-01         Navone M.         Shapovalov D.             1
# 7638  2025-07-01         Bublik A.              Munar J.             0
# 7643  2025-07-01     Kecmanovic M.          Michelsen A.             1
# 7648  2025-07-01    Rinderknech A.             Zverev A.             1
# 7650  2025-07-01        De Jong J.            Eubanks C.             1
# 7651  2025-07-01        Arnaldi M.  Van De Zandschulp B.             0
# 7652  2025-07-01         Goffin D.           Hijikata R.             0
# 7655  2025-07-01     Etcheverry T.   Pinnington Jones J.             0
# 7656  2025-07-01          Halys Q.           Holmgren A.             0
# 7661  2025-07-01      Loffhagen G.           Martinez P.             0
# 7664  2025-07-01     Medjedovic H.              Ofner S.             0
# 7669  2025-07-01   Basilashvili N.            Musetti L.             1
#
#       Predicted  Probability
# 7607          0     0.235622
# 7608          0     0.045020
# 7614          0     0.189610
# 7620          1     0.638061
# 7624          0     0.103124
# 7628          1     0.734258
# 7630          1     0.913441
# 7632          0     0.322725
# 7633          0     0.307659
# 7634          0     0.160269
# 7635          1     0.751392
# 7636          0     0.189610
# 7638          1     0.879320
# 7643          0     0.262005
# 7648          0     0.045020
# 7650          0     0.447396
# 7651          1     0.579007
# 7652          1     0.599214
# 7655          1     0.764514
# 7656          1     0.900143
# 7661          1     0.559420
# 7664          1     0.689990
# 7669          0     0.149406

# %% [markdown]
# ### 5.3. Segona ronda
#
# Continuem el procés incremental afegint les dades de la primera ronda.

# %%
# Actualizar el conjunt de entrenament: afegir first_round al train actual
train_second_round = pd.concat([first_round, train], ignore_index=True)

print(f"Mida del train original: {len(train_second_round) - len(first_round)}")
print(f"Mida de first_round afegir: {len(first_round)}")
print(f"Mida del nou train: {len(train_second_round)}")
print(f"\nTrain actualizat correctament. Llest per la següent fase.")

train_second_round.head()
# Out:
# Mida del train original: 7607
# Mida de first_round afegir: 64
# Mida del nou train: 7671
#
# Train actualizat correctament. Llest per la següent fase.
#    ATP Location Tournament        Date  Series  Court  Surface      Round  \
# 0   36   London  Wimbledon  2025-06-30       2      1        2  1st Round
# 1   36   London  Wimbledon  2025-06-30       2      1        2  1st Round
# 2   36   London  Wimbledon  2025-06-30       2      1        2  1st Round
# 3   36   London  Wimbledon  2025-06-30       2      1        2  1st Round
# 4   36   London  Wimbledon  2025-06-30       2      1        2  1st Round
#
#    Best of        Winner          Loser  WRank  LRank   W1   L1   W2   L2  \
# 0      5.0   Brooksby J.  Griekspoor T.  101.0   29.0  6.0  2.0  7.0  5.0
# 1      5.0      Bonzi B.    Medvedev D.   64.0    9.0  7.0  6.0  3.0  6.0
# 2      5.0    Fonseca J.    Fearnley J.   54.0   51.0  6.0  4.0  6.0  1.0
# 3      5.0  Khachanov K.    McDonald M.   20.0   88.0  7.0  5.0  6.0  4.0
# 4      5.0     Tiafoe F.      Moller E.   12.0  117.0  6.0  3.0  6.0  4.0
#
#     W3   L3   W4   L4  W5  L5  Wsets  Lsets    Comment  CBW  CBL  GBW  GBL  \
# 0  6.0  3.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN  NaN
# 1  7.0  6.0  6.0  2.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN  NaN
# 2  7.0  6.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN  NaN
# 3  6.0  4.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN  NaN
# 4  6.0  2.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN  NaN
#
#    IWW  IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW    PSL  \
# 0  NaN  NaN  NaN  NaN   2.75   1.40   NaN   NaN  NaN  NaN  2.70   1.52
# 1  NaN  NaN  NaN  NaN   8.50   1.07   NaN   NaN  NaN  NaN  9.03   1.09
# 2  NaN  NaN  NaN  NaN   1.50   2.63   NaN   NaN  NaN  NaN  1.49   2.79
# 3  NaN  NaN  NaN  NaN   1.22   4.33   NaN   NaN  NaN  NaN  1.21   4.91
# 4  NaN  NaN  NaN  NaN   1.04   9.00   NaN   NaN  NaN  NaN  1.06  12.44
#
#      WPts    LPts  UBW  UBL  LBW  LBL  SJW  SJL   MaxW   MaxL  AvgW   AvgL  \
# 0   577.0  1755.0  NaN  NaN  NaN  NaN  NaN  NaN   2.85   1.53  2.75   1.44
# 1   930.0  3420.0  NaN  NaN  NaN  NaN  NaN  NaN  12.50   1.09  8.56   1.07
# 2  1016.0  1060.0  NaN  NaN  NaN  NaN  NaN  NaN   1.53   2.86  1.47   2.67
# 3  2240.0   689.0  NaN  NaN  NaN  NaN  NaN  NaN   1.25   4.91  1.22   4.22
# 4  2990.0   499.0  NaN  NaN  NaN  NaN  NaN  NaN   1.07  13.50  1.05  10.57
#
#    BFEW  BFEL  MaxWin  MaxLoss  AvgWin  AvgLoss       PlayerA        PlayerB  \
# 0   NaN   NaN    2.75     1.52   2.725     1.46   Brooksby J.  Griekspoor T.
# 1   NaN   NaN    9.03     1.09   8.765     1.08      Bonzi B.    Medvedev D.
# 2   NaN   NaN    1.50     2.79   1.495     2.71   Fearnley J.     Fonseca J.
# 3   NaN   NaN    1.22     4.91   1.215     4.62  Khachanov K.    McDonald M.
# 4   NaN   NaN    1.06    12.44   1.050    10.72     Moller E.      Tiafoe F.
#
#    RankA  RankB  RankDiff  WinnerBinary  MaxOddsPlayerA  MaxOddsPlayerB  \
# 0  101.0   29.0      72.0             1            2.85            1.53
# 1   64.0    9.0      55.0             1           12.50            1.09
# 2   51.0   54.0      -3.0             0            2.86            1.53
# 3   20.0   88.0     -68.0             1            1.25            4.91
# 4  117.0   12.0     105.0             0           13.50            1.07
#
#    AvgOddsPlayerA  AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  H2H_Diff  WinsA  \
# 0            2.75            1.44           0           0         0     58
# 1            8.56            1.07           1           0         1     51
# 2            2.67            1.47           0           1        -1     15
# 3            1.22            4.22           5           0         5    283
# 4           10.57            1.05           0           0         0      0
#
#    LossesA  WinsB  LossesB  WinRateA_cum  WinRateB_cum  Form10A  Form10B  \
# 0       40    107       94      0.591837      0.532338      0.7      0.8
# 1       68    377      160      0.428571      0.702048      0.2      0.6
# 2       14     18       16      0.517241      0.529412      0.5      0.4
# 3      205    107      131      0.579918      0.449580      0.6      0.4
# 4        2    214      191      0.000000      0.528395      0.0      0.5
#
#    RestDaysA  RestDaysB    DiffWR  DiffForm  DiffRest  LogRankDiff  H2HDiff  \
# 0          2          2  0.059498      -0.1         0     1.247825        0
# 1          6          8 -0.273477      -0.4        -2     1.961659        1
# 2          5          4 -0.012170       0.1         1    -0.057158       -1
# 3          9         12  0.130338       0.2        -3    -1.481605        5
# 4         36         14 -0.528395      -0.5        22     2.277267        0
#
#    ProbA_odds  ProbB_odds  OddsProbDiff  WinRateA_x_Rank  WinRateB_x_Rank  \
# 0    0.350877    0.653595     -0.302718         0.005860         0.018356
# 1    0.080000    0.917431     -0.837431         0.006696         0.078005
# 2    0.349650    0.653595     -0.303944         0.010142         0.009804
# 3    0.800000    0.203666      0.596334         0.028996         0.005109
# 4    0.074074    0.934579     -0.860505         0.000000         0.044033
#
#    EfficiencyDiff  EloA_Global  EloB_Global  EloA_Surface  EloB_Surface  \
# 0       -0.012497  1555.332933  1612.307681   1533.884576   1583.992935
# 1       -0.071309  1445.016874  1704.547322   1426.887995   1659.093992
# 2        0.000338  1508.457531  1467.515774   1495.740663   1460.974829
# 3        0.023887  1582.443815  1518.933926   1548.116979   1490.150750
# 4       -0.044033  1499.250000  1562.354534   1498.500000   1528.328826
#
#    EloDiff_Global  EloDiff_Surface SurfaceText  RoundOrder
# 0      -56.974748       -50.108359       Grass           1
# 1     -259.530448      -232.205997       Grass           1
# 2       40.941757        34.765834       Grass           1
# 3       63.509889        57.966229       Grass           1
# 4      -63.104534       -29.828826       Grass           1

# %%
X_train = train_second_round[features].fillna(0)
X_test = second_round[features].fillna(0)
y_train = train_second_round['WinnerBinary']
y_test = second_round['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = LogisticRegression(
    C=1.0,                    # Paràmetre de regularització inversa. Valors més petits indiquen regularització més forta.
    max_iter=1000,            # Nombre màxim d'iteracions per convergir. 1000 és un valor segur per a conjunts de dades mitjans.
    class_weight='balanced',  # Equilibra els pesos de les classes automàticament per compensar classes desequilibrades.
    random_state=42,          # Llavor per a la reproductibilitat dels resultats.
    solver='lbfgs'            # Algoritme d'optimització. 'lbfgs' és bo per a problemes petits/medians i funciona bé amb regularització L2.
)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 0.7188
# Brier Score: 0.2149
#               precision    recall  f1-score   support
#
#            0     0.5789    0.9167    0.7097        12
#            1     0.9231    0.6000    0.7273        20
#
#     accuracy                         0.7188        32
#    macro avg     0.7510    0.7583    0.7185        32
# weighted avg     0.7940    0.7188    0.7207        32
#
# ================================================================================

# %%
results_df, failed_df = analyze_predictions(
    df=second_round,
    y_true=second_round["WinnerBinary"].values,
    y_pred=pred,
    y_prob=prob,
    date_col="Date",
    player_a_col="PlayerA",
    player_b_col="PlayerB",
    true_col_name="WinnerBinary"
)
# Out:
# RESULTADOS DETALLADOS POR FILA:
# ====================================================================================================
#
# Total de predicciones: 32
# Correctas: 23 (71.88%)
# Fallidas: 9 (28.12%)
#
# ====================================================================================================
#             Date               PlayerA               PlayerB  WinnerBinary  \
# 7670  2025-07-02          Majchrzak K.              Quinn E.             1
# 7671  2025-07-02           Bellucci M.            Lehecka J.             1
# 7672  2025-07-02             Norrie C.             Tiafoe F.             1
# 7673  2025-07-02             Harris L.             Rublev A.             0
# 7674  2025-07-02            Alcaraz C.             Tarvet O.             1
# 7675  2025-07-02          Mannarino A.              Royer V.             1
# 7676  2025-07-02              Jarry N.               Tien L.             1
# 7677  2025-07-02          Khachanov K.          Mochizuki S.             1
# 7679  2025-07-02             Diallo G.              Fritz T.             0
# 7680  2025-07-02              Bonzi B.           Thompson J.             0
# 7681  2025-07-02           Brooksby J.            Fonseca J.             0
# 7682  2025-07-02             Borges N.             Harris B.             1
# 7683  2025-07-03            Darderi L.               Fery A.             1
# 7684  2025-07-03           Martinez P.             Navone M.             1
# 7685  2025-07-03  Davidovich Fokina A.  Van De Zandschulp B.             1
# 7686  2025-07-03           Marozsan F.              Munar J.             0
# 7687  2025-07-03            Cobolli F.   Pinnington Jones J.             1
# 7688  2025-07-03           Djokovic N.              Evans D.             1
# 7689  2025-07-03              Giron M.             Mensik J.             0
# 7690  2025-07-03           Dimitrov G.             Moutet C.             1
# 7691  2025-07-03       Basilashvili N.             Sonego L.             0
# 7692  2025-07-03              Ofner S.               Paul T.             1
# 7693  2025-07-03           Holmgren A.             Machac T.             1
# 7694  2025-07-03              Garin C.        Rinderknech A.             0
# 7695  2025-07-03             Sinner J.              Vukic A.             1
# 7696  2025-07-03            De Jong J.         Kecmanovic M.             0
# 7697  2025-07-03    Auger-Aliassime F.           Struff J.L.             0
# 7698  2025-07-03              Cilic M.             Draper J.             1
# 7699  2025-07-03             Cazaux A.          De Minaur A.             0
# 7700  2025-07-03          Nakashima B.             Opelka R.             1
# 7708  2025-07-04           Hijikata R.            Shelton B.             0
# 7709  2025-07-04          Fucsovics M.            Monfils G.             1
#
#       Predicted  Probability     Result
# 7670          0     0.402023   ✗ Failed
# 7671          0     0.193772   ✗ Failed
# 7672          0     0.288359   ✗ Failed
# 7673          0     0.151271  ✓ Correct
# 7674          1     0.979808  ✓ Correct
# 7675          1     0.721306  ✓ Correct
# 7676          1     0.530385  ✓ Correct
# 7677          1     0.918178  ✓ Correct
# 7679          0     0.162586  ✓ Correct
# 7680          0     0.494534  ✓ Correct
# 7681          0     0.376319  ✓ Correct
# 7682          1     0.689072  ✓ Correct
# 7683          1     0.635383  ✓ Correct
# 7684          0     0.353248   ✗ Failed
# 7685          1     0.740142  ✓ Correct
# 7686          0     0.480523  ✓ Correct
# 7687          1     0.801791  ✓ Correct
# 7688          1     0.979808  ✓ Correct
# 7689          0     0.353248  ✓ Correct
# 7690          1     0.735926  ✓ Correct
# 7691          0     0.293160  ✓ Correct
# 7692          0     0.098464   ✗ Failed
# 7693          0     0.199752   ✗ Failed
# 7694          0     0.467149  ✓ Correct
# 7695          1     0.973214  ✓ Correct
# 7696          0     0.241039  ✓ Correct
# 7697          1     0.789815   ✗ Failed
# 7698          0     0.218367   ✗ Failed
# 7699          0     0.092185  ✓ Correct
# 7700          1     0.729084  ✓ Correct
# 7708          0     0.199752  ✓ Correct
# 7709          0     0.482569   ✗ Failed
# ====================================================================================================
# PREDICCIONES FALLIDAS:
# ====================================================================================================
#             Date             PlayerA      PlayerB  WinnerBinary  Predicted  \
# 7670  2025-07-02        Majchrzak K.     Quinn E.             1          0
# 7671  2025-07-02         Bellucci M.   Lehecka J.             1          0
# 7672  2025-07-02           Norrie C.    Tiafoe F.             1          0
# 7684  2025-07-03         Martinez P.    Navone M.             1          0
# 7692  2025-07-03            Ofner S.      Paul T.             1          0
# 7693  2025-07-03         Holmgren A.    Machac T.             1          0
# 7697  2025-07-03  Auger-Aliassime F.  Struff J.L.             0          1
# 7698  2025-07-03            Cilic M.    Draper J.             1          0
# 7709  2025-07-04        Fucsovics M.   Monfils G.             1          0
#
#       Probability
# 7670     0.402023
# 7671     0.193772
# 7672     0.288359
# 7684     0.353248
# 7692     0.098464
# 7693     0.199752
# 7697     0.789815
# 7698     0.218367
# 7709     0.482569

# %% [markdown]
# ### 5.4. Tercera ronda
#
# Continuem el procés incremental afegint les dades de la segona ronda.

# %%
# Actualizar el conjunto de entrenamiento: añadir second_round al train actual
train_third_round = pd.concat([second_round, train_second_round], ignore_index=True)

print(f"Tamaño del train original: {len(train_third_round) - len(second_round)}")
print(f"Tamaño de second_round añadido: {len(second_round)}")
print(f"Tamaño del nuevo train: {len(train_third_round)}")
print(f"\nTrain actualizado correctamente. Listo para la siguiente fase.")

train_third_round.head()
# Out:
# Tamaño del train original: 7671
# Tamaño de second_round añadido: 32
# Tamaño del nuevo train: 7703
#
# Train actualizado correctamente. Listo para la siguiente fase.
#    ATP Location Tournament        Date  Series  Court  Surface      Round  \
# 0   36   London  Wimbledon  2025-07-02       2      1        2  2nd Round
# 1   36   London  Wimbledon  2025-07-02       2      1        2  2nd Round
# 2   36   London  Wimbledon  2025-07-02       2      1        2  2nd Round
# 3   36   London  Wimbledon  2025-07-02       2      1        2  2nd Round
# 4   36   London  Wimbledon  2025-07-02       2      1        2  2nd Round
#
#    Best of        Winner       Loser  WRank  LRank   W1   L1   W2   L2   W3  \
# 0      5.0  Majchrzak K.    Quinn E.  109.0   89.0  6.0  1.0  6.0  4.0  6.0
# 1      5.0   Bellucci M.  Lehecka J.   73.0   25.0  7.0  6.0  6.0  1.0  7.0
# 2      5.0     Norrie C.   Tiafoe F.   61.0   12.0  4.0  6.0  6.0  4.0  6.0
# 3      5.0     Rublev A.   Harris L.   14.0  320.0  6.0  7.0  6.0  4.0  7.0
# 4      5.0    Alcaraz C.   Tarvet O.    2.0  733.0  6.0  1.0  6.0  4.0  6.0
#
#     L3   W4   L4  W5  L5  Wsets  Lsets    Comment  CBW  CBL  GBW  GBL  IWW  \
# 0  3.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN  NaN  NaN
# 1  5.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN  NaN  NaN
# 2  3.0  7.0  5.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN  NaN  NaN
# 3  6.0  6.0  3.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN  NaN  NaN
# 4  4.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN  NaN  NaN
#
#    IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW   PSL    WPts  \
# 0  NaN  NaN  NaN   2.20   1.62   NaN   NaN  NaN  NaN  2.26  1.72   527.0
# 1  NaN  NaN  NaN   4.50   1.20   NaN   NaN  NaN  NaN  5.04  1.21   864.0
# 2  NaN  NaN  NaN   2.50   1.53   NaN   NaN  NaN  NaN  2.59  1.57   952.0
# 3  NaN  NaN  NaN   1.29   3.75   NaN   NaN  NaN  NaN  1.31  3.81  2920.0
# 4  NaN  NaN  NaN   1.01  12.00   NaN   NaN  NaN  NaN   NaN   NaN  9300.0
#
#      LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW   MaxL  AvgW   AvgL  BFEW  BFEL  \
# 0   682.0  NaN  NaN  NaN  NaN  NaN  NaN  2.30   1.75  2.16   1.69   NaN   NaN
# 1  1965.0  NaN  NaN  NaN  NaN  NaN  NaN  5.30   1.22  4.57   1.20   NaN   NaN
# 2  2990.0  NaN  NaN  NaN  NaN  NaN  NaN  2.66   1.59  2.48   1.54   NaN   NaN
# 3   159.0  NaN  NaN  NaN  NaN  NaN  NaN  1.33   3.90  1.29   3.60   NaN   NaN
# 4    36.0  NaN  NaN  NaN  NaN  NaN  NaN  1.03  34.00  1.01  19.33   NaN   NaN
#
#    MaxWin  MaxLoss  AvgWin  AvgLoss       PlayerA     PlayerB  RankA  RankB  \
# 0    2.26     1.72   2.230    1.670  Majchrzak K.    Quinn E.  109.0   89.0
# 1    5.04     1.21   4.770    1.205   Bellucci M.  Lehecka J.   73.0   25.0
# 2    2.59     1.57   2.545    1.550     Norrie C.   Tiafoe F.   61.0   12.0
# 3    1.31     3.81   1.300    3.780     Harris L.   Rublev A.  320.0   14.0
# 4    1.01    12.00   1.010   12.000    Alcaraz C.   Tarvet O.    2.0  733.0
#
#    RankDiff  WinnerBinary  MaxOddsPlayerA  MaxOddsPlayerB  AvgOddsPlayerA  \
# 0      20.0             1            2.30            1.75            2.16
# 1      48.0             1            5.30            1.22            4.57
# 2      49.0             1            2.66            1.59            2.48
# 3     306.0             0            3.90            1.33            3.60
# 4    -731.0             1            1.03           34.00            1.01
#
#    AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  H2H_Diff  WinsA  LossesA  WinsB  \
# 0            1.69           0           0         0     23       35      9
# 1            1.20           0           0         0     14       19     90
# 2            1.54           1           2        -1    213      156    215
# 3            1.29           0           3        -3     63       77    335
# 4           19.33           0           0         0    235       59      1
#
#    LossesB  WinRateA_cum  WinRateB_cum  Form10A  Form10B  RestDaysA  \
# 0       16      0.396552      0.360000      0.5      0.4          2
# 1       68      0.424242      0.569620      0.4      0.7          2
# 2      191      0.577236      0.529557      0.6      0.6          2
# 3      188      0.450000      0.640535      0.4      0.7          2
# 4        0      0.799320      1.000000      1.0      1.0          2
#
#    RestDaysB    DiffWR  DiffForm  DiffRest  LogRankDiff  H2HDiff  ProbA_odds  \
# 0          2  0.036552       0.1         0     0.202712        0    0.434783
# 1          2 -0.145378      -0.3         0     1.071584        0    0.188679
# 2          2  0.047679       0.0         0     1.625967       -1    0.375940
# 3          2 -0.190535      -0.3         0     3.129264       -3    0.256410
# 4          2 -0.200680       0.0         0    -5.903999        0    0.970874
#
#    ProbB_odds  OddsProbDiff  WinRateA_x_Rank  WinRateB_x_Rank  EfficiencyDiff  \
# 0    0.571429     -0.136646         0.003638         0.004045       -0.000407
# 1    0.819672     -0.630993         0.005812         0.022785       -0.016973
# 2    0.628931     -0.252991         0.009463         0.044130       -0.034667
# 3    0.751880     -0.495469         0.001406         0.045753       -0.044346
# 4    0.029412      0.941462         0.399660         0.001364        0.398296
#
#    EloA_Global  EloB_Global  EloA_Surface  EloB_Surface  EloDiff_Global  \
# 0  1471.900657  1523.756610   1458.919230   1515.198809      -51.855952
# 1  1489.768419  1617.356344   1482.981179   1595.193619     -127.587925
# 2  1567.665112  1578.627935   1532.492388   1545.800085      -10.962824
# 3  1487.628773  1623.169013   1468.161856   1590.407235     -135.540240
# 4  1806.381603  1524.487375   1767.802433   1522.975500      281.894228
#
#    EloDiff_Surface SurfaceText  RoundOrder
# 0       -56.279580       Grass           2
# 1      -112.212440       Grass           2
# 2       -13.307697       Grass           2
# 3      -122.245379       Grass           2
# 4       244.826933       Grass           2

# %%
X_train = train_third_round[features].fillna(0)
X_test = third_round[features].fillna(0)
y_train = train_third_round['WinnerBinary']
y_test = third_round['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = LogisticRegression(
    C=1.0,                    # Paràmetre de regularització inversa. Valors més petits indiquen regularització més forta.
    max_iter=1000,            # Nombre màxim d'iteracions per convergir. 1000 és un valor segur per a conjunts de dades mitjans.
    class_weight='balanced',  # Equilibra els pesos de les classes automàticament per compensar classes desequilibrades.
    random_state=42,          # Llavor per a la reproductibilitat dels resultats.
    solver='lbfgs'            # Algoritme d'optimització. 'lbfgs' és bo per a problemes petits/medians i funciona bé amb regularització L2.
)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 0.7500
# Brier Score: 0.1381
#               precision    recall  f1-score   support
#
#            0     0.7778    0.7778    0.7778         9
#            1     0.7143    0.7143    0.7143         7
#
#     accuracy                         0.7500        16
#    macro avg     0.7460    0.7460    0.7460        16
# weighted avg     0.7500    0.7500    0.7500        16
#
# ================================================================================

# %%
results_df, failed_df = analyze_predictions(
    df=third_round,
    y_true=third_round["WinnerBinary"].values,
    y_pred=pred,
    y_prob=prob,
    date_col="Date",
    player_a_col="PlayerA",
    player_b_col="PlayerB",
    true_col_name="WinnerBinary"
)
# Out:
# RESULTADOS DETALLADOS POR FILA:
# ====================================================================================================
#
# Total de predicciones: 16
# Correctas: 12 (75.00%)
# Fallidas: 4 (25.00%)
#
# ====================================================================================================
#             Date               PlayerA         PlayerB  WinnerBinary  \
# 7701  2025-07-04          Mannarino A.       Rublev A.             0
# 7702  2025-07-04           Bellucci M.       Norrie C.             0
# 7703  2025-07-04            Alcaraz C.     Struff J.L.             1
# 7704  2025-07-04            Fonseca J.        Jarry N.             0
# 7705  2025-07-04  Davidovich Fokina A.        Fritz T.             0
# 7706  2025-07-04          Majchrzak K.  Rinderknech A.             1
# 7707  2025-07-04             Borges N.    Khachanov K.             0
# 7710  2025-07-04            Darderi L.     Thompson J.             0
# 7711  2025-07-05            Cobolli F.       Mensik J.             1
# 7712  2025-07-05          Nakashima B.       Sonego L.             0
# 7713  2025-07-05          De Minaur A.     Holmgren A.             1
# 7714  2025-07-05          Fucsovics M.      Shelton B.             0
# 7715  2025-07-05           Dimitrov G.        Ofner S.             1
# 7716  2025-07-05              Cilic M.        Munar J.             1
# 7717  2025-07-05           Martinez P.       Sinner J.             0
# 7718  2025-07-05           Djokovic N.   Kecmanovic M.             1
#
#       Predicted  Probability     Result
# 7701          0     0.237410  ✓ Correct
# 7702          0     0.281967  ✓ Correct
# 7703          1     0.973449  ✓ Correct
# 7704          1     0.690995   ✗ Failed
# 7705          0     0.155897  ✓ Correct
# 7706          0     0.405833   ✗ Failed
# 7707          0     0.244395  ✓ Correct
# 7710          0     0.341883  ✓ Correct
# 7711          0     0.353821   ✗ Failed
# 7712          1     0.690995   ✗ Failed
# 7713          1     0.919066  ✓ Correct
# 7714          0     0.262963  ✓ Correct
# 7715          1     0.845525  ✓ Correct
# 7716          1     0.787593  ✓ Correct
# 7717          0     0.031283  ✓ Correct
# 7718          1     0.973593  ✓ Correct
# ====================================================================================================
# PREDICCIONES FALLIDAS:
# ====================================================================================================
#             Date       PlayerA         PlayerB  WinnerBinary  Predicted  \
# 7704  2025-07-04    Fonseca J.        Jarry N.             0          1
# 7706  2025-07-04  Majchrzak K.  Rinderknech A.             1          0
# 7711  2025-07-05    Cobolli F.       Mensik J.             1          0
# 7712  2025-07-05  Nakashima B.       Sonego L.             0          1
#
#       Probability
# 7704     0.690995
# 7706     0.405833
# 7711     0.353821
# 7712     0.690995

# %% [markdown]
# ### 5.5. Quarta ronda

# %%
# Actualizar el conjunto de entrenamiento: añadir third_round al train actual
train_fourth_round = pd.concat([third_round, train_third_round], ignore_index=True)

print(f"Tamaño del train original: {len(train_fourth_round) - len(third_round)}")
print(f"Tamaño de third_round añadido: {len(third_round)}")
print(f"Tamaño del nuevo train: {len(train_fourth_round)}")
print(f"\nTrain actualizado correctamente. Listo para la siguiente fase.")

train_fourth_round.head()
# Out:
# Tamaño del train original: 7703
# Tamaño de third_round añadido: 16
# Tamaño del nuevo train: 7719
#
# Train actualizado correctamente. Listo para la siguiente fase.
#    ATP Location Tournament        Date  Series  Court  Surface      Round  \
# 0   36   London  Wimbledon  2025-07-04       2      1        2  3rd Round
# 1   36   London  Wimbledon  2025-07-04       2      1        2  3rd Round
# 2   36   London  Wimbledon  2025-07-04       2      1        2  3rd Round
# 3   36   London  Wimbledon  2025-07-04       2      1        2  3rd Round
# 4   36   London  Wimbledon  2025-07-04       2      1        2  3rd Round
#
#    Best of      Winner                 Loser  WRank  LRank   W1   L1   W2  \
# 0      5.0   Rublev A.          Mannarino A.   14.0  123.0  7.0  5.0  6.0
# 1      5.0   Norrie C.           Bellucci M.   61.0   73.0  7.0  6.0  6.0
# 2      5.0  Alcaraz C.           Struff J.L.    2.0  125.0  6.0  1.0  3.0
# 3      5.0    Jarry N.            Fonseca J.  143.0   54.0  6.0  3.0  6.0
# 4      5.0    Fritz T.  Davidovich Fokina A.    5.0   27.0  6.0  4.0  6.0
#
#     L2   W3   L3   W4   L4  W5  L5  Wsets  Lsets    Comment  CBW  CBL  GBW  \
# 0  2.0  6.0  3.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN
# 1  4.0  6.0  3.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN
# 2  6.0  6.0  3.0  6.0  4.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN
# 3  4.0  3.0  6.0  7.0  6.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN
# 4  3.0  6.0  7.0  6.0  1.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN
#
#    GBL  IWW  IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW    PSL  \
# 0  NaN  NaN  NaN  NaN  NaN   1.25   3.75   NaN   NaN  NaN  NaN  1.30   3.96
# 1  NaN  NaN  NaN  NaN  NaN   1.57   2.30   NaN   NaN  NaN  NaN  1.60   2.50
# 2  NaN  NaN  NaN  NaN  NaN   1.04  11.00   NaN   NaN  NaN  NaN  1.05  15.53
# 3  NaN  NaN  NaN  NaN  NaN   2.90   1.40   NaN   NaN  NaN  NaN  3.05   1.43
# 4  NaN  NaN  NaN  NaN  NaN   1.25   3.75   NaN   NaN  NaN  NaN  1.30   3.92
#
#      WPts    LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW   MaxL  AvgW   AvgL  \
# 0  2920.0   477.0  NaN  NaN  NaN  NaN  NaN  NaN  1.31   4.10  1.27   3.77
# 1   952.0   864.0  NaN  NaN  NaN  NaN  NaN  NaN  1.63   2.56  1.56   2.41
# 2  9300.0   475.0  NaN  NaN  NaN  NaN  NaN  NaN  1.05  18.00  1.03  12.61
# 3   418.0  1016.0  NaN  NaN  NaN  NaN  NaN  NaN  3.05   1.48  2.81   1.42
# 4  4635.0  1845.0  NaN  NaN  NaN  NaN  NaN  NaN  1.34   3.92  1.28   3.66
#
#    BFEW  BFEL  MaxWin  MaxLoss  AvgWin  AvgLoss               PlayerA  \
# 0   NaN   NaN    1.30     3.96   1.275    3.855          Mannarino A.
# 1   NaN   NaN    1.60     2.50   1.585    2.400           Bellucci M.
# 2   NaN   NaN    1.05    15.53   1.045   13.265            Alcaraz C.
# 3   NaN   NaN    3.05     1.43   2.975    1.415            Fonseca J.
# 4   NaN   NaN    1.30     3.92   1.275    3.835  Davidovich Fokina A.
#
#        PlayerB  RankA  RankB  RankDiff  WinnerBinary  MaxOddsPlayerA  \
# 0    Rublev A.  123.0   14.0     109.0             0            4.10
# 1    Norrie C.   73.0   61.0      12.0             0            2.56
# 2  Struff J.L.    2.0  125.0    -123.0             1            1.05
# 3     Jarry N.   54.0  143.0     -89.0             0            1.48
# 4     Fritz T.   27.0    5.0      22.0             0            3.92
#
#    MaxOddsPlayerB  AvgOddsPlayerA  AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  \
# 0            1.31            3.77            1.27           1           3
# 1            1.63            2.41            1.56           0           0
# 2           18.00            1.03           12.61           3           1
# 3            3.05            1.42            2.81           0           0
# 4            1.34            3.66            1.28           3           2
#
#    H2H_Diff  WinsA  LossesA  WinsB  LossesB  WinRateA_cum  WinRateB_cum  \
# 0        -2    298      344    336      188      0.464174      0.641221
# 1         0     15       19    214      156      0.441176      0.578378
# 2         2    236       59    208      241      0.800000      0.463252
# 3         0     20       16    107      110      0.555556      0.493088
# 4         1    138      127    286      189      0.520755      0.602105
#
#    Form10A  Form10B  RestDaysA  RestDaysB    DiffWR  DiffForm  DiffRest  \
# 0      0.4      0.7          2          2 -0.177047      -0.3         0
# 1      0.4      0.6          2          2 -0.137202      -0.2         0
# 2      1.0      0.4          2          1  0.336748       0.6         1
# 3      0.5      0.5          2          2  0.062468       0.0         0
# 4      0.7      0.9          1          2 -0.081351      -0.2        -1
#
#    LogRankDiff  H2HDiff  ProbA_odds  ProbB_odds  OddsProbDiff  \
# 0     2.173127       -2    0.243902    0.763359     -0.519456
# 1     0.179586        0    0.390625    0.613497     -0.222872
# 2    -4.135167        2    0.952381    0.055556      0.896825
# 3    -0.973861        0    0.675676    0.327869      0.347807
# 4     1.686399        1    0.255102    0.746269     -0.491167
#
#    WinRateA_x_Rank  WinRateB_x_Rank  EfficiencyDiff  EloA_Global  EloB_Global  \
# 0         0.003774         0.045802       -0.042028  1584.607625  1632.157744
# 1         0.006044         0.009482       -0.003438  1510.097396  1593.687989
# 2         0.400000         0.003706        0.396294  1808.905182  1557.455951
# 3         0.010288         0.003448        0.006840  1508.754340  1533.371476
# 4         0.019287         0.120421       -0.101134  1528.970909  1707.759945
#
#    EloA_Surface  EloB_Surface  EloDiff_Global  EloDiff_Surface SurfaceText  \
# 0   1542.463192   1599.133457      -47.550119       -56.670265       Grass
# 1   1501.947938   1557.928281      -83.590593       -55.980344       Grass
# 2   1770.114390   1525.673558      251.449231       244.440832       Grass
# 3   1499.726319   1509.966528      -24.617136       -10.240208       Grass
# 4   1509.092212   1668.348596     -178.789036      -159.256383       Grass
#
#    RoundOrder
# 0           3
# 1           3
# 2           3
# 3           3
# 4           3

# %%
X_train = train_fourth_round[features].fillna(0)
X_test = fourth_round[features].fillna(0)
y_train = train_fourth_round['WinnerBinary']
y_test = fourth_round['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = LogisticRegression(
    C=1.0,                    # Paràmetre de regularització inversa. Valors més petits indiquen regularització més forta.
    max_iter=1000,            # Nombre màxim d'iteracions per convergir. 1000 és un valor segur per a conjunts de dades mitjans.
    class_weight='balanced',  # Equilibra els pesos de les classes automàticament per compensar classes desequilibrades.
    random_state=42,          # Llavor per a la reproductibilitat dels resultats.
    solver='lbfgs'            # Algoritme d'optimització. 'lbfgs' és bo per a problemes petits/medians i funciona bé amb regularització L2.
)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 0.8750
# Brier Score: 0.0894
#               precision    recall  f1-score   support
#
#            0     1.0000    0.7500    0.8571         4
#            1     0.8000    1.0000    0.8889         4
#
#     accuracy                         0.8750         8
#    macro avg     0.9000    0.8750    0.8730         8
# weighted avg     0.9000    0.8750    0.8730         8
#
# ================================================================================

# %%
results_df, failed_df = analyze_predictions(
    df=fourth_round,
    y_true=fourth_round["WinnerBinary"].values,
    y_pred=pred,
    y_prob=prob,
    date_col="Date",
    player_a_col="PlayerA",
    player_b_col="PlayerB",
    true_col_name="WinnerBinary"
)
# Out:
# RESULTADOS DETALLADOS POR FILA:
# ====================================================================================================
#
# Total de predicciones: 8
# Correctas: 7 (87.50%)
# Fallidas: 1 (12.50%)
#
# ====================================================================================================
#             Date       PlayerA       PlayerB  WinnerBinary  Predicted  \
# 7719  2025-07-06      Fritz T.   Thompson J.             1          1
# 7720  2025-07-06      Jarry N.     Norrie C.             0          0
# 7721  2025-07-06  Khachanov K.  Majchrzak K.             1          1
# 7722  2025-07-06    Alcaraz C.     Rublev A.             1          1
# 7723  2025-07-07      Cilic M.    Cobolli F.             0          1
# 7724  2025-07-07    Shelton B.     Sonego L.             1          1
# 7725  2025-07-07   Dimitrov G.     Sinner J.             0          0
# 7726  2025-07-07  De Minaur A.   Djokovic N.             0          0
#
#       Probability     Result
# 7719     0.866037  ✓ Correct
# 7720     0.367878  ✓ Correct
# 7721     0.805183  ✓ Correct
# 7722     0.918316  ✓ Correct
# 7723     0.654381   ✗ Failed
# 7724     0.739340  ✓ Correct
# 7725     0.089168  ✓ Correct
# 7726     0.114608  ✓ Correct
# ====================================================================================================
# PREDICCIONES FALLIDAS:
# ====================================================================================================
#             Date   PlayerA     PlayerB  WinnerBinary  Predicted  Probability
# 7723  2025-07-07  Cilic M.  Cobolli F.             0          1     0.654381

# %% [markdown]
# ### 5.6. Quarts de final

# %%
# Actualizar el conjunto de entrenamiento: añadir fourth_round al train actual
train_quarter_finals = pd.concat([fourth_round, train_fourth_round], ignore_index=True)

print(f"Tamaño del train original: {len(train_quarter_finals) - len(fourth_round)}")
print(f"Tamaño de fourth_round añadido: {len(fourth_round)}")
print(f"Tamaño del nuevo train: {len(train_quarter_finals)}")
print(f"\nTrain actualizado correctamente. Listo para la siguiente fase.")

train_quarter_finals.head()
# Out:
# Tamaño del train original: 7719
# Tamaño de fourth_round añadido: 8
# Tamaño del nuevo train: 7727
#
# Train actualizado correctamente. Listo para la siguiente fase.
#    ATP Location Tournament        Date  Series  Court  Surface      Round  \
# 0   36   London  Wimbledon  2025-07-06       2      1        2  4th Round
# 1   36   London  Wimbledon  2025-07-06       2      1        2  4th Round
# 2   36   London  Wimbledon  2025-07-06       2      1        2  4th Round
# 3   36   London  Wimbledon  2025-07-06       2      1        2  4th Round
# 4   36   London  Wimbledon  2025-07-07       2      1        2  4th Round
#
#    Best of        Winner         Loser  WRank  LRank   W1   L1   W2   L2   W3  \
# 0      5.0      Fritz T.   Thompson J.    5.0   44.0  6.0  1.0  3.0  0.0  NaN
# 1      5.0     Norrie C.      Jarry N.   61.0  143.0  6.0  3.0  7.0  6.0  6.0
# 2      5.0  Khachanov K.  Majchrzak K.   20.0  109.0  6.0  4.0  6.0  2.0  6.0
# 3      5.0    Alcaraz C.     Rublev A.    2.0   14.0  6.0  7.0  6.0  3.0  6.0
# 4      5.0    Cobolli F.      Cilic M.   24.0   83.0  6.0  4.0  6.0  4.0  6.0
#
#     L3   W4   L4   W5   L5  Wsets  Lsets    Comment  CBW  CBL  GBW  GBL  IWW  \
# 0  NaN  NaN  NaN  NaN  NaN    1.0    0.0    Retired  NaN  NaN  NaN  NaN  NaN
# 1  7.0  6.0  7.0  6.0  3.0    3.0    2.0  Completed  NaN  NaN  NaN  NaN  NaN
# 2  3.0  NaN  NaN  NaN  NaN    3.0    0.0  Completed  NaN  NaN  NaN  NaN  NaN
# 3  4.0  6.0  4.0  NaN  NaN    3.0    1.0  Completed  NaN  NaN  NaN  NaN  NaN
# 4  7.0  7.0  6.0  NaN  NaN    3.0    1.0  Completed  NaN  NaN  NaN  NaN  NaN
#
#    IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW   PSL    WPts  \
# 0  NaN  NaN  NaN   1.14   5.50   NaN   NaN  NaN  NaN  1.15  6.36  4635.0
# 1  NaN  NaN  NaN   1.83   1.91   NaN   NaN  NaN  NaN  1.87  2.04   952.0
# 2  NaN  NaN  NaN   1.36   3.20   NaN   NaN  NaN  NaN  1.38  3.36  2240.0
# 3  NaN  NaN  NaN   1.08   7.00   NaN   NaN  NaN  NaN  1.10  8.57  9300.0
# 4  NaN  NaN  NaN   1.83   2.00   NaN   NaN  NaN  NaN  1.88  2.03  2035.0
#
#      LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW  MaxL  AvgW  AvgL  BFEW  BFEL  \
# 0  1200.0  NaN  NaN  NaN  NaN  NaN  NaN  1.16  6.80  1.14  5.64   NaN   NaN
# 1   418.0  NaN  NaN  NaN  NaN  NaN  NaN  2.10  2.08  1.84  1.96   NaN   NaN
# 2   527.0  NaN  NaN  NaN  NaN  NaN  NaN  1.40  3.40  1.35  3.19   NaN   NaN
# 3  2920.0  NaN  NaN  NaN  NaN  NaN  NaN  1.11  9.40  1.09  7.50   NaN   NaN
# 4   722.0  NaN  NaN  NaN  NaN  NaN  NaN  1.89  2.10  1.79  2.01   NaN   NaN
#
#    MaxWin  MaxLoss  AvgWin  AvgLoss       PlayerA       PlayerB  RankA  RankB  \
# 0    1.15     6.36   1.145    5.930      Fritz T.   Thompson J.    5.0   44.0
# 1    1.87     2.04   1.850    1.975      Jarry N.     Norrie C.  143.0   61.0
# 2    1.38     3.36   1.370    3.280  Khachanov K.  Majchrzak K.   20.0  109.0
# 3    1.10     8.57   1.090    7.785    Alcaraz C.     Rublev A.    2.0   14.0
# 4    1.88     2.03   1.855    2.015      Cilic M.    Cobolli F.   83.0   24.0
#
#    RankDiff  WinnerBinary  MaxOddsPlayerA  MaxOddsPlayerB  AvgOddsPlayerA  \
# 0     -39.0             1            1.16            6.80            1.14
# 1      82.0             0            2.08            2.10            1.96
# 2     -89.0             1            1.40            3.40            1.35
# 3     -12.0             1            1.11            9.40            1.09
# 4      59.0             0            2.10            1.89            2.01
#
#    AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  H2H_Diff  WinsA  LossesA  WinsB  \
# 0            5.64           1           1         0    287      189    147
# 1            1.84           1           0         1    108      110    215
# 2            3.19           3           0         3    286      205     25
# 3            7.50           2           1         1    237       59    337
# 4            1.79           0           2        -2    556      323     58
#
#    LossesB  WinRateA_cum  WinRateB_cum  Form10A  Form10B  RestDaysA  \
# 0      165      0.602941      0.471154      0.9      0.5          2
# 1      156      0.495413      0.579515      0.5      0.6          2
# 2       35      0.582485      0.416667      0.7      0.6          2
# 3      188      0.800676      0.641905      1.0      0.7          2
# 4       49      0.632537      0.542056      0.5      0.7          2
#
#    RestDaysB    DiffWR  DiffForm  DiffRest  LogRankDiff  H2HDiff  ProbA_odds  \
# 0          2  0.131787       0.4         0    -2.174752        0    0.862069
# 1          2 -0.084102      -0.1         0     0.851971        1    0.480769
# 2          2  0.165818       0.1         0    -1.695616        3    0.714286
# 3          2  0.158771       0.3         0    -1.945910        1    0.900901
# 4          2  0.090481      -0.2         0     1.240787       -2    0.476190
#
#    ProbB_odds  OddsProbDiff  WinRateA_x_Rank  WinRateB_x_Rank  EfficiencyDiff  \
# 0    0.147059      0.715010         0.120588         0.010708        0.109880
# 1    0.476190      0.004579         0.003464         0.009500       -0.006036
# 2    0.294118      0.420168         0.029124         0.003823        0.025302
# 3    0.106383      0.794518         0.400338         0.045850        0.354487
# 4    0.529101     -0.052910         0.007621         0.022586       -0.014965
#
#    EloA_Global  EloB_Global  EloA_Surface  EloB_Surface  EloDiff_Global  \
# 0  1712.378734  1588.874387   1672.615199   1554.619894      123.504347
# 1  1556.753588  1604.802715   1533.665233   1569.465233      -48.049127
# 2  1616.322216  1520.374896   1581.881337   1505.298845       95.947320
# 3  1811.958925  1649.303628   1772.431327   1614.953967      162.655297
# 4  1767.584060  1570.980643   1705.444237   1556.305961      196.603417
#
#    EloDiff_Surface SurfaceText  RoundOrder
# 0       117.995306       Grass           4
# 1       -35.800000       Grass           4
# 2        76.582492       Grass           4
# 3       157.477361       Grass           4
# 4       149.138276       Grass           4

# %%
X_train = train_quarter_finals[features].fillna(0)
X_test = quarter_finals[features].fillna(0)
y_train = train_quarter_finals['WinnerBinary']
y_test = quarter_finals['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = LogisticRegression(
    C=1.0,                    # Paràmetre de regularització inversa. Valors més petits indiquen regularització més forta.
    max_iter=1000,            # Nombre màxim d'iteracions per convergir. 1000 és un valor segur per a conjunts de dades mitjans.
    class_weight='balanced',  # Equilibra els pesos de les classes automàticament per compensar classes desequilibrades.
    random_state=42,          # Llavor per a la reproductibilitat dels resultats.
    solver='lbfgs'            # Algoritme d'optimització. 'lbfgs' és bo per a problemes petits/medians i funciona bé amb regularització L2.
)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 1.0000
# Brier Score: 0.0151
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000         2
#            1     1.0000    1.0000    1.0000         2
#
#     accuracy                         1.0000         4
#    macro avg     1.0000    1.0000    1.0000         4
# weighted avg     1.0000    1.0000    1.0000         4
#
# ================================================================================

# %%
results_df, failed_df = analyze_predictions(
    df=quarter_finals,
    y_true=quarter_finals["WinnerBinary"].values,
    y_pred=pred,
    y_prob=prob,
    date_col="Date",
    player_a_col="PlayerA",
    player_b_col="PlayerB",
    true_col_name="WinnerBinary"
)
# Out:
# RESULTADOS DETALLADOS POR FILA:
# ====================================================================================================
#
# Total de predicciones: 4
# Correctas: 4 (100.00%)
# Fallidas: 0 (0.00%)
#
# ====================================================================================================
#             Date     PlayerA       PlayerB  WinnerBinary  Predicted  \
# 7727  2025-07-08  Alcaraz C.     Norrie C.             1          1
# 7728  2025-07-08    Fritz T.  Khachanov K.             1          1
# 7729  2025-07-09  Cobolli F.   Djokovic N.             0          0
# 7730  2025-07-09  Shelton B.     Sinner J.             0          0
#
#       Probability     Result
# 7727     0.943178  ✓ Correct
# 7728     0.825602  ✓ Correct
# 7729     0.062884  ✓ Correct
# 7730     0.151278  ✓ Correct
# ====================================================================================================
# PREDICCIONES FALLIDAS:
# ====================================================================================================
# ¡Todas las predicciones han sido correctas!

# %% [markdown]
# ### 5.7. Semifinals

# %%
# Actualizar el conjunto de entrenamiento: añadir quarter_finals al train actual
train_semi_finals = pd.concat([quarter_finals, train_quarter_finals], ignore_index=True)

print(f"Tamaño del train original: {len(train_semi_finals) - len(quarter_finals)}")
print(f"Tamaño de quarter_finals añadido: {len(quarter_finals)}")
print(f"Tamaño del nuevo train: {len(train_semi_finals)}")
print(f"\nTrain actualizado correctamente. Listo para la siguiente fase.")

train_semi_finals.head()
# Out:
# Tamaño del train original: 7727
# Tamaño de quarter_finals añadido: 4
# Tamaño del nuevo train: 7731
#
# Train actualizado correctamente. Listo para la siguiente fase.
#    ATP Location Tournament        Date  Series  Court  Surface          Round  \
# 0   36   London  Wimbledon  2025-07-08       2      1        2  Quarterfinals
# 1   36   London  Wimbledon  2025-07-08       2      1        2  Quarterfinals
# 2   36   London  Wimbledon  2025-07-09       2      1        2  Quarterfinals
# 3   36   London  Wimbledon  2025-07-09       2      1        2  Quarterfinals
# 4   36   London  Wimbledon  2025-07-06       2      1        2      4th Round
#
#    Best of       Winner         Loser  WRank LRank   W1   L1   W2   L2   W3  \
# 0      5.0   Alcaraz C.     Norrie C.    2.0  61.0  6.0  2.0  6.0  3.0  6.0
# 1      5.0     Fritz T.  Khachanov K.    5.0  20.0  6.0  3.0  6.0  4.0  1.0
# 2      5.0  Djokovic N.    Cobolli F.    6.0  24.0  6.0  7.0  6.0  2.0  7.0
# 3      5.0    Sinner J.    Shelton B.    1.0  10.0  7.0  6.0  6.0  4.0  6.0
# 4      5.0     Fritz T.   Thompson J.    5.0  44.0  6.0  1.0  3.0  0.0  NaN
#
#     L3   W4   L4  W5  L5  Wsets  Lsets    Comment  CBW  CBL  GBW  GBL  IWW  \
# 0  3.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN  NaN  NaN
# 1  6.0  7.0  6.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN  NaN  NaN
# 2  5.0  6.0  4.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN  NaN  NaN
# 3  4.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN NaN NaN    1.0    0.0    Retired  NaN  NaN  NaN  NaN  NaN
#
#    IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW    PSL     WPts  \
# 0  NaN  NaN  NaN   1.06   9.00   NaN   NaN  NaN  NaN  1.07  10.89   9300.0
# 1  NaN  NaN  NaN   1.29   3.75   NaN   NaN  NaN  NaN  1.29   4.06   4635.0
# 2  NaN  NaN  NaN   1.10   7.00   NaN   NaN  NaN  NaN  1.11   8.33   4630.0
# 3  NaN  NaN  NaN   1.25   3.60   NaN   NaN  NaN  NaN  1.32   3.60  10430.0
# 4  NaN  NaN  NaN   1.14   5.50   NaN   NaN  NaN  NaN  1.15   6.36   4635.0
#
#      LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW  MaxL  AvgW  AvgL  BFEW  BFEL  \
# 0   952.0  NaN  NaN  NaN  NaN  NaN  NaN  1.07  13.5  1.05  9.96   NaN   NaN
# 1  2240.0  NaN  NaN  NaN  NaN  NaN  NaN  1.31   4.2  1.27  3.76   NaN   NaN
# 2  2035.0  NaN  NaN  NaN  NaN  NaN  NaN  1.12   8.6  1.09  7.53   NaN   NaN
# 3  3130.0  NaN  NaN  NaN  NaN  NaN  NaN  1.34   3.9  1.29  3.58   NaN   NaN
# 4  1200.0  NaN  NaN  NaN  NaN  NaN  NaN  1.16   6.8  1.14  5.64   NaN   NaN
#
#    MaxWin  MaxLoss  AvgWin  AvgLoss     PlayerA       PlayerB  RankA  RankB  \
# 0    1.07    10.89   1.065    9.945  Alcaraz C.     Norrie C.    2.0   61.0
# 1    1.29     4.06   1.290    3.905    Fritz T.  Khachanov K.    5.0   20.0
# 2    1.11     8.33   1.105    7.665  Cobolli F.   Djokovic N.   24.0    6.0
# 3    1.32     3.60   1.285    3.600  Shelton B.     Sinner J.   10.0    1.0
# 4    1.15     6.36   1.145    5.930    Fritz T.   Thompson J.    5.0   44.0
#
#    RankDiff  WinnerBinary  MaxOddsPlayerA  MaxOddsPlayerB  AvgOddsPlayerA  \
# 0     -59.0             1            1.07           13.50            1.05
# 1     -15.0             1            1.31            4.20            1.27
# 2      18.0             0            8.60            1.12            7.53
# 3       9.0             0            3.90            1.34            3.58
# 4     -39.0             1            1.16            6.80            1.14
#
#    AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  H2H_Diff  WinsA  LossesA  WinsB  \
# 0            9.96           4           2         2    238       59    216
# 1            3.76           0           1        -1    288      189    287
# 2            1.09           0           1        -1     59       49   1093
# 3            1.29           1           5        -4     93       65    272
# 4            5.64           1           1         0    287      189    147
#
#    LossesB  WinRateA_cum  WinRateB_cum  Form10A  Form10B  RestDaysA  \
# 0      156      0.801347      0.580645      1.0      0.7          2
# 1      205      0.603774      0.583333      0.9      0.8          2
# 2      215      0.546296      0.835627      0.7      0.9          2
# 3       86      0.588608      0.759777      0.6      0.8          2
# 4      165      0.602941      0.471154      0.9      0.5          2
#
#    RestDaysB    DiffWR  DiffForm  DiffRest  LogRankDiff  H2HDiff  ProbA_odds  \
# 0          2  0.220702       0.3         0    -3.417727        2    0.934579
# 1          2  0.020440       0.1         0    -1.386294       -1    0.763359
# 2          2 -0.289331      -0.2         0     1.386294       -1    0.116279
# 3          2 -0.171169      -0.2         0     2.302585       -4    0.256410
# 4          2  0.131787       0.4         0    -2.174752        0    0.862069
#
#    ProbB_odds  OddsProbDiff  WinRateA_x_Rank  WinRateB_x_Rank  EfficiencyDiff  \
# 0    0.074074      0.860505         0.400673         0.009519        0.391155
# 1    0.238095      0.525264         0.120755         0.029167        0.091588
# 2    0.892857     -0.776578         0.022762         0.139271       -0.116509
# 3    0.746269     -0.489858         0.058861         0.759777       -0.700916
# 4    0.147059      0.715010         0.120588         0.010708        0.109880
#
#    EloA_Global  EloB_Global  EloA_Surface  EloB_Surface  EloDiff_Global  \
# 0  1816.908221  1621.932975   1776.637363   1586.541410      194.975246
# 1  1721.794354  1626.906557   1681.428764   1592.503282       94.887798
# 2  1585.915415  1939.233116   1569.343906   1860.199075     -353.317701
# 3  1551.763916  1688.748267   1529.518201   1653.339587     -136.984350
# 4  1712.378734  1588.874387   1672.615199   1554.619894      123.504347
#
#    EloDiff_Surface SurfaceText  RoundOrder
# 0       190.095953       Grass           6
# 1        88.925482       Grass           6
# 2      -290.855169       Grass           6
# 3      -123.821386       Grass           6
# 4       117.995306       Grass           4

# %%
X_train = train_semi_finals[features].fillna(0)
X_test = semi_finals[features].fillna(0)
y_train = train_semi_finals['WinnerBinary']
y_test = semi_finals['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)


base_model = LogisticRegression(
    C=1.0,                    # Paràmetre de regularització inversa. Valors més petits indiquen regularització més forta.
    max_iter=1000,            # Nombre màxim d'iteracions per convergir. 1000 és un valor segur per a conjunts de dades mitjans.
    class_weight='balanced',  # Equilibra els pesos de les classes automàticament per compensar classes desequilibrades.
    random_state=42,          # Llavor per a la reproductibilitat dels resultats.
    solver='lbfgs'            # Algoritme d'optimització. 'lbfgs' és bo per a problemes petits/medians i funciona bé amb regularització L2.
)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 1.0000
# Brier Score: 0.0692
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000         1
#            1     1.0000    1.0000    1.0000         1
#
#     accuracy                         1.0000         2
#    macro avg     1.0000    1.0000    1.0000         2
# weighted avg     1.0000    1.0000    1.0000         2
#
# ================================================================================

# %%
results_df, failed_df = analyze_predictions(
    df=semi_finals,
    y_true=semi_finals["WinnerBinary"].values,
    y_pred=pred,
    y_prob=prob,
    date_col="Date",
    player_a_col="PlayerA",
    player_b_col="PlayerB",
    true_col_name="WinnerBinary"
)
# Out:
# RESULTADOS DETALLADOS POR FILA:
# ====================================================================================================
#
# Total de predicciones: 2
# Correctas: 2 (100.00%)
# Fallidas: 0 (0.00%)
#
# ====================================================================================================
#             Date      PlayerA    PlayerB  WinnerBinary  Predicted  \
# 7731  2025-07-11  Djokovic N.  Sinner J.             0          0
# 7732  2025-07-11   Alcaraz C.   Fritz T.             1          1
#
#       Probability     Result
# 7731     0.328507  ✓ Correct
# 7732     0.825519  ✓ Correct
# ====================================================================================================
# PREDICCIONES FALLIDAS:
# ====================================================================================================
# ¡Todas las predicciones han sido correctas!

# %% [markdown]
# ### 5.8. Final
#
# Última ronda del torneig. Nota: La final només té un partit, per la qual cosa els resultats poden ser més volàtils degut a la mida petita de la mostra.

# %%
# Actualizar el conjunto de entrenamiento: añadir semi_finals al train actual
train_final = pd.concat([semi_finals, train_semi_finals], ignore_index=True)

print(f"Tamaño del train original: {len(train_final) - len(train_semi_finals)}")
print(f"Tamaño de semi_finals añadido: {len(train_semi_finals)}")
print(f"Tamaño del nuevo train: {len(train_final)}")
print(f"\nTrain actualizado correctamente. Listo para la siguiente fase.")

train_final.head()
# Out:
# Tamaño del train original: 2
# Tamaño de semi_finals añadido: 7731
# Tamaño del nuevo train: 7733
#
# Train actualizado correctamente. Listo para la siguiente fase.
#    ATP Location Tournament        Date  Series  Court  Surface          Round  \
# 0   36   London  Wimbledon  2025-07-11       2      1        2     Semifinals
# 1   36   London  Wimbledon  2025-07-11       2      1        2     Semifinals
# 2   36   London  Wimbledon  2025-07-08       2      1        2  Quarterfinals
# 3   36   London  Wimbledon  2025-07-08       2      1        2  Quarterfinals
# 4   36   London  Wimbledon  2025-07-09       2      1        2  Quarterfinals
#
#    Best of       Winner         Loser  WRank LRank   W1   L1   W2   L2   W3  \
# 0      5.0    Sinner J.   Djokovic N.    1.0   6.0  6.0  3.0  6.0  3.0  6.0
# 1      5.0   Alcaraz C.      Fritz T.    2.0   5.0  6.0  4.0  5.0  7.0  6.0
# 2      5.0   Alcaraz C.     Norrie C.    2.0  61.0  6.0  2.0  6.0  3.0  6.0
# 3      5.0     Fritz T.  Khachanov K.    5.0  20.0  6.0  3.0  6.0  4.0  1.0
# 4      5.0  Djokovic N.    Cobolli F.    6.0  24.0  6.0  7.0  6.0  2.0  7.0
#
#     L3   W4   L4  W5  L5  Wsets  Lsets    Comment  CBW  CBL  GBW  GBL  IWW  \
# 0  4.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN  NaN  NaN
# 1  3.0  7.0  6.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN  NaN  NaN
# 2  3.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN  NaN  NaN
# 3  6.0  7.0  6.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN  NaN  NaN
# 4  5.0  6.0  4.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN  NaN  NaN
#
#    IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW    PSL     WPts  \
# 0  NaN  NaN  NaN   1.40   2.80   NaN   NaN  NaN  NaN  1.47   2.93  10430.0
# 1  NaN  NaN  NaN   1.17   4.75   NaN   NaN  NaN  NaN  1.20   5.13   9300.0
# 2  NaN  NaN  NaN   1.06   9.00   NaN   NaN  NaN  NaN  1.07  10.89   9300.0
# 3  NaN  NaN  NaN   1.29   3.75   NaN   NaN  NaN  NaN  1.29   4.06   4635.0
# 4  NaN  NaN  NaN   1.10   7.00   NaN   NaN  NaN  NaN  1.11   8.33   4630.0
#
#      LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW   MaxL  AvgW  AvgL  BFEW  BFEL  \
# 0  4630.0  NaN  NaN  NaN  NaN  NaN  NaN  1.47   3.05  1.42  2.85   NaN   NaN
# 1  4635.0  NaN  NaN  NaN  NaN  NaN  NaN  1.24   5.25  1.17  4.98   NaN   NaN
# 2   952.0  NaN  NaN  NaN  NaN  NaN  NaN  1.07  13.50  1.05  9.96   NaN   NaN
# 3  2240.0  NaN  NaN  NaN  NaN  NaN  NaN  1.31   4.20  1.27  3.76   NaN   NaN
# 4  2035.0  NaN  NaN  NaN  NaN  NaN  NaN  1.12   8.60  1.09  7.53   NaN   NaN
#
#    MaxWin  MaxLoss  AvgWin  AvgLoss      PlayerA       PlayerB  RankA  RankB  \
# 0    1.47     2.93   1.435    2.865  Djokovic N.     Sinner J.    6.0    1.0
# 1    1.20     5.13   1.185    4.940   Alcaraz C.      Fritz T.    2.0    5.0
# 2    1.07    10.89   1.065    9.945   Alcaraz C.     Norrie C.    2.0   61.0
# 3    1.29     4.06   1.290    3.905     Fritz T.  Khachanov K.    5.0   20.0
# 4    1.11     8.33   1.105    7.665   Cobolli F.   Djokovic N.   24.0    6.0
#
#    RankDiff  WinnerBinary  MaxOddsPlayerA  MaxOddsPlayerB  AvgOddsPlayerA  \
# 0       5.0             0            3.05            1.47            2.85
# 1      -3.0             1            1.24            5.25            1.17
# 2     -59.0             1            1.07           13.50            1.05
# 3     -15.0             1            1.31            4.20            1.27
# 4      18.0             0            8.60            1.12            7.53
#
#    AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  H2H_Diff  WinsA  LossesA  WinsB  \
# 0            1.42           4           4         0   1094      215    273
# 1            4.98           1           0         1    239       59    289
# 2            9.96           4           2         2    238       59    216
# 3            3.76           0           1        -1    288      189    287
# 4            1.09           0           1        -1     59       49   1093
#
#    LossesB  WinRateA_cum  WinRateB_cum  Form10A  Form10B  RestDaysA  \
# 0       86      0.835752      0.760446      0.9      0.8          2
# 1      189      0.802013      0.604603      1.0      0.9          3
# 2      156      0.801347      0.580645      1.0      0.7          2
# 3      205      0.603774      0.583333      0.9      0.8          2
# 4      215      0.546296      0.835627      0.7      0.9          2
#
#    RestDaysB    DiffWR  DiffForm  DiffRest  LogRankDiff  H2HDiff  ProbA_odds  \
# 0          2  0.075307       0.1         0     1.791759        0    0.327869
# 1          3  0.197411       0.1         0    -0.916291        1    0.806452
# 2          2  0.220702       0.3         0    -3.417727        2    0.934579
# 3          2  0.020440       0.1         0    -1.386294       -1    0.763359
# 4          2 -0.289331      -0.2         0     1.386294       -1    0.116279
#
#    ProbB_odds  OddsProbDiff  WinRateA_x_Rank  WinRateB_x_Rank  EfficiencyDiff  \
# 0    0.680272     -0.352403         0.139292         0.760446       -0.621154
# 1    0.190476      0.615975         0.401007         0.120921        0.280086
# 2    0.074074      0.860505         0.400673         0.009519        0.391155
# 3    0.238095      0.525264         0.120755         0.029167        0.091588
# 4    0.892857     -0.776578         0.022762         0.139271       -0.116509
#
#    EloA_Global  EloB_Global  EloA_Surface  EloB_Surface  EloDiff_Global  \
# 0  1940.668719  1697.648428   1861.618917   1661.940358      243.020291
# 1  1821.105118  1732.370096   1780.072422   1691.427815       88.735023
# 2  1816.908221  1621.932975   1776.637363   1586.541410      194.975246
# 3  1721.794354  1626.906557   1681.428764   1592.503282       94.887798
# 4  1585.915415  1939.233116   1569.343906   1860.199075     -353.317701
#
#    EloDiff_Surface SurfaceText  RoundOrder
# 0       199.678559       Grass           7
# 1        88.644606       Grass           7
# 2       190.095953       Grass           6
# 3        88.925482       Grass           6
# 4      -290.855169       Grass           6

# %%
X_train = train_final[features].fillna(0)
X_test = finals[features].fillna(0)
y_train = train_final['WinnerBinary']
y_test = finals['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = LogisticRegression(
    C=1.0,                    # Paràmetre de regularització inversa. Valors més petits indiquen regularització més forta.
    max_iter=1000,            # Nombre màxim d'iteracions per convergir. 1000 és un valor segur per a conjunts de dades mitjans.
    class_weight='balanced',  # Equilibra els pesos de les classes automàticament per compensar classes desequilibrades.
    random_state=42,          # Llavor per a la reproductibilitat dels resultats.
    solver='lbfgs'            # Algoritme d'optimització. 'lbfgs' és bo per a problemes petits/medians i funciona bé amb regularització L2.
)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 1.0000
# Brier Score: 0.1788
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000         1
#
#     accuracy                         1.0000         1
#    macro avg     1.0000    1.0000    1.0000         1
# weighted avg     1.0000    1.0000    1.0000         1
#
# ================================================================================

# %%
results_df, failed_df = analyze_predictions(
    df=finals,
    y_true=finals["WinnerBinary"].values,
    y_pred=pred,
    y_prob=prob,
    date_col="Date",
    player_a_col="PlayerA",
    player_b_col="PlayerB",
    true_col_name="WinnerBinary"
)
# Out:
# RESULTADOS DETALLADOS POR FILA:
# ====================================================================================================
#
# Total de predicciones: 1
# Correctas: 1 (100.00%)
# Fallidas: 0 (0.00%)
#
# ====================================================================================================
#             Date     PlayerA    PlayerB  WinnerBinary  Predicted  Probability  \
# 7733  2025-07-13  Alcaraz C.  Sinner J.             0          0     0.422862
#
#          Result
# 7733  ✓ Correct
# ====================================================================================================
# PREDICCIONES FALLIDAS:
# ====================================================================================================
# ¡Todas las predicciones han sido correctas!

# %% [markdown]
# ## Resum dels resultats
#
# El model de Regressió Logística amb calibratge isotònic ha estat avaluat en cada ronda del torneig de Wimbledon 2025. Els resultats mostren com el rendiment varia a mesura que el torneig progressa i el model s'entrena amb més dades.
#
# **Observacions importants:**
# - El model s'entrena incrementalment després de cada ronda, simulant un escenari real.
# - La Regressió Logística és un model lineal més simple que XGBoost, però pot ser més interpretable a través dels coeficients.
# - Les rondes posteriors (quarts de final, semifinals) poden mostrar diferents resultats degut a la naturalesa lineal del model.
# - La final només té un partit, per la qual cosa els resultats són més volàtils i difícils d'avaluar estadísticament.
# - L'escalat de característiques és crític per a regressió logística per assegurar una convergència adequada.
