# %%
import pandas as pd
import numpy as np

# Llegim el df

df = pd.read_csv('wimbeldon_dataset.csv')
df.head()
# Out:
#    ATP Location Tournament        Date      Series    Court Surface  \
# 0   36   London  Wimbledon  2025-07-13  Grand Slam  Outdoor   Grass
# 1   36   London  Wimbledon  2025-07-11  Grand Slam  Outdoor   Grass
# 2   36   London  Wimbledon  2025-07-11  Grand Slam  Outdoor   Grass
# 3   36   London  Wimbledon  2025-07-09  Grand Slam  Outdoor   Grass
# 4   36   London  Wimbledon  2025-07-09  Grand Slam  Outdoor   Grass
#
#            Round  Best of       Winner        Loser  WRank LRank   W1   L1  \
# 0      The Final      5.0    Sinner J.   Alcaraz C.    1.0     2  4.0  6.0
# 1     Semifinals      5.0   Alcaraz C.     Fritz T.    2.0     5  6.0  4.0
# 2     Semifinals      5.0    Sinner J.  Djokovic N.    1.0     6  6.0  3.0
# 3  Quarterfinals      5.0    Sinner J.   Shelton B.    1.0    10  7.0  6.0
# 4  Quarterfinals      5.0  Djokovic N.   Cobolli F.    6.0    24  6.0  7.0
#
#     W2   L2   W3   L3   W4   L4  W5  L5  Wsets  Lsets    Comment  CBW  CBL  \
# 0  6.0  4.0  6.0  4.0  6.0  4.0 NaN NaN    3.0    1.0  Completed  NaN  NaN
# 1  5.0  7.0  6.0  3.0  7.0  6.0 NaN NaN    3.0    1.0  Completed  NaN  NaN
# 2  6.0  3.0  6.0  4.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN
# 3  6.0  4.0  6.0  4.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN
# 4  6.0  2.0  7.0  5.0  6.0  4.0 NaN NaN    3.0    1.0  Completed  NaN  NaN
#
#    GBW  GBL  IWW  IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW  \
# 0  NaN  NaN  NaN  NaN  NaN  NaN   1.83   2.00   NaN   NaN  NaN  NaN  1.85
# 1  NaN  NaN  NaN  NaN  NaN  NaN   1.17   4.75   NaN   NaN  NaN  NaN  1.20
# 2  NaN  NaN  NaN  NaN  NaN  NaN   1.40   2.80   NaN   NaN  NaN  NaN  1.47
# 3  NaN  NaN  NaN  NaN  NaN  NaN   1.25   3.60   NaN   NaN  NaN  NaN  1.32
# 4  NaN  NaN  NaN  NaN  NaN  NaN   1.10   7.00   NaN   NaN  NaN  NaN  1.11
#
#     PSL     WPts    LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW  MaxL  AvgW  \
# 0  2.07  10430.0  9300.0  NaN  NaN  NaN  NaN  NaN  NaN  1.87  2.07  1.82
# 1  5.13   9300.0  4635.0  NaN  NaN  NaN  NaN  NaN  NaN  1.24  5.25  1.17
# 2  2.93  10430.0  4630.0  NaN  NaN  NaN  NaN  NaN  NaN  1.47  3.05  1.42
# 3  3.60  10430.0  3130.0  NaN  NaN  NaN  NaN  NaN  NaN  1.34  3.90  1.29
# 4  8.33   4630.0  2035.0  NaN  NaN  NaN  NaN  NaN  NaN  1.12  8.60  1.09
#
#    AvgL  BFEW  BFEL  MaxWin  MaxLoss  AvgWin  AvgLoss      PlayerA  \
# 0  1.98   NaN   NaN    1.85     2.07   1.840    2.035   Alcaraz C.
# 1  4.98   NaN   NaN    1.20     5.13   1.185    4.940   Alcaraz C.
# 2  2.85   NaN   NaN    1.47     2.93   1.435    2.865  Djokovic N.
# 3  3.58   NaN   NaN    1.32     3.60   1.285    3.600   Shelton B.
# 4  7.53   NaN   NaN    1.11     8.33   1.105    7.665   Cobolli F.
#
#        PlayerB  RankA  RankB  RankDiff  WinnerBinary  MaxOddsPlayerA  \
# 0    Sinner J.    2.0    1.0       1.0             0            2.07
# 1     Fritz T.    2.0    5.0      -3.0             1            1.24
# 2    Sinner J.    6.0    1.0       5.0             0            3.05
# 3    Sinner J.   10.0    1.0       9.0             0            3.90
# 4  Djokovic N.   24.0    6.0      18.0             0            8.60
#
#    MaxOddsPlayerB  AvgOddsPlayerA  AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  \
# 0            1.87            1.98            1.82          10           5
# 1            5.25            1.17            4.98           3           0
# 2            1.47            2.85            1.42           4           5
# 3            1.34            3.58            1.29           1           6
# 4            1.12            7.53            1.09           0           2
#
#    H2H_Diff  WinsA  LossesA  WinsB  LossesB  WinRateA_cum  WinRateB_cum  \
# 0         5    240       59    274       86      0.921053      0.736842
# 1         3    239       59    289      189      0.918919      0.657143
# 2        -1   1094      215    273       86      0.871429      0.729730
# 3        -5     93       65    272       86      0.545455      0.722222
# 4        -2     59       49   1093      215      0.600000      0.870504
#
#    Form10A  Form10B  RestDaysA  RestDaysB    DiffWR  DiffForm  DiffRest  \
# 0      1.0      0.8          2          2  0.184211       0.2         0
# 1      1.0      0.9          3          3  0.261776       0.1         0
# 2      0.9      0.8          2          2  0.141699       0.1         0
# 3      0.6      0.8          2          2 -0.176768      -0.2         0
# 4      0.7      0.9          2          2 -0.270504      -0.2         0
#
#    LogRankDiff  H2HDiff  ProbA_odds  ProbB_odds  OddsProbDiff  \
# 0     0.693147        5    0.483092    0.534759     -0.051668
# 1    -0.916291        3    0.806452    0.190476      0.615975
# 2     1.791759       -1    0.327869    0.680272     -0.352403
# 3     2.302585       -5    0.256410    0.746269     -0.489858
# 4     1.386294       -2    0.116279    0.892857     -0.776578
#
#    WinRateA_x_Rank  WinRateB_x_Rank  EfficiencyDiff
# 0         0.460526         0.736842       -0.276316
# 1         0.459459         0.131429        0.328031
# 2         0.145238         0.729730       -0.584492
# 3         0.054545         0.722222       -0.667677
# 4         0.025000         0.145084       -0.120084

# %% [markdown]
# ## Estrategia a seguir
#
# - Del 1 al 127 serà la test, les altes seran de test.
# - Dividirem el test per rondes.
# - Un poc hem pasat la ronda, afegirem els valor de test de la ronda a train.

# %%
test = df.head(127)
train = df.iloc[127:]

# %%
test.head()
# Out:
#    ATP Location Tournament        Date      Series    Court Surface  \
# 0   36   London  Wimbledon  2025-07-13  Grand Slam  Outdoor   Grass
# 1   36   London  Wimbledon  2025-07-11  Grand Slam  Outdoor   Grass
# 2   36   London  Wimbledon  2025-07-11  Grand Slam  Outdoor   Grass
# 3   36   London  Wimbledon  2025-07-09  Grand Slam  Outdoor   Grass
# 4   36   London  Wimbledon  2025-07-09  Grand Slam  Outdoor   Grass
#
#            Round  Best of       Winner        Loser  WRank LRank   W1   L1  \
# 0      The Final      5.0    Sinner J.   Alcaraz C.    1.0     2  4.0  6.0
# 1     Semifinals      5.0   Alcaraz C.     Fritz T.    2.0     5  6.0  4.0
# 2     Semifinals      5.0    Sinner J.  Djokovic N.    1.0     6  6.0  3.0
# 3  Quarterfinals      5.0    Sinner J.   Shelton B.    1.0    10  7.0  6.0
# 4  Quarterfinals      5.0  Djokovic N.   Cobolli F.    6.0    24  6.0  7.0
#
#     W2   L2   W3   L3   W4   L4  W5  L5  Wsets  Lsets    Comment  CBW  CBL  \
# 0  6.0  4.0  6.0  4.0  6.0  4.0 NaN NaN    3.0    1.0  Completed  NaN  NaN
# 1  5.0  7.0  6.0  3.0  7.0  6.0 NaN NaN    3.0    1.0  Completed  NaN  NaN
# 2  6.0  3.0  6.0  4.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN
# 3  6.0  4.0  6.0  4.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN
# 4  6.0  2.0  7.0  5.0  6.0  4.0 NaN NaN    3.0    1.0  Completed  NaN  NaN
#
#    GBW  GBL  IWW  IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW  \
# 0  NaN  NaN  NaN  NaN  NaN  NaN   1.83   2.00   NaN   NaN  NaN  NaN  1.85
# 1  NaN  NaN  NaN  NaN  NaN  NaN   1.17   4.75   NaN   NaN  NaN  NaN  1.20
# 2  NaN  NaN  NaN  NaN  NaN  NaN   1.40   2.80   NaN   NaN  NaN  NaN  1.47
# 3  NaN  NaN  NaN  NaN  NaN  NaN   1.25   3.60   NaN   NaN  NaN  NaN  1.32
# 4  NaN  NaN  NaN  NaN  NaN  NaN   1.10   7.00   NaN   NaN  NaN  NaN  1.11
#
#     PSL     WPts    LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW  MaxL  AvgW  \
# 0  2.07  10430.0  9300.0  NaN  NaN  NaN  NaN  NaN  NaN  1.87  2.07  1.82
# 1  5.13   9300.0  4635.0  NaN  NaN  NaN  NaN  NaN  NaN  1.24  5.25  1.17
# 2  2.93  10430.0  4630.0  NaN  NaN  NaN  NaN  NaN  NaN  1.47  3.05  1.42
# 3  3.60  10430.0  3130.0  NaN  NaN  NaN  NaN  NaN  NaN  1.34  3.90  1.29
# 4  8.33   4630.0  2035.0  NaN  NaN  NaN  NaN  NaN  NaN  1.12  8.60  1.09
#
#    AvgL  BFEW  BFEL  MaxWin  MaxLoss  AvgWin  AvgLoss      PlayerA  \
# 0  1.98   NaN   NaN    1.85     2.07   1.840    2.035   Alcaraz C.
# 1  4.98   NaN   NaN    1.20     5.13   1.185    4.940   Alcaraz C.
# 2  2.85   NaN   NaN    1.47     2.93   1.435    2.865  Djokovic N.
# 3  3.58   NaN   NaN    1.32     3.60   1.285    3.600   Shelton B.
# 4  7.53   NaN   NaN    1.11     8.33   1.105    7.665   Cobolli F.
#
#        PlayerB  RankA  RankB  RankDiff  WinnerBinary  MaxOddsPlayerA  \
# 0    Sinner J.    2.0    1.0       1.0             0            2.07
# 1     Fritz T.    2.0    5.0      -3.0             1            1.24
# 2    Sinner J.    6.0    1.0       5.0             0            3.05
# 3    Sinner J.   10.0    1.0       9.0             0            3.90
# 4  Djokovic N.   24.0    6.0      18.0             0            8.60
#
#    MaxOddsPlayerB  AvgOddsPlayerA  AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  \
# 0            1.87            1.98            1.82          10           5
# 1            5.25            1.17            4.98           3           0
# 2            1.47            2.85            1.42           4           5
# 3            1.34            3.58            1.29           1           6
# 4            1.12            7.53            1.09           0           2
#
#    H2H_Diff  WinsA  LossesA  WinsB  LossesB  WinRateA_cum  WinRateB_cum  \
# 0         5    240       59    274       86      0.921053      0.736842
# 1         3    239       59    289      189      0.918919      0.657143
# 2        -1   1094      215    273       86      0.871429      0.729730
# 3        -5     93       65    272       86      0.545455      0.722222
# 4        -2     59       49   1093      215      0.600000      0.870504
#
#    Form10A  Form10B  RestDaysA  RestDaysB    DiffWR  DiffForm  DiffRest  \
# 0      1.0      0.8          2          2  0.184211       0.2         0
# 1      1.0      0.9          3          3  0.261776       0.1         0
# 2      0.9      0.8          2          2  0.141699       0.1         0
# 3      0.6      0.8          2          2 -0.176768      -0.2         0
# 4      0.7      0.9          2          2 -0.270504      -0.2         0
#
#    LogRankDiff  H2HDiff  ProbA_odds  ProbB_odds  OddsProbDiff  \
# 0     0.693147        5    0.483092    0.534759     -0.051668
# 1    -0.916291        3    0.806452    0.190476      0.615975
# 2     1.791759       -1    0.327869    0.680272     -0.352403
# 3     2.302585       -5    0.256410    0.746269     -0.489858
# 4     1.386294       -2    0.116279    0.892857     -0.776578
#
#    WinRateA_x_Rank  WinRateB_x_Rank  EfficiencyDiff
# 0         0.460526         0.736842       -0.276316
# 1         0.459459         0.131429        0.328031
# 2         0.145238         0.729730       -0.584492
# 3         0.054545         0.722222       -0.667677
# 4         0.025000         0.145084       -0.120084

# %% [markdown]
# Dividim el test en les fases

# %%
# First round 
first_round = test[test['Round'] == '1st Round']
# Second round
second_round = test[test['Round'] == '2nd Round']
# Third round
third_round = test[test['Round'] == '3rd Round']
# Fourth round
fourth_round = test[test['Round'] == '4th Round']
# Quarter finals
quarter_finals = test[test['Round'] == 'Quarterfinals']
# Semi finals
semi_finals = test[test['Round'] == 'Semifinals']
# Finals
finals = test[test['Round'] == 'The Final']

# %%
test.tail()
# Out:
#      ATP Location Tournament        Date      Series    Court Surface  \
# 122   36   London  Wimbledon  2025-06-30  Grand Slam  Outdoor   Grass
# 123   36   London  Wimbledon  2025-06-30  Grand Slam  Outdoor   Grass
# 124   36   London  Wimbledon  2025-06-30  Grand Slam  Outdoor   Grass
# 125   36   London  Wimbledon  2025-06-30  Grand Slam  Outdoor   Grass
# 126   36   London  Wimbledon  2025-06-30  Grand Slam  Outdoor   Grass
#
#          Round  Best of                Winner           Loser  WRank LRank  \
# 122  1st Round      5.0          Khachanov K.     McDonald M.   20.0    88
# 123  1st Round      5.0               Tien L.  Basavareddy N.   62.0   100
# 124  1st Round      5.0  Davidovich Fokina A.         Holt B.   27.0    99
# 125  1st Round      5.0            Fonseca J.     Fearnley J.   54.0    51
# 126  1st Round      5.0           Brooksby J.   Griekspoor T.  101.0    29
#
#       W1   L1   W2   L2   W3   L3  W4  L4  W5  L5  Wsets  Lsets    Comment  \
# 122  7.0  5.0  6.0  4.0  6.0  4.0 NaN NaN NaN NaN    3.0    0.0  Completed
# 123  7.0  6.0  6.0  3.0  6.0  2.0 NaN NaN NaN NaN    3.0    0.0  Completed
# 124  6.0  2.0  6.0  4.0  7.0  5.0 NaN NaN NaN NaN    3.0    0.0  Completed
# 125  6.0  4.0  6.0  1.0  7.0  6.0 NaN NaN NaN NaN    3.0    0.0  Completed
# 126  6.0  2.0  7.0  5.0  6.0  3.0 NaN NaN NaN NaN    3.0    0.0  Completed
#
#      CBW  CBL  GBW  GBL  IWW  IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  \
# 122  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.22   4.33   NaN   NaN  NaN
# 123  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.50   2.60   NaN   NaN  NaN
# 124  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.22   4.33   NaN   NaN  NaN
# 125  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.50   2.63   NaN   NaN  NaN
# 126  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   2.75   1.40   NaN   NaN  NaN
#
#      EXL   PSW   PSL    WPts    LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW  \
# 122  NaN  1.21  4.91  2240.0   689.0  NaN  NaN  NaN  NaN  NaN  NaN  1.25
# 123  NaN  1.54  2.63   940.0   595.0  NaN  NaN  NaN  NaN  NaN  NaN  1.54
# 124  NaN  1.23  4.58  1845.0   600.0  NaN  NaN  NaN  NaN  NaN  NaN  1.26
# 125  NaN  1.49  2.79  1016.0  1060.0  NaN  NaN  NaN  NaN  NaN  NaN  1.53
# 126  NaN  2.70  1.52   577.0  1755.0  NaN  NaN  NaN  NaN  NaN  NaN  2.85
#
#      MaxL  AvgW  AvgL  BFEW  BFEL  MaxWin  MaxLoss  AvgWin  AvgLoss  \
# 122  4.91  1.22  4.22   NaN   NaN    1.22     4.91   1.215    4.620
# 123  2.80  1.46  2.68   NaN   NaN    1.54     2.63   1.520    2.615
# 124  4.70  1.22  4.28   NaN   NaN    1.23     4.58   1.225    4.455
# 125  2.86  1.47  2.67   NaN   NaN    1.50     2.79   1.495    2.710
# 126  1.53  2.75  1.44   NaN   NaN    2.75     1.52   2.725    1.460
#
#                   PlayerA        PlayerB  RankA  RankB  RankDiff  \
# 122          Khachanov K.    McDonald M.   20.0   88.0     -68.0
# 123        Basavareddy N.        Tien L.  100.0   62.0      38.0
# 124  Davidovich Fokina A.        Holt B.   27.0   99.0     -72.0
# 125           Fearnley J.     Fonseca J.   51.0   54.0      -3.0
# 126           Brooksby J.  Griekspoor T.  101.0   29.0      72.0
#
#      WinnerBinary  MaxOddsPlayerA  MaxOddsPlayerB  AvgOddsPlayerA  \
# 122             1            1.25            4.91            1.22
# 123             0            2.80            1.54            2.68
# 124             1            1.26            4.70            1.22
# 125             0            2.86            1.53            2.67
# 126             1            2.85            1.53            2.75
#
#      AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  H2H_Diff  WinsA  LossesA  WinsB  \
# 122            4.22           6           0         6    283      205    107
# 123            1.46           0           1        -1      3        8     13
# 124            4.28           2           0         2    136      127      3
# 125            1.47           0           2        -2     15       14     18
# 126            1.44           1           1         0     58       40    107
#
#      LossesB  WinRateA_cum  WinRateB_cum   Form10A  Form10B  RestDaysA  \
# 122      131      0.622222      0.513514  0.500000     0.50          9
# 123       18      0.000000      0.600000  0.000000     0.60          7
# 124       11      0.450000      0.500000  0.500000     0.50          3
# 125       16      0.444444      0.250000  0.444444     0.25          5
# 126       94      0.611111      0.645161  0.600000     0.70          2
#
#      RestDaysB    DiffWR  DiffForm  DiffRest  LogRankDiff  H2HDiff  \
# 122         12  0.108709  0.000000        -3    -1.481605        6
# 123          4 -0.600000 -0.600000         3     0.478036       -1
# 124          5 -0.050000  0.000000        -2    -1.299283        2
# 125          4  0.194444  0.194444         1    -0.057158       -2
# 126          2 -0.034050 -0.100000         0     1.247825        0
#
#      ProbA_odds  ProbB_odds  OddsProbDiff  WinRateA_x_Rank  WinRateB_x_Rank  \
# 122    0.800000    0.203666      0.596334         0.031111         0.005835
# 123    0.357143    0.649351     -0.292208         0.000000         0.009677
# 124    0.793651    0.212766      0.580885         0.016667         0.005051
# 125    0.349650    0.653595     -0.303944         0.008715         0.004630
# 126    0.350877    0.653595     -0.302718         0.006051         0.022247
#
#      EfficiencyDiff
# 122        0.025276
# 123       -0.009677
# 124        0.011616
# 125        0.004085
# 126       -0.016196

# %% [markdown]
# ---
#
# ## Prediccions amb XGBoost
#
# #### Primera fase

# %%
from collections import defaultdict
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import brier_score_loss
from sklearn.metrics import accuracy_score, classification_report

features = [
    'LogRankDiff',      # ranking
    'DiffWR',           # diferencia de winrate históric en herva
    'DiffForm',         # últims 10
    'H2HDiff',          # head-to-head
    'OddsProbDiff',     # diferencia de probabilitat implícita de quotas
    'DiffRest',         # dies de rest
    'EfficiencyDiff',   # winrate / rank → jugador que rendeix per sobre del seu ranking
    'RankDiff'          # diferencia de ranking
]

X_train = train[features].fillna(0)
X_test = first_round[features].fillna(0)
y_train = train['WinnerBinary']
y_test = first_round['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = XGBClassifier(
    n_estimators=500,                    # Nombre total d'arbres (boosting rounds) que es construiran. 500 és un valor força alt, bo per a un bon rendiment si es controla l'overfitting.
    max_depth=6,                         # Profunditat màxima de cada arbre. 6 és un valor moderat: permet interaccions complexes sense fer els arbres excessivament profunds.
    learning_rate=0.02,                  # Taxa d'aprenentatge (eta). 0.02 és bastant baixa → aprenentatge lent i estable, ideal quan tens molts estimators (500).
    subsample=0.85,                      # Percentatge de mostres (files) que s'utilitzen per entrenar cada arbre. 0.85 = 85% → ajuda a reduir overfitting i afegeix variància (com bagging).
    colsample_bytree=0.85,               # Percentatge de columnes (variables) que s'agafen aleatòriament per cada arbre. 85% → també redueix overfitting i millora la generalització.
    min_child_weight=5,                  # Suma mínima del pes Hessiana en un node fill. Valors >1 fan el model més conservador: evita dividir nodes amb poca informació.
    gamma=0.1,                           # Minimització mínima de la funció de pèrdua necessària per fer una partició addicional (regularització per poda). 0.1 afavoreix arbres més simples.
    reg_alpha=0.1,                       # Terme de regularització L1 sobre els pesos de les fulles. Ajuda a fer sparseness i és útil quan hi ha moltes variables irrellevants.
    reg_lambda=1.0,                      # Terme de regularització L2 (més suau que L1). 1.0 és el valor per defecte i sol funcionar bé en la majoria de casos.
    random_state=42,                     # Llavor per a la reproductibilitat dels resultats (aleatorietat controlada).
    n_jobs=-1,                           # Utilitza tots els nuclis disponibles del processador per entrenar en paral·lel → molt més ràpid.
    eval_metric='logloss'                # Mètrica d'avaluació durant l'entrenament (per classificació binària/multiclasse). 'logloss' = logarithmic loss (cross-entropy).
)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 0.9062
# Brier Score: 0.0459
#               precision    recall  f1-score   support
#
#            0     0.8611    0.9688    0.9118        32
#            1     0.9643    0.8438    0.9000        32
#
#     accuracy                         0.9062        64
#    macro avg     0.9127    0.9062    0.9059        64
# weighted avg     0.9127    0.9062    0.9059        64
#
# ================================================================================

# %%
# Resultats detallats per fila
results_df = first_round[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary']].copy()
results_df['Predicted'] = pred
results_df['Probability'] = prob
results_df['Correct'] = (results_df['WinnerBinary'] == results_df['Predicted'])
results_df['Result'] = results_df['Correct'].map({True: '✓ Correct', False: '✗ Failed'})

# Mostrar resultats
print("RESULTADOS DETALLADOS POR FILA:")
print("="*100)
print(f"\nTotal de predicciones: {len(results_df)}")
print(f"Correctas: {results_df['Correct'].sum()} ({results_df['Correct'].mean()*100:.2f}%)")
print(f"Fallidas: {(~results_df['Correct']).sum()} ({(~results_df['Correct']).mean()*100:.2f}%)")
print("\n" + "="*100 + "\n")

# Mostrar totes les files
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_columns', None)

display(results_df[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary', 'Predicted', 'Probability', 'Result']])

# Mostrar només les fallides per anàlisis
print("\n" + "="*100)
print("PREDICCIONS FALLIDES:")
print("="*100)
failed = results_df[~results_df['Correct']]
if len(failed) > 0:
    display(failed[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary', 'Predicted', 'Probability']])
else:
    print("Totes les prediccions han sigut correctes!")
# Out:
# RESULTADOS DETALLADOS POR FILA:
# ====================================================================================================
#
# Total de predicciones: 64
# Correctas: 58 (90.62%)
# Fallidas: 6 (9.38%)
#
# ====================================================================================================
#            Date               PlayerA               PlayerB  WinnerBinary  \
# 59   2025-07-02                 Bu Y.          Nakashima B.             0
# 64   2025-07-01       Basilashvili N.            Musetti L.             1
# 65   2025-07-01            Tseng C.H.              Vukic A.             0
# 66   2025-07-01               Baez S.             Draper J.             0
# 67   2025-07-01         Medjedovic H.              Ofner S.             0
# 68   2025-07-01            Dzumhur D.             Machac T.             0
# 69   2025-07-01              Cilic M.          Collignon R.             1
# 70   2025-07-01           Dimitrov G.           Nishioka Y.             1
# 71   2025-07-01             Goffin D.           Hijikata R.             0
# 72   2025-07-01           Comesana F.             Moutet C.             0
# 73   2025-07-01           Marozsan F.             McCabe J.             1
# 74   2025-07-01              Faria J.             Sonego L.             0
# 75   2025-07-01             Monday J.               Paul T.             0
# 76   2025-07-01              Nardi L.             Sinner J.             0
# 77   2025-07-01              Halys Q.           Holmgren A.             0
# 78   2025-07-01         Etcheverry T.   Pinnington Jones J.             0
# 79   2025-07-01    Carballes Baena R.          De Minaur A.             0
# 80   2025-07-01               Bolt A.            Shelton B.             0
# 81   2025-07-01             Clarke J.              Evans D.             0
# 82   2025-07-01            Arnaldi M.  Van De Zandschulp B.             0
# 83   2025-07-01             Opelka R.         Shevchenko A.             1
# 84   2025-07-01            Cobolli F.           Zhukayev B.             1
# 85   2025-07-01              Giron M.      Ugo Carabelli C.             1
# 86   2025-07-01          Loffhagen G.           Martinez P.             0
# 87   2025-07-01          Mochizuki S.           Zeppieri G.             1
# 88   2025-07-01         Kecmanovic M.          Michelsen A.             1
# 89   2025-07-01            De Jong J.            Eubanks C.             1
# 90   2025-07-01        Rinderknech A.             Zverev A.             1
# 91   2025-07-01            Humbert U.            Monfils G.             0
# 92   2025-07-01              Fritz T.            Mpetshi G.             1
# 93   2025-07-01          Fucsovics M.          Kovacevic A.             1
# 94   2025-07-01             Cazaux A.             Walton A.             1
# 95   2025-07-01             Bublik A.              Munar J.             0
# 96   2025-07-01           Djokovic N.             Muller A.             1
# 97   2025-07-01             Navone M.         Shapovalov D.             1
# 98   2025-07-01             Gaston H.             Mensik J.             0
# 99   2025-06-30              Garin C.            Rodesch C.             1
# 100  2025-06-30            Alcaraz C.            Fognini F.             1
# 101  2025-06-30         Berrettini M.          Majchrzak K.             0
# 102  2025-06-30    Auger-Aliassime F.          Duckworth J.             1
# 103  2025-06-30            Darderi L.          Safiullin R.             1
# 104  2025-06-30              Jarry N.               Rune H.             1
# 105  2025-06-30            Kopriva V.           Thompson J.             0
# 106  2025-06-30           Bellucci M.           Crawford O.             1
# 107  2025-06-30            Misolic F.           Struff J.L.             0
# 108  2025-06-30              Bergs Z.             Harris L.             0
# 109  2025-06-30              Quinn E.             Searle H.             1
# 110  2025-06-30             Borges N.          Cerundolo F.             1
# 111  2025-06-30               Fery A.            Popyrin A.             1
# 112  2025-06-30              Bonzi B.           Medvedev D.             1
# 113  2025-06-30              Djere L.             Rublev A.             0
# 114  2025-06-30            Dellien H.            Lehecka J.             0
# 115  2025-06-30      Bautista Agut R.             Norrie C.             0
# 116  2025-06-30              Royer V.          Tsitsipas S.             1
# 117  2025-06-30           Altmaier D.             Diallo G.             0
# 118  2025-06-30             Harris B.            Lajovic D.             1
# 119  2025-06-30              Riedi L.             Tarvet O.             0
# 120  2025-06-30          Mannarino A.          O Connell C.             1
# 121  2025-06-30             Moller E.             Tiafoe F.             0
# 122  2025-06-30          Khachanov K.           McDonald M.             1
# 123  2025-06-30        Basavareddy N.               Tien L.             0
# 124  2025-06-30  Davidovich Fokina A.               Holt B.             1
# 125  2025-06-30           Fearnley J.            Fonseca J.             0
# 126  2025-06-30           Brooksby J.         Griekspoor T.             1
#
#      Predicted  Probability     Result
# 59           0     0.062997  ✓ Correct
# 64           0     0.458080   ✗ Failed
# 65           0     0.054734  ✓ Correct
# 66           0     0.045112  ✓ Correct
# 67           0     0.119567  ✓ Correct
# 68           0     0.126251  ✓ Correct
# 69           1     0.917227  ✓ Correct
# 70           1     0.907543  ✓ Correct
# 71           0     0.199377  ✓ Correct
# 72           0     0.062997  ✓ Correct
# 73           1     0.982040  ✓ Correct
# 74           0     0.032094  ✓ Correct
# 75           0     0.000000  ✓ Correct
# 76           0     0.013255  ✓ Correct
# 77           0     0.167846  ✓ Correct
# 78           0     0.087820  ✓ Correct
# 79           0     0.042403  ✓ Correct
# 80           0     0.033736  ✓ Correct
# 81           0     0.042403  ✓ Correct
# 82           0     0.101017  ✓ Correct
# 83           1     0.932777  ✓ Correct
# 84           1     0.957878  ✓ Correct
# 85           1     0.968098  ✓ Correct
# 86           0     0.054734  ✓ Correct
# 87           1     1.000000  ✓ Correct
# 88           1     0.812167  ✓ Correct
# 89           1     0.918570  ✓ Correct
# 90           0     0.413523   ✗ Failed
# 91           1     0.748426   ✗ Failed
# 92           1     0.753062  ✓ Correct
# 93           1     0.914932  ✓ Correct
# 94           1     0.935409  ✓ Correct
# 95           0     0.172825  ✓ Correct
# 96           1     0.974115  ✓ Correct
# 97           1     0.811603  ✓ Correct
# 98           0     0.042403  ✓ Correct
# 99           1     0.950207  ✓ Correct
# 100          1     0.982028  ✓ Correct
# 101          0     0.115898  ✓ Correct
# 102          1     0.891993  ✓ Correct
# 103          1     0.874632  ✓ Correct
# 104          0     0.424808   ✗ Failed
# 105          0     0.062997  ✓ Correct
# 106          1     0.984218  ✓ Correct
# 107          0     0.042403  ✓ Correct
# 108          0     0.077924  ✓ Correct
# 109          1     0.971184  ✓ Correct
# 110          1     0.597471  ✓ Correct
# 111          1     0.773837  ✓ Correct
# 112          0     0.439772   ✗ Failed
# 113          0     0.139713  ✓ Correct
# 114          0     0.029066  ✓ Correct
# 115          0     0.129223  ✓ Correct
# 116          1     0.800437  ✓ Correct
# 117          0     0.052025  ✓ Correct
# 118          1     0.962963  ✓ Correct
# 119          0     0.045112  ✓ Correct
# 120          1     0.934947  ✓ Correct
# 121          0     0.000000  ✓ Correct
# 122          1     0.798988  ✓ Correct
# 123          0     0.062997  ✓ Correct
# 124          1     0.912834  ✓ Correct
# 125          0     0.085879  ✓ Correct
# 126          0     0.418545   ✗ Failed
# ====================================================================================================
# PREDICCIONES FALLIDAS:
# ====================================================================================================
#            Date          PlayerA        PlayerB  WinnerBinary  Predicted  \
# 64   2025-07-01  Basilashvili N.     Musetti L.             1          0
# 90   2025-07-01   Rinderknech A.      Zverev A.             1          0
# 91   2025-07-01       Humbert U.     Monfils G.             0          1
# 104  2025-06-30         Jarry N.        Rune H.             1          0
# 112  2025-06-30         Bonzi B.    Medvedev D.             1          0
# 126  2025-06-30      Brooksby J.  Griekspoor T.             1          0
#
#      Probability
# 64      0.458080
# 90      0.413523
# 91      0.748426
# 104     0.424808
# 112     0.439772
# 126     0.418545

# %%
first_round.tail()
# Out:
#      ATP Location Tournament        Date      Series    Court Surface  \
# 122   36   London  Wimbledon  2025-06-30  Grand Slam  Outdoor   Grass
# 123   36   London  Wimbledon  2025-06-30  Grand Slam  Outdoor   Grass
# 124   36   London  Wimbledon  2025-06-30  Grand Slam  Outdoor   Grass
# 125   36   London  Wimbledon  2025-06-30  Grand Slam  Outdoor   Grass
# 126   36   London  Wimbledon  2025-06-30  Grand Slam  Outdoor   Grass
#
#          Round  Best of                Winner           Loser  WRank LRank  \
# 122  1st Round      5.0          Khachanov K.     McDonald M.   20.0    88
# 123  1st Round      5.0               Tien L.  Basavareddy N.   62.0   100
# 124  1st Round      5.0  Davidovich Fokina A.         Holt B.   27.0    99
# 125  1st Round      5.0            Fonseca J.     Fearnley J.   54.0    51
# 126  1st Round      5.0           Brooksby J.   Griekspoor T.  101.0    29
#
#       W1   L1   W2   L2   W3   L3  W4  L4  W5  L5  Wsets  Lsets    Comment  \
# 122  7.0  5.0  6.0  4.0  6.0  4.0 NaN NaN NaN NaN    3.0    0.0  Completed
# 123  7.0  6.0  6.0  3.0  6.0  2.0 NaN NaN NaN NaN    3.0    0.0  Completed
# 124  6.0  2.0  6.0  4.0  7.0  5.0 NaN NaN NaN NaN    3.0    0.0  Completed
# 125  6.0  4.0  6.0  1.0  7.0  6.0 NaN NaN NaN NaN    3.0    0.0  Completed
# 126  6.0  2.0  7.0  5.0  6.0  3.0 NaN NaN NaN NaN    3.0    0.0  Completed
#
#      CBW  CBL  GBW  GBL  IWW  IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  \
# 122  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.22   4.33   NaN   NaN  NaN
# 123  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.50   2.60   NaN   NaN  NaN
# 124  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.22   4.33   NaN   NaN  NaN
# 125  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.50   2.63   NaN   NaN  NaN
# 126  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   2.75   1.40   NaN   NaN  NaN
#
#      EXL   PSW   PSL    WPts    LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW  \
# 122  NaN  1.21  4.91  2240.0   689.0  NaN  NaN  NaN  NaN  NaN  NaN  1.25
# 123  NaN  1.54  2.63   940.0   595.0  NaN  NaN  NaN  NaN  NaN  NaN  1.54
# 124  NaN  1.23  4.58  1845.0   600.0  NaN  NaN  NaN  NaN  NaN  NaN  1.26
# 125  NaN  1.49  2.79  1016.0  1060.0  NaN  NaN  NaN  NaN  NaN  NaN  1.53
# 126  NaN  2.70  1.52   577.0  1755.0  NaN  NaN  NaN  NaN  NaN  NaN  2.85
#
#      MaxL  AvgW  AvgL  BFEW  BFEL  MaxWin  MaxLoss  AvgWin  AvgLoss  \
# 122  4.91  1.22  4.22   NaN   NaN    1.22     4.91   1.215    4.620
# 123  2.80  1.46  2.68   NaN   NaN    1.54     2.63   1.520    2.615
# 124  4.70  1.22  4.28   NaN   NaN    1.23     4.58   1.225    4.455
# 125  2.86  1.47  2.67   NaN   NaN    1.50     2.79   1.495    2.710
# 126  1.53  2.75  1.44   NaN   NaN    2.75     1.52   2.725    1.460
#
#                   PlayerA        PlayerB  RankA  RankB  RankDiff  \
# 122          Khachanov K.    McDonald M.   20.0   88.0     -68.0
# 123        Basavareddy N.        Tien L.  100.0   62.0      38.0
# 124  Davidovich Fokina A.        Holt B.   27.0   99.0     -72.0
# 125           Fearnley J.     Fonseca J.   51.0   54.0      -3.0
# 126           Brooksby J.  Griekspoor T.  101.0   29.0      72.0
#
#      WinnerBinary  MaxOddsPlayerA  MaxOddsPlayerB  AvgOddsPlayerA  \
# 122             1            1.25            4.91            1.22
# 123             0            2.80            1.54            2.68
# 124             1            1.26            4.70            1.22
# 125             0            2.86            1.53            2.67
# 126             1            2.85            1.53            2.75
#
#      AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  H2H_Diff  WinsA  LossesA  WinsB  \
# 122            4.22           6           0         6    283      205    107
# 123            1.46           0           1        -1      3        8     13
# 124            4.28           2           0         2    136      127      3
# 125            1.47           0           2        -2     15       14     18
# 126            1.44           1           1         0     58       40    107
#
#      LossesB  WinRateA_cum  WinRateB_cum   Form10A  Form10B  RestDaysA  \
# 122      131      0.622222      0.513514  0.500000     0.50          9
# 123       18      0.000000      0.600000  0.000000     0.60          7
# 124       11      0.450000      0.500000  0.500000     0.50          3
# 125       16      0.444444      0.250000  0.444444     0.25          5
# 126       94      0.611111      0.645161  0.600000     0.70          2
#
#      RestDaysB    DiffWR  DiffForm  DiffRest  LogRankDiff  H2HDiff  \
# 122         12  0.108709  0.000000        -3    -1.481605        6
# 123          4 -0.600000 -0.600000         3     0.478036       -1
# 124          5 -0.050000  0.000000        -2    -1.299283        2
# 125          4  0.194444  0.194444         1    -0.057158       -2
# 126          2 -0.034050 -0.100000         0     1.247825        0
#
#      ProbA_odds  ProbB_odds  OddsProbDiff  WinRateA_x_Rank  WinRateB_x_Rank  \
# 122    0.800000    0.203666      0.596334         0.031111         0.005835
# 123    0.357143    0.649351     -0.292208         0.000000         0.009677
# 124    0.793651    0.212766      0.580885         0.016667         0.005051
# 125    0.349650    0.653595     -0.303944         0.008715         0.004630
# 126    0.350877    0.653595     -0.302718         0.006051         0.022247
#
#      EfficiencyDiff
# 122        0.025276
# 123       -0.009677
# 124        0.011616
# 125        0.004085
# 126       -0.016196

# %% [markdown]
# #### Segona fase

# %%
# Actualizar el conjunt de entrenament: afegir first_round al train actual
train_second_round = pd.concat([first_round, train], ignore_index=True)

print(f"Mida del train original: {len(train_second_round) - len(first_round)}")
print(f"Mida de first_round afegir: {len(first_round)}")
print(f"Mida del nou train: {len(train_second_round)}")
print(f"\nTrain actualizat correctament. Llest per la següent fase.")

train_second_round.head()
# Out:
# Tamaño del train original: 7607
# Tamaño de first_round añadido: 64
# Tamaño del nuevo train: 7671
#
# Train actualizado correctamente. Listo para la siguiente fase.
#    ATP Location Tournament        Date      Series    Court Surface  \
# 0   36   London  Wimbledon  2025-07-02  Grand Slam  Outdoor   Grass
# 1   36   London  Wimbledon  2025-07-01  Grand Slam  Outdoor   Grass
# 2   36   London  Wimbledon  2025-07-01  Grand Slam  Outdoor   Grass
# 3   36   London  Wimbledon  2025-07-01  Grand Slam  Outdoor   Grass
# 4   36   London  Wimbledon  2025-07-01  Grand Slam  Outdoor   Grass
#
#        Round  Best of           Winner          Loser  WRank LRank   W1   L1  \
# 0  1st Round      5.0     Nakashima B.          Bu Y.   34.0    71  6.0  4.0
# 1  1st Round      5.0  Basilashvili N.     Musetti L.  126.0     7  6.0  2.0
# 2  1st Round      5.0         Vukic A.     Tseng C.H.   93.0    96  6.0  3.0
# 3  1st Round      5.0        Draper J.        Baez S.    4.0    38  6.0  2.0
# 4  1st Round      5.0         Ofner S.  Medjedovic H.  165.0    68  7.0  6.0
#
#     W2   L2   W3   L3   W4   L4  W5  L5  Wsets  Lsets    Comment  CBW  CBL  \
# 0  4.0  6.0  7.0  6.0  6.0  4.0 NaN NaN    3.0    1.0  Completed  NaN  NaN
# 1  4.0  6.0  7.0  5.0  6.0  1.0 NaN NaN    3.0    1.0  Completed  NaN  NaN
# 2  6.0  4.0  4.0  6.0  7.0  6.0 NaN NaN    3.0    1.0  Completed  NaN  NaN
# 3  6.0  2.0  2.0  1.0  NaN  NaN NaN NaN    2.0    0.0    Retired  NaN  NaN
# 4  3.0  1.0  NaN  NaN  NaN  NaN NaN NaN    1.0    0.0    Retired  NaN  NaN
#
#    GBW  GBL  IWW  IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW  \
# 0  NaN  NaN  NaN  NaN  NaN  NaN   1.13   6.00   NaN   NaN  NaN  NaN  1.15
# 1  NaN  NaN  NaN  NaN  NaN  NaN   3.40   1.30   NaN   NaN  NaN  NaN  3.90
# 2  NaN  NaN  NaN  NaN  NaN  NaN   1.25   4.00   NaN   NaN  NaN  NaN  1.26
# 3  NaN  NaN  NaN  NaN  NaN  NaN   1.02  15.00   NaN   NaN  NaN  NaN   NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN   2.50   1.53   NaN   NaN  NaN  NaN  2.65
#
#     PSL    WPts    LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW   MaxL  AvgW  \
# 0  6.44  1650.0   874.0  NaN  NaN  NaN  NaN  NaN  NaN  1.18   6.50  1.13
# 1  1.29   474.0  4140.0  NaN  NaN  NaN  NaN  NaN  NaN  3.90   1.36  3.32
# 2  4.23   664.0   643.0  NaN  NaN  NaN  NaN  NaN  NaN  1.30   4.33  1.24
# 3   NaN  4650.0  1370.0  NaN  NaN  NaN  NaN  NaN  NaN  1.02  36.00  1.01
# 4  1.53   343.0   896.0  NaN  NaN  NaN  NaN  NaN  NaN  2.74   1.56  2.51
#
#     AvgL  BFEW  BFEL  MaxWin  MaxLoss  AvgWin  AvgLoss          PlayerA  \
# 0   5.96   NaN   NaN    1.15     6.44   1.140    6.220            Bu Y.
# 1   1.32   NaN   NaN    3.90     1.30   3.650    1.295  Basilashvili N.
# 2   4.01   NaN   NaN    1.26     4.23   1.255    4.115       Tseng C.H.
# 3  20.67   NaN   NaN    1.02    15.00   1.020   15.000          Baez S.
# 4   1.53   NaN   NaN    2.65     1.53   2.575    1.530    Medjedovic H.
#
#         PlayerB  RankA  RankB  RankDiff  WinnerBinary  MaxOddsPlayerA  \
# 0  Nakashima B.   71.0   34.0      37.0             0            6.50
# 1    Musetti L.  126.0    7.0     119.0             1            3.90
# 2      Vukic A.   96.0   93.0       3.0             0            4.33
# 3     Draper J.   38.0    4.0      34.0             0           36.00
# 4      Ofner S.   68.0  165.0     -97.0             0            1.56
#
#    MaxOddsPlayerB  AvgOddsPlayerA  AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  \
# 0            1.18            5.96            1.13           0           1
# 1            1.36            3.32            1.32           2           2
# 2            1.30            4.01            1.24           0           1
# 3            1.02           20.67            1.01           0           3
# 4            2.74            1.53            2.51           0           1
#
#    H2H_Diff  WinsA  LossesA  WinsB  LossesB  WinRateA_cum  WinRateB_cum  \
# 0        -1     13       24    106       95      0.000000      0.562500
# 1         0    140      167    146      108      0.454545      0.642857
# 2        -1      5       16     45       68      0.000000      0.476190
# 3        -3     97       93    103       53      0.300000      0.692308
# 4        -1     25       26     46       53      0.500000      0.437500
#
#    Form10A  Form10B  RestDaysA  RestDaysB    DiffWR  DiffForm  DiffRest  \
# 0      0.0      0.6         10         12 -0.562500      -0.6        -2
# 1      0.5      0.8       1096        354 -0.188312      -0.3       742
# 2      0.0      0.4          8          7 -0.476190      -0.4         1
# 3      0.3      0.7        365         10 -0.392308      -0.4       355
# 4      0.5      0.4          5         14  0.062500       0.1        -9
#
#    LogRankDiff  H2HDiff  ProbA_odds  ProbB_odds  OddsProbDiff  \
# 0     0.736319       -1    0.153846    0.847458     -0.693611
# 1     2.890372        0    0.256410    0.735294     -0.478884
# 2     0.031749       -1    0.230947    0.769231     -0.538284
# 3     2.251292       -3    0.027778    0.980392     -0.952614
# 4    -0.886438       -1    0.641026    0.364964      0.276062
#
#    WinRateA_x_Rank  WinRateB_x_Rank  EfficiencyDiff
# 0         0.000000         0.016544       -0.016544
# 1         0.003608         0.091837       -0.088229
# 2         0.000000         0.005120       -0.005120
# 3         0.007895         0.173077       -0.165182
# 4         0.007353         0.002652        0.004701

# %%
features = [
    'LogRankDiff',      # ranking
    'DiffWR',           # diferencia de winrate históric en herva
    'DiffForm',         # últims 10
    'H2HDiff',          # head-to-head
    'OddsProbDiff',     # diferencia de probabilitat implícita de quotas
    'DiffRest',         # dies de rest
    'EfficiencyDiff',   # winrate / rank → jugador que rendeix per sobre del seu ranking
    'RankDiff'          # diferencia de ranking
]

X_train = train_second_round[features].fillna(0)
X_test = second_round[features].fillna(0)
y_train = train_second_round['WinnerBinary']
y_test = second_round['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = XGBClassifier(
    n_estimators=500,                    # Nombre total d'arbres (boosting rounds) que es construiran. 500 és un valor força alt, bo per a un bon rendiment si es controla l'overfitting.
    max_depth=6,                         # Profunditat màxima de cada arbre. 6 és un valor moderat: permet interaccions complexes sense fer els arbres excessivament profunds.
    learning_rate=0.02,                  # Taxa d'aprenentatge (eta). 0.02 és bastant baixa → aprenentatge lent i estable, ideal quan tens molts estimators (500).
    subsample=0.85,                      # Percentatge de mostres (files) que s'utilitzen per entrenar cada arbre. 0.85 = 85% → ajuda a reduir overfitting i afegeix variància (com bagging).
    colsample_bytree=0.85,               # Percentatge de columnes (variables) que s'agafen aleatòriament per cada arbre. 85% → també redueix overfitting i millora la generalització.
    min_child_weight=5,                  # Suma mínima del pes Hessiana en un node fill. Valors >1 fan el model més conservador: evita dividir nodes amb poca informació.
    gamma=0.1,                           # Minimització mínima de la funció de pèrdua necessària per fer una partició addicional (regularització per poda). 0.1 afavoreix arbres més simples.
    reg_alpha=0.1,                       # Terme de regularització L1 sobre els pesos de les fulles. Ajuda a fer sparseness i és útil quan hi ha moltes variables irrellevants.
    reg_lambda=1.0,                      # Terme de regularització L2 (més suau que L1). 1.0 és el valor per defecte i sol funcionar bé en la majoria de casos.
    random_state=42,                     # Llavor per a la reproductibilitat dels resultats (aleatorietat controlada).
    n_jobs=-1,                           # Utilitza tots els nuclis disponibles del processador per entrenar en paral·lel → molt més ràpid.
    eval_metric='logloss'                # Mètrica d'avaluació durant l'entrenament (per classificació binària/multiclasse). 'logloss' = logarithmic loss (cross-entropy).
)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 0.8438
# Brier Score: 0.1128
#               precision    recall  f1-score   support
#
#            0     0.7333    0.9167    0.8148        12
#            1     0.9412    0.8000    0.8649        20
#
#     accuracy                         0.8438        32
#    macro avg     0.8373    0.8583    0.8398        32
# weighted avg     0.8632    0.8438    0.8461        32
#
# ================================================================================

# %%
# Resultats detallats per fila
results_df = second_round[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary']].copy()
results_df['Predicted'] = pred
results_df['Probability'] = prob
results_df['Correct'] = (results_df['WinnerBinary'] == results_df['Predicted'])
results_df['Result'] = results_df['Correct'].map({True: '✓ Correct', False: '✗ Failed'})

# Mostrar resultats
print("RESULTADOS DETALLADOS POR FILA:")
print("="*100)
print(f"\nTotal de predicciones: {len(results_df)}")
print(f"Correctas: {results_df['Correct'].sum()} ({results_df['Correct'].mean()*100:.2f}%)")
print(f"Fallidas: {(~results_df['Correct']).sum()} ({(~results_df['Correct']).mean()*100:.2f}%)")
print("\n" + "="*100 + "\n")

# Mostrar totes les filas
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_columns', None)

display(results_df[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary', 'Predicted', 'Probability', 'Result']])

# Mostrar només les fallides per anàlisis
print("\n" + "="*100)
print("PREDICCIONS FALLIDES:")
print("="*100)
failed = results_df[~results_df['Correct']]
if len(failed) > 0:
    display(failed[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary', 'Predicted', 'Probability']])
else:
    print("Totes les prediccions han sigut correctes!")
# Out:
# RESULTADOS DETALLADOS POR FILA:
# ====================================================================================================
#
# Total de predicciones: 32
# Correctas: 27 (84.38%)
# Fallidas: 5 (15.62%)
#
# ====================================================================================================
#           Date               PlayerA               PlayerB  WinnerBinary  \
# 24  2025-07-04          Fucsovics M.            Monfils G.             1
# 32  2025-07-04           Hijikata R.            Shelton B.             0
# 33  2025-07-03           Martinez P.             Navone M.             1
# 34  2025-07-03           Holmgren A.             Machac T.             1
# 35  2025-07-03              Garin C.        Rinderknech A.             0
# 36  2025-07-03          Nakashima B.             Opelka R.             1
# 37  2025-07-03             Cazaux A.          De Minaur A.             0
# 38  2025-07-03            De Jong J.         Kecmanovic M.             0
# 39  2025-07-03    Auger-Aliassime F.           Struff J.L.             0
# 40  2025-07-03              Cilic M.             Draper J.             1
# 41  2025-07-03              Ofner S.               Paul T.             1
# 42  2025-07-03  Davidovich Fokina A.  Van De Zandschulp B.             1
# 43  2025-07-03           Dimitrov G.             Moutet C.             1
# 44  2025-07-03       Basilashvili N.             Sonego L.             0
# 45  2025-07-03              Giron M.             Mensik J.             0
# 46  2025-07-03           Djokovic N.              Evans D.             1
# 47  2025-07-03             Sinner J.              Vukic A.             1
# 48  2025-07-03            Darderi L.               Fery A.             1
# 49  2025-07-03           Marozsan F.              Munar J.             0
# 50  2025-07-03            Cobolli F.   Pinnington Jones J.             1
# 51  2025-07-02           Brooksby J.            Fonseca J.             0
# 52  2025-07-02           Bellucci M.            Lehecka J.             1
# 53  2025-07-02             Diallo G.              Fritz T.             0
# 54  2025-07-02             Borges N.             Harris B.             1
# 55  2025-07-02              Bonzi B.           Thompson J.             0
# 56  2025-07-02          Khachanov K.          Mochizuki S.             1
# 57  2025-07-02              Jarry N.               Tien L.             1
# 58  2025-07-02             Harris L.             Rublev A.             0
# 60  2025-07-02          Mannarino A.              Royer V.             1
# 61  2025-07-02             Norrie C.             Tiafoe F.             1
# 62  2025-07-02          Majchrzak K.              Quinn E.             1
# 63  2025-07-02            Alcaraz C.             Tarvet O.             1
#
#     Predicted  Probability     Result
# 24          0     0.168157   ✗ Failed
# 32          0     0.175146  ✓ Correct
# 33          1     0.881440  ✓ Correct
# 34          1     0.748006  ✓ Correct
# 35          0     0.078989  ✓ Correct
# 36          1     0.872253  ✓ Correct
# 37          0     0.026603  ✓ Correct
# 38          0     0.047382  ✓ Correct
# 39          1     0.871320   ✗ Failed
# 40          1     0.578215  ✓ Correct
# 41          0     0.392120   ✗ Failed
# 42          1     0.926057  ✓ Correct
# 43          0     0.249811   ✗ Failed
# 44          0     0.071553  ✓ Correct
# 45          0     0.460198  ✓ Correct
# 46          1     0.643877  ✓ Correct
# 47          1     0.918783  ✓ Correct
# 48          1     0.975984  ✓ Correct
# 49          0     0.114107  ✓ Correct
# 50          1     0.961077  ✓ Correct
# 51          0     0.079715  ✓ Correct
# 52          1     0.618554  ✓ Correct
# 53          0     0.275948  ✓ Correct
# 54          1     0.975984  ✓ Correct
# 55          0     0.164186  ✓ Correct
# 56          1     0.962843  ✓ Correct
# 57          1     0.940530  ✓ Correct
# 58          0     0.042275  ✓ Correct
# 60          1     0.961630  ✓ Correct
# 61          0     0.490182   ✗ Failed
# 62          1     0.863306  ✓ Correct
# 63          1     0.963743  ✓ Correct
# ====================================================================================================
# PREDICCIONES FALLIDAS:
# ====================================================================================================
#           Date             PlayerA      PlayerB  WinnerBinary  Predicted  \
# 24  2025-07-04        Fucsovics M.   Monfils G.             1          0
# 39  2025-07-03  Auger-Aliassime F.  Struff J.L.             0          1
# 41  2025-07-03            Ofner S.      Paul T.             1          0
# 43  2025-07-03         Dimitrov G.    Moutet C.             1          0
# 61  2025-07-02           Norrie C.    Tiafoe F.             1          0
#
#     Probability
# 24     0.168157
# 39     0.871320
# 41     0.392120
# 43     0.249811
# 61     0.490182

# %% [markdown]
# #### Tecera fase

# %%
# Actualizar el conjunto de entrenamiento: añadir first_round al train actual
train_third_round = pd.concat([second_round, train_second_round], ignore_index=True)

print(f"Tamaño del train original: {len(train_third_round) - len(second_round)}")
print(f"Tamaño de first_round añadido: {len(second_round)}")
print(f"Tamaño del nuevo train: {len(train_third_round)}")
print(f"\nTrain actualizado correctamente. Listo para la siguiente fase.")

train_third_round.head()
# Out:
# Tamaño del train original: 7671
# Tamaño de first_round añadido: 32
# Tamaño del nuevo train: 7703
#
# Train actualizado correctamente. Listo para la siguiente fase.
#    ATP Location Tournament        Date      Series    Court Surface  \
# 0   36   London  Wimbledon  2025-07-04  Grand Slam  Outdoor   Grass
# 1   36   London  Wimbledon  2025-07-04  Grand Slam  Outdoor   Grass
# 2   36   London  Wimbledon  2025-07-03  Grand Slam  Outdoor   Grass
# 3   36   London  Wimbledon  2025-07-03  Grand Slam  Outdoor   Grass
# 4   36   London  Wimbledon  2025-07-03  Grand Slam  Outdoor   Grass
#
#        Round  Best of          Winner        Loser  WRank LRank   W1   L1  \
# 0  2nd Round      5.0    Fucsovics M.   Monfils G.  105.0    48  6.0  4.0
# 1  2nd Round      5.0      Shelton B.  Hijikata R.   10.0    87  6.0  2.0
# 2  2nd Round      5.0     Martinez P.    Navone M.   52.0    91  7.0  5.0
# 3  2nd Round      5.0     Holmgren A.    Machac T.  192.0    23  7.0  6.0
# 4  2nd Round      5.0  Rinderknech A.     Garin C.   72.0   110  3.0  6.0
#
#     W2   L2   W3   L3   W4   L4   W5   L5  Wsets  Lsets    Comment  CBW  CBL  \
# 0  1.0  6.0  4.0  6.0  7.0  6.0  6.0  4.0    3.0    2.0  Completed  NaN  NaN
# 1  7.0  5.0  6.0  4.0  NaN  NaN  NaN  NaN    3.0    0.0  Completed  NaN  NaN
# 2  7.0  5.0  7.0  6.0  NaN  NaN  NaN  NaN    3.0    0.0  Completed  NaN  NaN
# 3  6.0  7.0  6.0  7.0  7.0  5.0  7.0  6.0    3.0    2.0  Completed  NaN  NaN
# 4  6.0  3.0  7.0  6.0  4.0  6.0  6.0  3.0    3.0    2.0  Completed  NaN  NaN
#
#    GBW  GBL  IWW  IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW  \
# 0  NaN  NaN  NaN  NaN  NaN  NaN   1.90   1.91   NaN   NaN  NaN  NaN  1.94
# 1  NaN  NaN  NaN  NaN  NaN  NaN   1.22   4.33   NaN   NaN  NaN  NaN  1.26
# 2  NaN  NaN  NaN  NaN  NaN  NaN   2.63   1.50   NaN   NaN  NaN  NaN  2.71
# 3  NaN  NaN  NaN  NaN  NaN  NaN   5.50   1.15   NaN   NaN  NaN  NaN  6.76
# 4  NaN  NaN  NaN  NaN  NaN  NaN   1.67   2.25   NaN   NaN  NaN  NaN  1.75
#
#     PSL    WPts    LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW  MaxL  AvgW  AvgL  \
# 0  1.96   564.0  1165.0  NaN  NaN  NaN  NaN  NaN  NaN  1.95  2.04  1.89  1.89
# 1  4.37  3130.0   693.0  NaN  NaN  NaN  NaN  NaN  NaN  1.26  4.80  1.22  4.29
# 2  1.53  1030.0   670.0  NaN  NaN  NaN  NaN  NaN  NaN  2.78  1.56  2.61  1.50
# 3  1.14   285.0  2110.0  NaN  NaN  NaN  NaN  NaN  NaN  6.80  1.17  5.63  1.14
# 4  2.21   873.0   525.0  NaN  NaN  NaN  NaN  NaN  NaN  1.75  2.34  1.65  2.24
#
#    BFEW  BFEL  MaxWin  MaxLoss  AvgWin  AvgLoss       PlayerA         PlayerB  \
# 0   NaN   NaN    1.94     1.96    1.92    1.935  Fucsovics M.      Monfils G.
# 1   NaN   NaN    1.26     4.37    1.24    4.350   Hijikata R.      Shelton B.
# 2   NaN   NaN    2.71     1.53    2.67    1.515   Martinez P.       Navone M.
# 3   NaN   NaN    6.76     1.15    6.13    1.145   Holmgren A.       Machac T.
# 4   NaN   NaN    1.75     2.25    1.71    2.230      Garin C.  Rinderknech A.
#
#    RankA  RankB  RankDiff  WinnerBinary  MaxOddsPlayerA  MaxOddsPlayerB  \
# 0  105.0   48.0      57.0             1            1.95            2.04
# 1   87.0   10.0      77.0             0            4.80            1.26
# 2   52.0   91.0     -39.0             1            2.78            1.56
# 3  192.0   23.0     169.0             1            6.80            1.17
# 4  110.0   72.0      38.0             0            2.34            1.75
#
#    AvgOddsPlayerA  AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  H2H_Diff  WinsA  \
# 0            1.89            1.89           2           3        -1    147
# 1            4.29            1.22           0           2        -2     34
# 2            2.61            1.50           1           0         1     80
# 3            5.63            1.14           1           0         1      1
# 4            2.24            1.65           0           1        -1    118
#
#    LossesA  WinsB  LossesB  WinRateA_cum  WinRateB_cum  Form10A  Form10B  \
# 0      156    566      344      0.500000      0.566265      0.6     0.60
# 1       49     90       65      0.470588      0.473684      0.4     0.60
# 2      107     30       37      0.307692      0.250000      0.2     0.25
# 3        1     56       45      1.000000      0.500000      1.0     0.50
# 4      103     80       95      0.500000      0.444444      0.5     0.60
#
#    RestDaysA  RestDaysB    DiffWR  DiffForm  DiffRest  LogRankDiff  H2HDiff  \
# 0          3          3 -0.066265      0.00         0     0.782759       -1
# 1          3          3 -0.003096     -0.20         0     2.163323       -2
# 2          2          2  0.057692     -0.05         0    -0.559616        1
# 3          2          2  0.500000      0.50         0     2.122001        1
# 4          3          2  0.055556     -0.10         1     0.423814       -1
#
#    ProbA_odds  ProbB_odds  OddsProbDiff  WinRateA_x_Rank  WinRateB_x_Rank  \
# 0    0.512821    0.490196      0.022624         0.004762         0.011797
# 1    0.208333    0.793651     -0.585317         0.005409         0.047368
# 2    0.359712    0.641026     -0.281313         0.005917         0.002747
# 3    0.147059    0.854701     -0.707642         0.005208         0.021739
# 4    0.427350    0.571429     -0.144078         0.004545         0.006173
#
#    EfficiencyDiff
# 0       -0.007035
# 1       -0.041959
# 2        0.003170
# 3       -0.016531
# 4       -0.001627

# %%
features = [
    'LogRankDiff',      # ranking
    'DiffWR',           # diferencia de winrate históric en herva
    'DiffForm',         # últims 10
    'H2HDiff',          # head-to-head
    'OddsProbDiff',     # diferencia de probabilitat implícita de quotas
    'DiffRest',         # dies de rest
    'EfficiencyDiff',   # winrate / rank → jugador que rendeix per sobre del seu ranking
    'RankDiff'          # diferencia de ranking
]

X_train = train_third_round[features].fillna(0)
X_test = third_round[features].fillna(0)
y_train = train_third_round['WinnerBinary']
y_test = third_round['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = XGBClassifier(
    n_estimators=500,                    # Nombre total d'arbres (boosting rounds) que es construiran. 500 és un valor força alt, bo per a un bon rendiment si es controla l'overfitting.
    max_depth=6,                         # Profunditat màxima de cada arbre. 6 és un valor moderat: permet interaccions complexes sense fer els arbres excessivament profunds.
    learning_rate=0.02,                  # Taxa d'aprenentatge (eta). 0.02 és bastant baixa → aprenentatge lent i estable, ideal quan tens molts estimators (500).
    subsample=0.85,                      # Percentatge de mostres (files) que s'utilitzen per entrenar cada arbre. 0.85 = 85% → ajuda a reduir overfitting i afegeix variància (com bagging).
    colsample_bytree=0.85,               # Percentatge de columnes (variables) que s'agafen aleatòriament per cada arbre. 85% → també redueix overfitting i millora la generalització.
    min_child_weight=5,                  # Suma mínima del pes Hessiana en un node fill. Valors >1 fan el model més conservador: evita dividir nodes amb poca informació.
    gamma=0.1,                           # Minimització mínima de la funció de pèrdua necessària per fer una partició addicional (regularització per poda). 0.1 afavoreix arbres més simples.
    reg_alpha=0.1,                       # Terme de regularització L1 sobre els pesos de les fulles. Ajuda a fer sparseness i és útil quan hi ha moltes variables irrellevants.
    reg_lambda=1.0,                      # Terme de regularització L2 (més suau que L1). 1.0 és el valor per defecte i sol funcionar bé en la majoria de casos.
    random_state=42,                     # Llavor per a la reproductibilitat dels resultats (aleatorietat controlada).
    n_jobs=-1,                           # Utilitza tots els nuclis disponibles del processador per entrenar en paral·lel → molt més ràpid.
    eval_metric='logloss'                # Mètrica d'avaluació durant l'entrenament (per classificació binària/multiclasse). 'logloss' = logarithmic loss (cross-entropy).
)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 0.9375
# Brier Score: 0.0445
#               precision    recall  f1-score   support
#
#            0     1.0000    0.8889    0.9412         9
#            1     0.8750    1.0000    0.9333         7
#
#     accuracy                         0.9375        16
#    macro avg     0.9375    0.9444    0.9373        16
# weighted avg     0.9453    0.9375    0.9377        16
#
# ================================================================================

# %%
# Resultados detallados por fila
results_df = third_round[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary']].copy()
results_df['Predicted'] = pred
results_df['Probability'] = prob
results_df['Correct'] = (results_df['WinnerBinary'] == results_df['Predicted'])
results_df['Result'] = results_df['Correct'].map({True: '✓ Correct', False: '✗ Failed'})

# Mostrar resultados
print("RESULTADOS DETALLADOS POR FILA:")
print("="*100)
print(f"\nTotal de predicciones: {len(results_df)}")
print(f"Correctas: {results_df['Correct'].sum()} ({results_df['Correct'].mean()*100:.2f}%)")
print(f"Fallidas: {(~results_df['Correct']).sum()} ({(~results_df['Correct']).mean()*100:.2f}%)")
print("\n" + "="*100 + "\n")

# Mostrar todas las filas
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_columns', None)

display(results_df[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary', 'Predicted', 'Probability', 'Result']])

# Mostrar solo las fallidas para análisis
print("\n" + "="*100)
print("PREDICCIONES FALLIDAS:")
print("="*100)
failed = results_df[~results_df['Correct']]
if len(failed) > 0:
    display(failed[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary', 'Predicted', 'Probability']])
else:
    print("¡Todas las predicciones fueron correctas!")
# Out:
# RESULTADOS DETALLADOS POR FILA:
# ====================================================================================================
#
# Total de predicciones: 16
# Correctas: 15 (93.75%)
# Fallidas: 1 (6.25%)
#
# ====================================================================================================
#           Date               PlayerA         PlayerB  WinnerBinary  Predicted  \
# 15  2025-07-05              Cilic M.        Munar J.             1          1
# 16  2025-07-05           Martinez P.       Sinner J.             0          0
# 17  2025-07-05           Djokovic N.   Kecmanovic M.             1          1
# 18  2025-07-05           Dimitrov G.        Ofner S.             1          1
# 19  2025-07-05          Fucsovics M.      Shelton B.             0          0
# 20  2025-07-05          De Minaur A.     Holmgren A.             1          1
# 21  2025-07-05          Nakashima B.       Sonego L.             0          0
# 22  2025-07-05            Cobolli F.       Mensik J.             1          1
# 23  2025-07-04            Darderi L.     Thompson J.             0          0
# 25  2025-07-04  Davidovich Fokina A.        Fritz T.             0          1
# 26  2025-07-04          Majchrzak K.  Rinderknech A.             1          1
# 27  2025-07-04            Alcaraz C.     Struff J.L.             1          1
# 28  2025-07-04             Borges N.    Khachanov K.             0          0
# 29  2025-07-04            Fonseca J.        Jarry N.             0          0
# 30  2025-07-04           Bellucci M.       Norrie C.             0          0
# 31  2025-07-04          Mannarino A.       Rublev A.             0          0
#
#     Probability     Result
# 15     0.921953  ✓ Correct
# 16     0.043505  ✓ Correct
# 17     0.976035  ✓ Correct
# 18     0.873191  ✓ Correct
# 19     0.054348  ✓ Correct
# 20     0.980753  ✓ Correct
# 21     0.257388  ✓ Correct
# 22     0.796044  ✓ Correct
# 23     0.134508  ✓ Correct
# 25     0.693864   ✗ Failed
# 26     0.895106  ✓ Correct
# 27     0.989646  ✓ Correct
# 28     0.182358  ✓ Correct
# 29     0.114684  ✓ Correct
# 30     0.131800  ✓ Correct
# 31     0.047809  ✓ Correct
# ====================================================================================================
# PREDICCIONES FALLIDAS:
# ====================================================================================================
#           Date               PlayerA   PlayerB  WinnerBinary  Predicted  \
# 25  2025-07-04  Davidovich Fokina A.  Fritz T.             0          1
#
#     Probability
# 25     0.693864

# %% [markdown]
# #### Quarta fase

# %%
# Actualizar el conjunto de entrenamiento: añadir first_round al train actual
train_fourth_round = pd.concat([third_round, train_third_round], ignore_index=True)

print(f"Tamaño del train original: {len(train_fourth_round) - len(third_round)}")
print(f"Tamaño de first_round añadido: {len(third_round)}")
print(f"Tamaño del nuevo train: {len(train_fourth_round)}")
print(f"\nTrain actualizado correctamente. Listo para la siguiente fase.")

train_fourth_round.head()
# Out:
# Tamaño del train original: 7703
# Tamaño de first_round añadido: 16
# Tamaño del nuevo train: 7719
#
# Train actualizado correctamente. Listo para la siguiente fase.
#    ATP Location Tournament        Date      Series    Court Surface  \
# 0   36   London  Wimbledon  2025-07-05  Grand Slam  Outdoor   Grass
# 1   36   London  Wimbledon  2025-07-05  Grand Slam  Outdoor   Grass
# 2   36   London  Wimbledon  2025-07-05  Grand Slam  Outdoor   Grass
# 3   36   London  Wimbledon  2025-07-05  Grand Slam  Outdoor   Grass
# 4   36   London  Wimbledon  2025-07-05  Grand Slam  Outdoor   Grass
#
#        Round  Best of       Winner          Loser  WRank LRank   W1   L1   W2  \
# 0  3rd Round      5.0     Cilic M.       Munar J.   83.0    55  6.0  3.0  3.0
# 1  3rd Round      5.0    Sinner J.    Martinez P.    1.0    52  6.0  1.0  6.0
# 2  3rd Round      3.0  Djokovic N.  Kecmanovic M.    6.0    49  6.0  3.0  6.0
# 3  3rd Round      5.0  Dimitrov G.       Ofner S.   21.0   165  6.0  3.0  6.0
# 4  3rd Round      5.0   Shelton B.   Fucsovics M.   10.0   105  6.0  3.0  7.0
#
#     L2   W3   L3   W4   L4  W5  L5  Wsets  Lsets    Comment  CBW  CBL  GBW  \
# 0  6.0  6.0  2.0  6.0  4.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN
# 1  3.0  6.0  1.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN
# 2  0.0  6.0  4.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN
# 3  4.0  7.0  6.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN
# 4  6.0  6.0  2.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN
#
#    GBL  IWW  IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW    PSL  \
# 0  NaN  NaN  NaN  NaN  NaN   1.53   2.50   NaN   NaN  NaN  NaN  1.58   2.55
# 1  NaN  NaN  NaN  NaN  NaN   1.01  19.00   NaN   NaN  NaN  NaN  1.01  41.19
# 2  NaN  NaN  NaN  NaN  NaN   1.04   9.50   NaN   NaN  NaN  NaN  1.05  15.38
# 3  NaN  NaN  NaN  NaN  NaN   1.29   3.75   NaN   NaN  NaN  NaN  1.31   3.83
# 4  NaN  NaN  NaN  NaN  NaN   1.30   3.60   NaN   NaN  NaN  NaN  1.32   3.77
#
#       WPts    LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW   MaxL  AvgW   AvgL  \
# 0    722.0  1012.0  NaN  NaN  NaN  NaN  NaN  NaN  1.61   2.62  1.54   2.46
# 1  10430.0  1030.0  NaN  NaN  NaN  NaN  NaN  NaN  1.01  75.00  1.01  28.17
# 2   4630.0  1106.0  NaN  NaN  NaN  NaN  NaN  NaN  1.05  19.50  1.03  13.67
# 3   2155.0   343.0  NaN  NaN  NaN  NaN  NaN  NaN  1.33   3.90  1.29   3.63
# 4   3130.0   564.0  NaN  NaN  NaN  NaN  NaN  NaN  1.33   4.00  1.29   3.60
#
#    BFEW  BFEL  MaxWin  MaxLoss  AvgWin  AvgLoss       PlayerA        PlayerB  \
# 0   NaN   NaN    1.58     2.55   1.555    2.525      Cilic M.       Munar J.
# 1   NaN   NaN    1.01    41.19   1.010   30.095   Martinez P.      Sinner J.
# 2   NaN   NaN    1.05    15.38   1.045   12.440   Djokovic N.  Kecmanovic M.
# 3   NaN   NaN    1.31     3.83   1.300    3.790   Dimitrov G.       Ofner S.
# 4   NaN   NaN    1.32     3.77   1.310    3.685  Fucsovics M.     Shelton B.
#
#    RankA  RankB  RankDiff  WinnerBinary  MaxOddsPlayerA  MaxOddsPlayerB  \
# 0   83.0   55.0      28.0             1            1.61            2.62
# 1   52.0    1.0      51.0             0           75.00            1.01
# 2    6.0   49.0     -43.0             1            1.05           19.50
# 3   21.0  165.0    -144.0             1            1.33            3.90
# 4  105.0   10.0      95.0             0            4.00            1.33
#
#    AvgOddsPlayerA  AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  H2H_Diff  WinsA  \
# 0            1.54            2.46           3           0         3    555
# 1           28.17            1.01           0           2        -2     81
# 2            1.03           13.67           4           0         4   1091
# 3            1.29            3.63           1           0         1    467
# 4            3.60            1.29           0           1        -1    148
#
#    LossesA  WinsB  LossesB  WinRateA_cum  WinRateB_cum  Form10A  Form10B  \
# 0      323    106      142      0.714286      0.315789      0.7      0.5
# 1      107    270       86      0.357143      0.705882      0.3      0.8
# 2      215    154      155      0.868613      0.472222      0.8      0.6
# 3      296     48       53      0.600000      0.500000      0.7      0.6
# 4      156     91       65      0.512821      0.500000      0.6      0.6
#
#    RestDaysA  RestDaysB    DiffWR  DiffForm  DiffRest  LogRankDiff  H2HDiff  \
# 0          2          2  0.398496       0.2         0     0.411507        3
# 1          2          2 -0.348739      -0.5         0     3.951244       -2
# 2          2          2  0.396391       0.2         0    -2.100061        4
# 3          2          2  0.100000       0.1         0    -2.061423        1
# 4          1          1  0.012821       0.0         0     2.351375       -1
#
#    ProbA_odds  ProbB_odds  OddsProbDiff  WinRateA_x_Rank  WinRateB_x_Rank  \
# 0    0.621118    0.381679      0.239439         0.008606         0.005742
# 1    0.013333    0.990099     -0.976766         0.006868         0.705882
# 2    0.952381    0.051282      0.901099         0.144769         0.009637
# 3    0.751880    0.256410      0.495469         0.028571         0.003030
# 4    0.250000    0.751880     -0.501880         0.004884         0.050000
#
#    EfficiencyDiff
# 0        0.002864
# 1       -0.699014
# 2        0.135132
# 3        0.025541
# 4       -0.045116

# %%
features = [
    'LogRankDiff',      # ranking
    'DiffWR',           # diferencia de winrate históric en herva
    'DiffForm',         # últims 10
    'H2HDiff',          # head-to-head
    'OddsProbDiff',     # diferencia de probabilitat implícita de quotas
    'DiffRest',         # dies de rest
    'EfficiencyDiff',   # winrate / rank → jugador que rendeix per sobre del seu ranking
    'RankDiff'          # diferencia de ranking
]

X_train = train_fourth_round[features].fillna(0)
X_test = fourth_round[features].fillna(0)
y_train = train_fourth_round['WinnerBinary']
y_test = fourth_round['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = XGBClassifier(
    n_estimators=500,                    # Nombre total d'arbres (boosting rounds) que es construiran. 500 és un valor força alt, bo per a un bon rendiment si es controla l'overfitting.
    max_depth=6,                         # Profunditat màxima de cada arbre. 6 és un valor moderat: permet interaccions complexes sense fer els arbres excessivament profunds.
    learning_rate=0.02,                  # Taxa d'aprenentatge (eta). 0.02 és bastant baixa → aprenentatge lent i estable, ideal quan tens molts estimators (500).
    subsample=0.85,                      # Percentatge de mostres (files) que s'utilitzen per entrenar cada arbre. 0.85 = 85% → ajuda a reduir overfitting i afegeix variància (com bagging).
    colsample_bytree=0.85,               # Percentatge de columnes (variables) que s'agafen aleatòriament per cada arbre. 85% → també redueix overfitting i millora la generalització.
    min_child_weight=5,                  # Suma mínima del pes Hessiana en un node fill. Valors >1 fan el model més conservador: evita dividir nodes amb poca informació.
    gamma=0.1,                           # Minimització mínima de la funció de pèrdua necessària per fer una partició addicional (regularització per poda). 0.1 afavoreix arbres més simples.
    reg_alpha=0.1,                       # Terme de regularització L1 sobre els pesos de les fulles. Ajuda a fer sparseness i és útil quan hi ha moltes variables irrellevants.
    reg_lambda=1.0,                      # Terme de regularització L2 (més suau que L1). 1.0 és el valor per defecte i sol funcionar bé en la majoria de casos.
    random_state=42,                     # Llavor per a la reproductibilitat dels resultats (aleatorietat controlada).
    n_jobs=-1,                           # Utilitza tots els nuclis disponibles del processador per entrenar en paral·lel → molt més ràpid.
    eval_metric='logloss'                # Mètrica d'avaluació durant l'entrenament (per classificació binària/multiclasse). 'logloss' = logarithmic loss (cross-entropy).
)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 0.8750
# Brier Score: 0.1017
#               precision    recall  f1-score   support
#
#            0     1.0000    0.7500    0.8571         4
#            1     0.8000    1.0000    0.8889         4
#
#     accuracy                         0.8750         8
#    macro avg     0.9000    0.8750    0.8730         8
# weighted avg     0.9000    0.8750    0.8730         8
#
# ================================================================================

# %%
# Resultados detallados por fila
results_df = fourth_round[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary']].copy()
results_df['Predicted'] = pred
results_df['Probability'] = prob
results_df['Correct'] = (results_df['WinnerBinary'] == results_df['Predicted'])
results_df['Result'] = results_df['Correct'].map({True: '✓ Correct', False: '✗ Failed'})

# Mostrar resultados
print("RESULTADOS DETALLADOS POR FILA:")
print("="*100)
print(f"\nTotal de predicciones: {len(results_df)}")
print(f"Correctas: {results_df['Correct'].sum()} ({results_df['Correct'].mean()*100:.2f}%)")
print(f"Fallidas: {(~results_df['Correct']).sum()} ({(~results_df['Correct']).mean()*100:.2f}%)")
print("\n" + "="*100 + "\n")

# Mostrar todas las filas
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_columns', None)

display(results_df[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary', 'Predicted', 'Probability', 'Result']])

# Mostrar solo las fallidas para análisis
print("\n" + "="*100)
print("PREDICCIONES FALLIDAS:")
print("="*100)
failed = results_df[~results_df['Correct']]
if len(failed) > 0:
    display(failed[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary', 'Predicted', 'Probability']])
else:
    print("¡Todas las predicciones fueron correctas!")
# Out:
# RESULTADOS DETALLADOS POR FILA:
# ====================================================================================================
#
# Total de predicciones: 8
# Correctas: 7 (87.50%)
# Fallidas: 1 (12.50%)
#
# ====================================================================================================
#           Date       PlayerA       PlayerB  WinnerBinary  Predicted  \
# 7   2025-07-07  De Minaur A.   Djokovic N.             0          0
# 8   2025-07-07   Dimitrov G.     Sinner J.             0          0
# 9   2025-07-07    Shelton B.     Sonego L.             1          1
# 10  2025-07-07      Cilic M.    Cobolli F.             0          0
# 11  2025-07-06    Alcaraz C.     Rublev A.             1          1
# 12  2025-07-06  Khachanov K.  Majchrzak K.             1          1
# 13  2025-07-06      Jarry N.     Norrie C.             0          1
# 14  2025-07-06      Fritz T.   Thompson J.             1          1
#
#     Probability     Result
# 7      0.150399  ✓ Correct
# 8      0.043126  ✓ Correct
# 9      0.830942  ✓ Correct
# 10     0.271889  ✓ Correct
# 11     0.962177  ✓ Correct
# 12     0.857474  ✓ Correct
# 13     0.807548   ✗ Failed
# 14     0.885918  ✓ Correct
# ====================================================================================================
# PREDICCIONES FALLIDAS:
# ====================================================================================================
#           Date   PlayerA    PlayerB  WinnerBinary  Predicted  Probability
# 13  2025-07-06  Jarry N.  Norrie C.             0          1     0.807548

# %% [markdown]
# #### Quarts de final

# %%
# Actualizar el conjunto de entrenamiento: añadir first_round al train actual
train_quarter_finals = pd.concat([fourth_round, train_fourth_round], ignore_index=True)

print(f"Tamaño del train original: {len(train_quarter_finals) - len(fourth_round)}")
print(f"Tamaño de first_round añadido: {len(fourth_round)}")
print(f"Tamaño del nuevo train: {len(train_quarter_finals)}")
print(f"\nTrain actualizado correctamente. Listo para la siguiente fase.")

train_quarter_finals.head()
# Out:
# Tamaño del train original: 7719
# Tamaño de first_round añadido: 8
# Tamaño del nuevo train: 7727
#
# Train actualizado correctamente. Listo para la siguiente fase.
#    ATP Location Tournament        Date      Series    Court Surface  \
# 0   36   London  Wimbledon  2025-07-07  Grand Slam  Outdoor   Grass
# 1   36   London  Wimbledon  2025-07-07  Grand Slam  Outdoor   Grass
# 2   36   London  Wimbledon  2025-07-07  Grand Slam  Outdoor   Grass
# 3   36   London  Wimbledon  2025-07-07  Grand Slam  Outdoor   Grass
# 4   36   London  Wimbledon  2025-07-06  Grand Slam  Outdoor   Grass
#
#        Round  Best of       Winner         Loser  WRank LRank   W1   L1   W2  \
# 0  4th Round      5.0  Djokovic N.  De Minaur A.    6.0    11  1.0  6.0  6.0
# 1  4th Round      5.0    Sinner J.   Dimitrov G.    1.0    21  3.0  6.0  5.0
# 2  4th Round      5.0   Shelton B.     Sonego L.   10.0    47  3.0  6.0  6.0
# 3  4th Round      5.0   Cobolli F.      Cilic M.   24.0    83  6.0  4.0  6.0
# 4  4th Round      5.0   Alcaraz C.     Rublev A.    2.0    14  6.0  7.0  6.0
#
#     L2   W3   L3   W4   L4  W5  L5  Wsets  Lsets    Comment  CBW  CBL  GBW  \
# 0  4.0  6.0  4.0  6.0  4.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN
# 1  7.0  2.0  2.0  NaN  NaN NaN NaN    0.0    2.0    Retired  NaN  NaN  NaN
# 2  1.0  7.0  6.0  7.0  5.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN
# 3  4.0  6.0  7.0  7.0  6.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN
# 4  3.0  6.0  4.0  6.0  4.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN
#
#    GBL  IWW  IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW    PSL  \
# 0  NaN  NaN  NaN  NaN  NaN   1.17   5.00   NaN   NaN  NaN  NaN  1.20   5.22
# 1  NaN  NaN  NaN  NaN  NaN   1.03  13.00   NaN   NaN  NaN  NaN  1.03  18.06
# 2  NaN  NaN  NaN  NaN  NaN   1.29   3.75   NaN   NaN  NaN  NaN  1.32   3.76
# 3  NaN  NaN  NaN  NaN  NaN   1.83   2.00   NaN   NaN  NaN  NaN  1.88   2.03
# 4  NaN  NaN  NaN  NaN  NaN   1.08   7.00   NaN   NaN  NaN  NaN  1.10   8.57
#
#       WPts    LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW   MaxL  AvgW   AvgL  \
# 0   4630.0  3085.0  NaN  NaN  NaN  NaN  NaN  NaN  1.20   5.90  1.17   5.04
# 1  10430.0  2155.0  NaN  NaN  NaN  NaN  NaN  NaN  1.05  18.06  1.03  13.83
# 2   3130.0  1171.0  NaN  NaN  NaN  NaN  NaN  NaN  1.32   4.30  1.27   3.76
# 3   2035.0   722.0  NaN  NaN  NaN  NaN  NaN  NaN  1.89   2.10  1.79   2.01
# 4   9300.0  2920.0  NaN  NaN  NaN  NaN  NaN  NaN  1.11   9.40  1.09   7.50
#
#    BFEW  BFEL  MaxWin  MaxLoss  AvgWin  AvgLoss       PlayerA      PlayerB  \
# 0   NaN   NaN    1.20     5.22   1.185    5.110  De Minaur A.  Djokovic N.
# 1   NaN   NaN    1.03    18.06   1.030   15.530   Dimitrov G.    Sinner J.
# 2   NaN   NaN    1.32     3.76   1.305    3.755    Shelton B.    Sonego L.
# 3   NaN   NaN    1.88     2.03   1.855    2.015      Cilic M.   Cobolli F.
# 4   NaN   NaN    1.10     8.57   1.090    7.785    Alcaraz C.    Rublev A.
#
#    RankA  RankB  RankDiff  WinnerBinary  MaxOddsPlayerA  MaxOddsPlayerB  \
# 0   11.0    6.0       5.0             0            5.90            1.20
# 1   21.0    1.0      20.0             0           18.06            1.05
# 2   10.0   47.0     -37.0             1            1.32            4.30
# 3   83.0   24.0      59.0             0            2.10            1.89
# 4    2.0   14.0     -12.0             1            1.11            9.40
#
#    AvgOddsPlayerA  AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  H2H_Diff  WinsA  \
# 0            5.04            1.17           0           4        -4    250
# 1           13.83            1.03           1           5        -4    468
# 2            1.27            3.76           4           1         3     92
# 3            2.01            1.79           0           3        -3    556
# 4            1.09            7.50           4           1         3    237
#
#    LossesA  WinsB  LossesB  WinRateA_cum  WinRateB_cum  Form10A  Form10B  \
# 0      149   1092      215      0.654545      0.869565      0.7      0.9
# 1      296    271       86      0.604938      0.714286      0.7      0.8
# 2       65    151      165      0.523810      0.565217      0.6      0.6
# 3      323     58       49      0.716814      0.571429      0.8      0.6
# 4       59    337      188      0.914286      0.676471      1.0      0.6
#
#    RestDaysA  RestDaysB    DiffWR  DiffForm  DiffRest  LogRankDiff  H2HDiff  \
# 0          2          2 -0.215020      -0.2         0     0.606136       -4
# 1          2          2 -0.109347      -0.1         0     3.044522       -4
# 2          2          2 -0.041408       0.0         0    -1.547563        3
# 3          2          2  0.145386       0.2         0     1.240787       -3
# 4          2          2  0.237815       0.4         0    -1.945910        3
#
#    ProbA_odds  ProbB_odds  OddsProbDiff  WinRateA_x_Rank  WinRateB_x_Rank  \
# 0    0.169492    0.833333     -0.663842         0.059504         0.144928
# 1    0.055371    0.952381     -0.897010         0.028807         0.714286
# 2    0.757576    0.232558      0.525018         0.052381         0.012026
# 3    0.476190    0.529101     -0.052910         0.008636         0.023810
# 4    0.900901    0.106383      0.794518         0.457143         0.048319
#
#    EfficiencyDiff
# 0       -0.085423
# 1       -0.685479
# 2        0.040355
# 3       -0.015173
# 4        0.408824

# %%
features = [
    'LogRankDiff',      # ranking
    'DiffWR',           # diferencia de winrate históric en herva
    'DiffForm',         # últims 10
    'H2HDiff',          # head-to-head
    'OddsProbDiff',     # diferencia de probabilitat implícita de quotas
    'DiffRest',         # dies de rest
    'EfficiencyDiff',   # winrate / rank → jugador que rendeix per sobre del seu ranking
    'RankDiff'          # diferencia de ranking
]

X_train = train_quarter_finals[features].fillna(0)
X_test = quarter_finals[features].fillna(0)
y_train = train_quarter_finals['WinnerBinary']
y_test = quarter_finals['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = XGBClassifier(
    n_estimators=500,                    # Nombre total d'arbres (boosting rounds) que es construiran. 500 és un valor força alt, bo per a un bon rendiment si es controla l'overfitting.
    max_depth=6,                         # Profunditat màxima de cada arbre. 6 és un valor moderat: permet interaccions complexes sense fer els arbres excessivament profunds.
    learning_rate=0.02,                  # Taxa d'aprenentatge (eta). 0.02 és bastant baixa → aprenentatge lent i estable, ideal quan tens molts estimators (500).
    subsample=0.85,                      # Percentatge de mostres (files) que s'utilitzen per entrenar cada arbre. 0.85 = 85% → ajuda a reduir overfitting i afegeix variància (com bagging).
    colsample_bytree=0.85,               # Percentatge de columnes (variables) que s'agafen aleatòriament per cada arbre. 85% → també redueix overfitting i millora la generalització.
    min_child_weight=5,                  # Suma mínima del pes Hessiana en un node fill. Valors >1 fan el model més conservador: evita dividir nodes amb poca informació.
    gamma=0.1,                           # Minimització mínima de la funció de pèrdua necessària per fer una partició addicional (regularització per poda). 0.1 afavoreix arbres més simples.
    reg_alpha=0.1,                       # Terme de regularització L1 sobre els pesos de les fulles. Ajuda a fer sparseness i és útil quan hi ha moltes variables irrellevants.
    reg_lambda=1.0,                      # Terme de regularització L2 (més suau que L1). 1.0 és el valor per defecte i sol funcionar bé en la majoria de casos.
    random_state=42,                     # Llavor per a la reproductibilitat dels resultats (aleatorietat controlada).
    n_jobs=-1,                           # Utilitza tots els nuclis disponibles del processador per entrenar en paral·lel → molt més ràpid.
    eval_metric='logloss'                # Mètrica d'avaluació durant l'entrenament (per classificació binària/multiclasse). 'logloss' = logarithmic loss (cross-entropy).
)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 1.0000
# Brier Score: 0.0312
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000         2
#            1     1.0000    1.0000    1.0000         2
#
#     accuracy                         1.0000         4
#    macro avg     1.0000    1.0000    1.0000         4
# weighted avg     1.0000    1.0000    1.0000         4
#
# ================================================================================

# %%
# Resultados detallados por fila
results_df = quarter_finals[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary']].copy()
results_df['Predicted'] = pred
results_df['Probability'] = prob
results_df['Correct'] = (results_df['WinnerBinary'] == results_df['Predicted'])
results_df['Result'] = results_df['Correct'].map({True: '✓ Correct', False: '✗ Failed'})

# Mostrar resultados
print("RESULTADOS DETALLADOS POR FILA:")
print("="*100)
print(f"\nTotal de predicciones: {len(results_df)}")
print(f"Correctas: {results_df['Correct'].sum()} ({results_df['Correct'].mean()*100:.2f}%)")
print(f"Fallidas: {(~results_df['Correct']).sum()} ({(~results_df['Correct']).mean()*100:.2f}%)")
print("\n" + "="*100 + "\n")

# Mostrar todas las filas
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_columns', None)

display(results_df[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary', 'Predicted', 'Probability', 'Result']])

# Mostrar solo las fallidas para análisis
print("\n" + "="*100)
print("PREDICCIONES FALLIDAS:")
print("="*100)
failed = results_df[~results_df['Correct']]
if len(failed) > 0:
    display(failed[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary', 'Predicted', 'Probability']])
else:
    print("¡Todas las predicciones fueron correctas!")
# Out:
# RESULTADOS DETALLADOS POR FILA:
# ====================================================================================================
#
# Total de predicciones: 4
# Correctas: 4 (100.00%)
# Fallidas: 0 (0.00%)
#
# ====================================================================================================
#          Date     PlayerA       PlayerB  WinnerBinary  Predicted  Probability  \
# 3  2025-07-09  Shelton B.     Sinner J.             0          0     0.161485
# 4  2025-07-09  Cobolli F.   Djokovic N.             0          0     0.058012
# 5  2025-07-08    Fritz T.  Khachanov K.             1          1     0.691984
# 6  2025-07-08  Alcaraz C.     Norrie C.             1          1     0.980101
#
#       Result
# 3  ✓ Correct
# 4  ✓ Correct
# 5  ✓ Correct
# 6  ✓ Correct
# ====================================================================================================
# PREDICCIONES FALLIDAS:
# ====================================================================================================
# ¡Todas las predicciones fueron correctas!

# %% [markdown]
# #### Semifinals

# %%
# Actualizar el conjunto de entrenamiento: añadir first_round al train actual
train_semi_finals = pd.concat([quarter_finals, train_quarter_finals], ignore_index=True)

print(f"Tamaño del train original: {len(train_semi_finals) - len(quarter_finals)}")
print(f"Tamaño de first_round añadido: {len(quarter_finals)}")
print(f"Tamaño del nuevo train: {len(train_semi_finals)}")
print(f"\nTrain actualizado correctamente. Listo para la siguiente fase.")

train_semi_finals.head()
# Out:
# Tamaño del train original: 7727
# Tamaño de first_round añadido: 4
# Tamaño del nuevo train: 7731
#
# Train actualizado correctamente. Listo para la siguiente fase.
#    ATP Location Tournament        Date      Series    Court Surface  \
# 0   36   London  Wimbledon  2025-07-09  Grand Slam  Outdoor   Grass
# 1   36   London  Wimbledon  2025-07-09  Grand Slam  Outdoor   Grass
# 2   36   London  Wimbledon  2025-07-08  Grand Slam  Outdoor   Grass
# 3   36   London  Wimbledon  2025-07-08  Grand Slam  Outdoor   Grass
# 4   36   London  Wimbledon  2025-07-07  Grand Slam  Outdoor   Grass
#
#            Round  Best of       Winner         Loser  WRank LRank   W1   L1  \
# 0  Quarterfinals      5.0    Sinner J.    Shelton B.    1.0    10  7.0  6.0
# 1  Quarterfinals      5.0  Djokovic N.    Cobolli F.    6.0    24  6.0  7.0
# 2  Quarterfinals      5.0     Fritz T.  Khachanov K.    5.0    20  6.0  3.0
# 3  Quarterfinals      5.0   Alcaraz C.     Norrie C.    2.0    61  6.0  2.0
# 4      4th Round      5.0  Djokovic N.  De Minaur A.    6.0    11  1.0  6.0
#
#     W2   L2   W3   L3   W4   L4  W5  L5  Wsets  Lsets    Comment  CBW  CBL  \
# 0  6.0  4.0  6.0  4.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN
# 1  6.0  2.0  7.0  5.0  6.0  4.0 NaN NaN    3.0    1.0  Completed  NaN  NaN
# 2  6.0  4.0  1.0  6.0  7.0  6.0 NaN NaN    3.0    1.0  Completed  NaN  NaN
# 3  6.0  3.0  6.0  3.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN
# 4  6.0  4.0  6.0  4.0  6.0  4.0 NaN NaN    3.0    1.0  Completed  NaN  NaN
#
#    GBW  GBL  IWW  IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW  \
# 0  NaN  NaN  NaN  NaN  NaN  NaN   1.25   3.60   NaN   NaN  NaN  NaN  1.32
# 1  NaN  NaN  NaN  NaN  NaN  NaN   1.10   7.00   NaN   NaN  NaN  NaN  1.11
# 2  NaN  NaN  NaN  NaN  NaN  NaN   1.29   3.75   NaN   NaN  NaN  NaN  1.29
# 3  NaN  NaN  NaN  NaN  NaN  NaN   1.06   9.00   NaN   NaN  NaN  NaN  1.07
# 4  NaN  NaN  NaN  NaN  NaN  NaN   1.17   5.00   NaN   NaN  NaN  NaN  1.20
#
#      PSL     WPts    LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW  MaxL  AvgW  \
# 0   3.60  10430.0  3130.0  NaN  NaN  NaN  NaN  NaN  NaN  1.34   3.9  1.29
# 1   8.33   4630.0  2035.0  NaN  NaN  NaN  NaN  NaN  NaN  1.12   8.6  1.09
# 2   4.06   4635.0  2240.0  NaN  NaN  NaN  NaN  NaN  NaN  1.31   4.2  1.27
# 3  10.89   9300.0   952.0  NaN  NaN  NaN  NaN  NaN  NaN  1.07  13.5  1.05
# 4   5.22   4630.0  3085.0  NaN  NaN  NaN  NaN  NaN  NaN  1.20   5.9  1.17
#
#    AvgL  BFEW  BFEL  MaxWin  MaxLoss  AvgWin  AvgLoss       PlayerA  \
# 0  3.58   NaN   NaN    1.32     3.60   1.285    3.600    Shelton B.
# 1  7.53   NaN   NaN    1.11     8.33   1.105    7.665    Cobolli F.
# 2  3.76   NaN   NaN    1.29     4.06   1.290    3.905      Fritz T.
# 3  9.96   NaN   NaN    1.07    10.89   1.065    9.945    Alcaraz C.
# 4  5.04   NaN   NaN    1.20     5.22   1.185    5.110  De Minaur A.
#
#         PlayerB  RankA  RankB  RankDiff  WinnerBinary  MaxOddsPlayerA  \
# 0     Sinner J.   10.0    1.0       9.0             0            3.90
# 1   Djokovic N.   24.0    6.0      18.0             0            8.60
# 2  Khachanov K.    5.0   20.0     -15.0             1            1.31
# 3     Norrie C.    2.0   61.0     -59.0             1            1.07
# 4   Djokovic N.   11.0    6.0       5.0             0            5.90
#
#    MaxOddsPlayerB  AvgOddsPlayerA  AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  \
# 0            1.34            3.58            1.29           1           6
# 1            1.12            7.53            1.09           0           2
# 2            4.20            1.27            3.76           1           1
# 3           13.50            1.05            9.96           5           2
# 4            1.20            5.04            1.17           0           4
#
#    H2H_Diff  WinsA  LossesA  WinsB  LossesB  WinRateA_cum  WinRateB_cum  \
# 0        -5     93       65    272       86      0.545455      0.722222
# 1        -2     59       49   1093      215      0.600000      0.870504
# 2         0    288      189    287      205      0.652174      0.653061
# 3         3    238       59    216      156      0.916667      0.553191
# 4        -4    250      149   1092      215      0.654545      0.869565
#
#    Form10A  Form10B  RestDaysA  RestDaysB    DiffWR  DiffForm  DiffRest  \
# 0      0.6      0.8          2          2 -0.176768      -0.2         0
# 1      0.7      0.9          2          2 -0.270504      -0.2         0
# 2      0.9      0.8          2          2 -0.000887       0.1         0
# 3      1.0      0.6          2          2  0.363475       0.4         0
# 4      0.7      0.9          2          2 -0.215020      -0.2         0
#
#    LogRankDiff  H2HDiff  ProbA_odds  ProbB_odds  OddsProbDiff  \
# 0     2.302585       -5    0.256410    0.746269     -0.489858
# 1     1.386294       -2    0.116279    0.892857     -0.776578
# 2    -1.386294        0    0.763359    0.238095      0.525264
# 3    -3.417727        3    0.934579    0.074074      0.860505
# 4     0.606136       -4    0.169492    0.833333     -0.663842
#
#    WinRateA_x_Rank  WinRateB_x_Rank  EfficiencyDiff
# 0         0.054545         0.722222       -0.667677
# 1         0.025000         0.145084       -0.120084
# 2         0.130435         0.032653        0.097782
# 3         0.458333         0.009069        0.449265
# 4         0.059504         0.144928       -0.085423

# %%
features = [
    'LogRankDiff',      # ranking
    'DiffWR',           # diferencia de winrate históric en herva
    'DiffForm',         # últims 10
    'H2HDiff',          # head-to-head
    'OddsProbDiff',     # diferencia de probabilitat implícita de quotas
    'DiffRest',         # dies de rest
    'EfficiencyDiff',   # winrate / rank → jugador que rendeix per sobre del seu ranking
    'RankDiff'          # diferencia de ranking
]

X_train = train_semi_finals[features].fillna(0)
X_test = semi_finals[features].fillna(0)
y_train = train_semi_finals['WinnerBinary']
y_test = semi_finals['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = XGBClassifier(
    n_estimators=500,                    # Nombre total d'arbres (boosting rounds) que es construiran. 500 és un valor força alt, bo per a un bon rendiment si es controla l'overfitting.
    max_depth=6,                         # Profunditat màxima de cada arbre. 6 és un valor moderat: permet interaccions complexes sense fer els arbres excessivament profunds.
    learning_rate=0.02,                  # Taxa d'aprenentatge (eta). 0.02 és bastant baixa → aprenentatge lent i estable, ideal quan tens molts estimators (500).
    subsample=0.85,                      # Percentatge de mostres (files) que s'utilitzen per entrenar cada arbre. 0.85 = 85% → ajuda a reduir overfitting i afegeix variància (com bagging).
    colsample_bytree=0.85,               # Percentatge de columnes (variables) que s'agafen aleatòriament per cada arbre. 85% → també redueix overfitting i millora la generalització.
    min_child_weight=5,                  # Suma mínima del pes Hessiana en un node fill. Valors >1 fan el model més conservador: evita dividir nodes amb poca informació.
    gamma=0.1,                           # Minimització mínima de la funció de pèrdua necessària per fer una partició addicional (regularització per poda). 0.1 afavoreix arbres més simples.
    reg_alpha=0.1,                       # Terme de regularització L1 sobre els pesos de les fulles. Ajuda a fer sparseness i és útil quan hi ha moltes variables irrellevants.
    reg_lambda=1.0,                      # Terme de regularització L2 (més suau que L1). 1.0 és el valor per defecte i sol funcionar bé en la majoria de casos.
    random_state=42,                     # Llavor per a la reproductibilitat dels resultats (aleatorietat controlada).
    n_jobs=-1,                           # Utilitza tots els nuclis disponibles del processador per entrenar en paral·lel → molt més ràpid.
    eval_metric='logloss'                # Mètrica d'avaluació durant l'entrenament (per classificació binària/multiclasse). 'logloss' = logarithmic loss (cross-entropy).
)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 1.0000
# Brier Score: 0.1061
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000         1
#            1     1.0000    1.0000    1.0000         1
#
#     accuracy                         1.0000         2
#    macro avg     1.0000    1.0000    1.0000         2
# weighted avg     1.0000    1.0000    1.0000         2
#
# ================================================================================

# %%
# Resultados detallados por fila
results_df = semi_finals[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary']].copy()
results_df['Predicted'] = pred
results_df['Probability'] = prob
results_df['Correct'] = (results_df['WinnerBinary'] == results_df['Predicted'])
results_df['Result'] = results_df['Correct'].map({True: '✓ Correct', False: '✗ Failed'})

# Mostrar resultados
print("RESULTADOS DETALLADOS POR FILA:")
print("="*100)
print(f"\nTotal de predicciones: {len(results_df)}")
print(f"Correctas: {results_df['Correct'].sum()} ({results_df['Correct'].mean()*100:.2f}%)")
print(f"Fallidas: {(~results_df['Correct']).sum()} ({(~results_df['Correct']).mean()*100:.2f}%)")
print("\n" + "="*100 + "\n")

# Mostrar todas las filas
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_columns', None)

display(results_df[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary', 'Predicted', 'Probability', 'Result']])

# Mostrar solo las fallidas para análisis
print("\n" + "="*100)
print("PREDICCIONES FALLIDAS:")
print("="*100)
failed = results_df[~results_df['Correct']]
if len(failed) > 0:
    display(failed[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary', 'Predicted', 'Probability']])
else:
    print("¡Todas las predicciones fueron correctas!")
# Out:
# RESULTADOS DETALLADOS POR FILA:
# ====================================================================================================
#
# Total de predicciones: 2
# Correctas: 2 (100.00%)
# Fallidas: 0 (0.00%)
#
# ====================================================================================================
#          Date      PlayerA    PlayerB  WinnerBinary  Predicted  Probability  \
# 1  2025-07-11   Alcaraz C.   Fritz T.             1          1     0.905119
# 2  2025-07-11  Djokovic N.  Sinner J.             0          0     0.450797
#
#       Result
# 1  ✓ Correct
# 2  ✓ Correct
# ====================================================================================================
# PREDICCIONES FALLIDAS:
# ====================================================================================================
# ¡Todas las predicciones fueron correctas!

# %% [markdown]
# #### Final

# %%
# Actualizar el conjunto de entrenamiento: añadir first_round al train actual
train_final = pd.concat([semi_finals, train_semi_finals], ignore_index=True)

print(f"Tamaño del train original: {len(train_final) - len(train_semi_finals)}")
print(f"Tamaño de first_round añadido: {len(train_semi_finals)}")
print(f"Tamaño del nuevo train: {len(train_final)}")
print(f"\nTrain actualizado correctamente. Listo para la siguiente fase.")

train_final.head()
# Out:
# Tamaño del train original: 2
# Tamaño de first_round añadido: 7731
# Tamaño del nuevo train: 7733
#
# Train actualizado correctamente. Listo para la siguiente fase.
#    ATP Location Tournament        Date      Series    Court Surface  \
# 0   36   London  Wimbledon  2025-07-11  Grand Slam  Outdoor   Grass
# 1   36   London  Wimbledon  2025-07-11  Grand Slam  Outdoor   Grass
# 2   36   London  Wimbledon  2025-07-09  Grand Slam  Outdoor   Grass
# 3   36   London  Wimbledon  2025-07-09  Grand Slam  Outdoor   Grass
# 4   36   London  Wimbledon  2025-07-08  Grand Slam  Outdoor   Grass
#
#            Round  Best of       Winner         Loser  WRank LRank   W1   L1  \
# 0     Semifinals      5.0   Alcaraz C.      Fritz T.    2.0     5  6.0  4.0
# 1     Semifinals      5.0    Sinner J.   Djokovic N.    1.0     6  6.0  3.0
# 2  Quarterfinals      5.0    Sinner J.    Shelton B.    1.0    10  7.0  6.0
# 3  Quarterfinals      5.0  Djokovic N.    Cobolli F.    6.0    24  6.0  7.0
# 4  Quarterfinals      5.0     Fritz T.  Khachanov K.    5.0    20  6.0  3.0
#
#     W2   L2   W3   L3   W4   L4  W5  L5  Wsets  Lsets    Comment  CBW  CBL  \
# 0  5.0  7.0  6.0  3.0  7.0  6.0 NaN NaN    3.0    1.0  Completed  NaN  NaN
# 1  6.0  3.0  6.0  4.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN
# 2  6.0  4.0  6.0  4.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN
# 3  6.0  2.0  7.0  5.0  6.0  4.0 NaN NaN    3.0    1.0  Completed  NaN  NaN
# 4  6.0  4.0  1.0  6.0  7.0  6.0 NaN NaN    3.0    1.0  Completed  NaN  NaN
#
#    GBW  GBL  IWW  IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW  \
# 0  NaN  NaN  NaN  NaN  NaN  NaN   1.17   4.75   NaN   NaN  NaN  NaN  1.20
# 1  NaN  NaN  NaN  NaN  NaN  NaN   1.40   2.80   NaN   NaN  NaN  NaN  1.47
# 2  NaN  NaN  NaN  NaN  NaN  NaN   1.25   3.60   NaN   NaN  NaN  NaN  1.32
# 3  NaN  NaN  NaN  NaN  NaN  NaN   1.10   7.00   NaN   NaN  NaN  NaN  1.11
# 4  NaN  NaN  NaN  NaN  NaN  NaN   1.29   3.75   NaN   NaN  NaN  NaN  1.29
#
#     PSL     WPts    LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW  MaxL  AvgW  \
# 0  5.13   9300.0  4635.0  NaN  NaN  NaN  NaN  NaN  NaN  1.24  5.25  1.17
# 1  2.93  10430.0  4630.0  NaN  NaN  NaN  NaN  NaN  NaN  1.47  3.05  1.42
# 2  3.60  10430.0  3130.0  NaN  NaN  NaN  NaN  NaN  NaN  1.34  3.90  1.29
# 3  8.33   4630.0  2035.0  NaN  NaN  NaN  NaN  NaN  NaN  1.12  8.60  1.09
# 4  4.06   4635.0  2240.0  NaN  NaN  NaN  NaN  NaN  NaN  1.31  4.20  1.27
#
#    AvgL  BFEW  BFEL  MaxWin  MaxLoss  AvgWin  AvgLoss      PlayerA  \
# 0  4.98   NaN   NaN    1.20     5.13   1.185    4.940   Alcaraz C.
# 1  2.85   NaN   NaN    1.47     2.93   1.435    2.865  Djokovic N.
# 2  3.58   NaN   NaN    1.32     3.60   1.285    3.600   Shelton B.
# 3  7.53   NaN   NaN    1.11     8.33   1.105    7.665   Cobolli F.
# 4  3.76   NaN   NaN    1.29     4.06   1.290    3.905     Fritz T.
#
#         PlayerB  RankA  RankB  RankDiff  WinnerBinary  MaxOddsPlayerA  \
# 0      Fritz T.    2.0    5.0      -3.0             1            1.24
# 1     Sinner J.    6.0    1.0       5.0             0            3.05
# 2     Sinner J.   10.0    1.0       9.0             0            3.90
# 3   Djokovic N.   24.0    6.0      18.0             0            8.60
# 4  Khachanov K.    5.0   20.0     -15.0             1            1.31
#
#    MaxOddsPlayerB  AvgOddsPlayerA  AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  \
# 0            5.25            1.17            4.98           3           0
# 1            1.47            2.85            1.42           4           5
# 2            1.34            3.58            1.29           1           6
# 3            1.12            7.53            1.09           0           2
# 4            4.20            1.27            3.76           1           1
#
#    H2H_Diff  WinsA  LossesA  WinsB  LossesB  WinRateA_cum  WinRateB_cum  \
# 0         3    239       59    289      189      0.918919      0.657143
# 1        -1   1094      215    273       86      0.871429      0.729730
# 2        -5     93       65    272       86      0.545455      0.722222
# 3        -2     59       49   1093      215      0.600000      0.870504
# 4         0    288      189    287      205      0.652174      0.653061
#
#    Form10A  Form10B  RestDaysA  RestDaysB    DiffWR  DiffForm  DiffRest  \
# 0      1.0      0.9          3          3  0.261776       0.1         0
# 1      0.9      0.8          2          2  0.141699       0.1         0
# 2      0.6      0.8          2          2 -0.176768      -0.2         0
# 3      0.7      0.9          2          2 -0.270504      -0.2         0
# 4      0.9      0.8          2          2 -0.000887       0.1         0
#
#    LogRankDiff  H2HDiff  ProbA_odds  ProbB_odds  OddsProbDiff  \
# 0    -0.916291        3    0.806452    0.190476      0.615975
# 1     1.791759       -1    0.327869    0.680272     -0.352403
# 2     2.302585       -5    0.256410    0.746269     -0.489858
# 3     1.386294       -2    0.116279    0.892857     -0.776578
# 4    -1.386294        0    0.763359    0.238095      0.525264
#
#    WinRateA_x_Rank  WinRateB_x_Rank  EfficiencyDiff
# 0         0.459459         0.131429        0.328031
# 1         0.145238         0.729730       -0.584492
# 2         0.054545         0.722222       -0.667677
# 3         0.025000         0.145084       -0.120084
# 4         0.130435         0.032653        0.097782

# %%
features = [
    'LogRankDiff',      # ranking
    'DiffWR',           # diferencia de winrate históric en herva
    'DiffForm',         # últims 10
    'H2HDiff',          # head-to-head
    'OddsProbDiff',     # diferencia de probabilitat implícita de quotas
    'DiffRest',         # dies de rest
    'EfficiencyDiff',   # winrate / rank → jugador que rendeix per sobre del seu ranking
    'RankDiff'          # diferencia de ranking
]

X_train = train_final[features].fillna(0)
X_test = finals[features].fillna(0)
y_train = train_final['WinnerBinary']
y_test = finals['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = XGBClassifier(
    n_estimators=500,                    # Nombre total d'arbres (boosting rounds) que es construiran. 500 és un valor força alt, bo per a un bon rendiment si es controla l'overfitting.
    max_depth=6,                         # Profunditat màxima de cada arbre. 6 és un valor moderat: permet interaccions complexes sense fer els arbres excessivament profunds.
    learning_rate=0.02,                  # Taxa d'aprenentatge (eta). 0.02 és bastant baixa → aprenentatge lent i estable, ideal quan tens molts estimators (500).
    subsample=0.85,                      # Percentatge de mostres (files) que s'utilitzen per entrenar cada arbre. 0.85 = 85% → ajuda a reduir overfitting i afegeix variància (com bagging).
    colsample_bytree=0.85,               # Percentatge de columnes (variables) que s'agafen aleatòriament per cada arbre. 85% → també redueix overfitting i millora la generalització.
    min_child_weight=5,                  # Suma mínima del pes Hessiana en un node fill. Valors >1 fan el model més conservador: evita dividir nodes amb poca informació.
    gamma=0.1,                           # Minimització mínima de la funció de pèrdua necessària per fer una partició addicional (regularització per poda). 0.1 afavoreix arbres més simples.
    reg_alpha=0.1,                       # Terme de regularització L1 sobre els pesos de les fulles. Ajuda a fer sparseness i és útil quan hi ha moltes variables irrellevants.
    reg_lambda=1.0,                      # Terme de regularització L2 (més suau que L1). 1.0 és el valor per defecte i sol funcionar bé en la majoria de casos.
    random_state=42,                     # Llavor per a la reproductibilitat dels resultats (aleatorietat controlada).
    n_jobs=-1,                           # Utilitza tots els nuclis disponibles del processador per entrenar en paral·lel → molt més ràpid.
    eval_metric='logloss'                # Mètrica d'avaluació durant l'entrenament (per classificació binària/multiclasse). 'logloss' = logarithmic loss (cross-entropy).
)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 0.0000
# Brier Score: 0.5024
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000       1.0
#            1     0.0000    0.0000    0.0000       0.0
#
#     accuracy                         0.0000       1.0
#    macro avg     0.0000    0.0000    0.0000       1.0
# weighted avg     0.0000    0.0000    0.0000       1.0
#
# ================================================================================
# c:\Users\ikerr\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ikerr\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ikerr\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ikerr\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ikerr\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ikerr\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
# Resultados detallados por fila
results_df = finals[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary']].copy()
results_df['Predicted'] = pred
results_df['Probability'] = prob
results_df['Correct'] = (results_df['WinnerBinary'] == results_df['Predicted'])
results_df['Result'] = results_df['Correct'].map({True: '✓ Correct', False: '✗ Failed'})

# Mostrar resultados
print("RESULTADOS DETALLADOS POR FILA:")
print("="*100)
print(f"\nTotal de predicciones: {len(results_df)}")
print(f"Correctas: {results_df['Correct'].sum()} ({results_df['Correct'].mean()*100:.2f}%)")
print(f"Fallidas: {(~results_df['Correct']).sum()} ({(~results_df['Correct']).mean()*100:.2f}%)")
print("\n" + "="*100 + "\n")

# Mostrar todas las filas
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_columns', None)

display(results_df[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary', 'Predicted', 'Probability', 'Result']])

# Mostrar solo las fallidas para análisis
print("\n" + "="*100)
print("PREDICCIONES FALLIDAS:")
print("="*100)
failed = results_df[~results_df['Correct']]
if len(failed) > 0:
    display(failed[['Date', 'PlayerA', 'PlayerB', 'WinnerBinary', 'Predicted', 'Probability']])
else:
    print("¡Todas las predicciones fueron correctas!")
# Out:
# RESULTADOS DETALLADOS POR FILA:
# ====================================================================================================
#
# Total de predicciones: 1
# Correctas: 0 (0.00%)
# Fallidas: 1 (100.00%)
#
# ====================================================================================================
#          Date     PlayerA    PlayerB  WinnerBinary  Predicted  Probability  \
# 0  2025-07-13  Alcaraz C.  Sinner J.             0          1     0.708794
#
#      Result
# 0  ✗ Failed
# ====================================================================================================
# PREDICCIONES FALLIDAS:
# ====================================================================================================
#          Date     PlayerA    PlayerB  WinnerBinary  Predicted  Probability
# 0  2025-07-13  Alcaraz C.  Sinner J.             0          1     0.708794
