# %%
import pandas as pd
import numpy as np

df_origin = pd.read_csv('wimbeldon_dataset_all_surfaces_v2.csv')
df_origin.head()
# Out:
# C:\Users\ikerr\AppData\Local\Temp\ipykernel_32432\59993403.py:4: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_origin = pd.read_csv('wimbeldon_dataset_all_surfaces_v2.csv')
#    ATP  Location                          Tournament        Date  \
# 0    2   Chennai                     Gold Flake Open  2000-01-03
# 1    1  Adelaide  Australian Hardcourt Championships  2000-01-03
# 2    2   Chennai                     Gold Flake Open  2000-01-03
# 3    2   Chennai                     Gold Flake Open  2000-01-03
# 4    2   Chennai                     Gold Flake Open  2000-01-03
#
#           Series  Court  Surface      Round  Best of      Winner       Loser  \
# 0  International      1        3  1st Round      3.0   Agenor R.    Kumar S.
# 1  International      1        3  1st Round      3.0   Norman M.   Draper S.
# 2  International      1        3  1st Round      3.0  Golmard J.   Spottl M.
# 3  International      1        3  1st Round      3.0  Jonsson F.  Kroslak J.
# 4  International      1        3  1st Round      3.0  Pioline C.      Ram A.
#
#    WRank LRank   W1   L1   W2   L2  W3  L3  W4  L4  W5  L5  Wsets  Lsets  \
# 0   94.0  1198  6.0  4.0  6.0  4.0 NaN NaN NaN NaN NaN NaN    2.0    0.0
# 1   15.0   155  6.0  4.0  6.0  4.0 NaN NaN NaN NaN NaN NaN    2.0    0.0
# 2   38.0   200  6.0  3.0  6.0  4.0 NaN NaN NaN NaN NaN NaN    2.0    0.0
# 3  127.0   103  6.0  3.0  6.0  3.0 NaN NaN NaN NaN NaN NaN    2.0    0.0
# 4   14.0   414  6.0  3.0  6.0  1.0 NaN NaN NaN NaN NaN NaN    2.0    0.0
#
#      Comment  CBW  CBL  GBW  GBL  IWW  IWL  SBW  SBL  B365W  B365L  B&WW  \
# 0  Completed  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN   NaN
# 1  Completed  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN   NaN
# 2  Completed  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN   NaN
# 3  Completed  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN   NaN
# 4  Completed  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN   NaN
#
#    B&WL  EXW  EXL  PSW  PSL  WPts  LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW  \
# 0   NaN  NaN  NaN  NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1   NaN  NaN  NaN  NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2   NaN  NaN  NaN  NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 3   NaN  NaN  NaN  NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4   NaN  NaN  NaN  NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
#    MaxL  AvgW  AvgL  BFEW  BFEL  MaxWin  MaxLoss  AvgWin  AvgLoss     PlayerA  \
# 0   NaN   NaN   NaN   NaN   NaN     NaN      NaN     NaN      NaN   Agenor R.
# 1   NaN   NaN   NaN   NaN   NaN     NaN      NaN     NaN      NaN   Draper S.
# 2   NaN   NaN   NaN   NaN   NaN     NaN      NaN     NaN      NaN  Golmard J.
# 3   NaN   NaN   NaN   NaN   NaN     NaN      NaN     NaN      NaN  Jonsson F.
# 4   NaN   NaN   NaN   NaN   NaN     NaN      NaN     NaN      NaN  Pioline C.
#
#       PlayerB  RankA   RankB  RankDiff  WinnerBinary  MaxOddsPlayerA  \
# 0    Kumar S.   94.0  1198.0   -1104.0             1             NaN
# 1   Norman M.  155.0    15.0     140.0             0             NaN
# 2   Spottl M.   38.0   200.0    -162.0             1             NaN
# 3  Kroslak J.  127.0   103.0      24.0             1             NaN
# 4      Ram A.   14.0   414.0    -400.0             1             NaN
#
#    MaxOddsPlayerB  AvgOddsPlayerA  AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  \
# 0             NaN             NaN             NaN           0           0
# 1             NaN             NaN             NaN           0           0
# 2             NaN             NaN             NaN           0           0
# 3             NaN             NaN             NaN           0           0
# 4             NaN             NaN             NaN           0           0
#
#    H2H_Diff  WinsA  LossesA  WinsB  LossesB  WinRateA_cum  WinRateB_cum  \
# 0         0      0        0      0        0           0.5           0.5
# 1         0      0        0      1        1           0.5           0.5
# 2         0      2        0      0        0           1.0           0.5
# 3         0      0        0      0        0           0.5           0.5
# 4         0      1        1      0        0           0.5           0.5
#
#    Form10A  Form10B  RestDaysA  RestDaysB  DiffWR  DiffForm  DiffRest  \
# 0      0.5      0.5         30         30     0.0       0.0         0
# 1      0.5      0.5         30          0     0.0       0.0        30
# 2      1.0      0.5          0         30     0.5       0.5       -30
# 3      0.5      0.5         30         30     0.0       0.0         0
# 4      0.5      0.5          0         30     0.0       0.0       -30
#
#    LogRankDiff  H2HDiff  ProbA_odds  ProbB_odds  OddsProbDiff  \
# 0    -2.545114        0    0.333333    0.333333           0.0
# 1     2.335375        0    0.333333    0.333333           0.0
# 2    -1.660731        0    0.333333    0.333333           0.0
# 3     0.209458        0    0.333333    0.333333           0.0
# 4    -3.386809        0    0.333333    0.333333           0.0
#
#    WinRateA_x_Rank  WinRateB_x_Rank  EfficiencyDiff  EloA_Global  EloB_Global  \
# 0         0.005319         0.000500        0.004819       1500.0       1500.0
# 1         0.003226         0.033333       -0.030108       1500.0       1500.0
# 2         0.026316         0.002500        0.023816       1500.0       1500.0
# 3         0.003937         0.004854       -0.000917       1500.0       1500.0
# 4         0.035714         0.001208        0.034507       1500.0       1500.0
#
#    EloA_Surface  EloB_Surface  EloDiff_Global  EloDiff_Surface
# 0        1500.0        1500.0             0.0              0.0
# 1        1500.0        1500.0             0.0              0.0
# 2        1500.0        1500.0             0.0              0.0
# 3        1500.0        1500.0             0.0              0.0
# 4        1500.0        1500.0             0.0              0.0

# %%
# Ens tenim que quedar amb només les dades de tots aquests partits que la seva data és anterior al 2025-06-29
df = df_origin.copy()
#df = df_origin[df_origin['Date'] < '2025-06-29'].copy()
df = df[df['Surface'] == 2].copy()

df.tail()
#print("Mida del df: ", len(df))
# Out:
#        ATP Location Tournament        Date      Series  Court  Surface  \
# 68317   36   London  Wimbledon  2025-07-09  Grand Slam      1        2
# 68318   36   London  Wimbledon  2025-07-09  Grand Slam      1        2
# 68319   36   London  Wimbledon  2025-07-11  Grand Slam      1        2
# 68320   36   London  Wimbledon  2025-07-11  Grand Slam      1        2
# 68321   36   London  Wimbledon  2025-07-13  Grand Slam      1        2
#
#                Round  Best of       Winner        Loser  WRank LRank   W1  \
# 68317  Quarterfinals      5.0  Djokovic N.   Cobolli F.    6.0  24.0  6.0
# 68318  Quarterfinals      5.0    Sinner J.   Shelton B.    1.0  10.0  7.0
# 68319     Semifinals      5.0    Sinner J.  Djokovic N.    1.0   6.0  6.0
# 68320     Semifinals      5.0   Alcaraz C.     Fritz T.    2.0   5.0  6.0
# 68321      The Final      5.0    Sinner J.   Alcaraz C.    1.0   2.0  4.0
#
#         L1   W2   L2   W3   L3   W4   L4  W5  L5  Wsets  Lsets    Comment  \
# 68317  7.0  6.0  2.0  7.0  5.0  6.0  4.0 NaN NaN    3.0    1.0  Completed
# 68318  6.0  6.0  4.0  6.0  4.0  NaN  NaN NaN NaN    3.0    0.0  Completed
# 68319  3.0  6.0  3.0  6.0  4.0  NaN  NaN NaN NaN    3.0    0.0  Completed
# 68320  4.0  5.0  7.0  6.0  3.0  7.0  6.0 NaN NaN    3.0    1.0  Completed
# 68321  6.0  6.0  4.0  6.0  4.0  6.0  4.0 NaN NaN    3.0    1.0  Completed
#
#        CBW  CBL  GBW  GBL  IWW  IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  \
# 68317  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.10   7.00   NaN   NaN  NaN
# 68318  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.25   3.60   NaN   NaN  NaN
# 68319  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.40   2.80   NaN   NaN  NaN
# 68320  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.17   4.75   NaN   NaN  NaN
# 68321  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.83   2.00   NaN   NaN  NaN
#
#        EXL   PSW   PSL     WPts    LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW  \
# 68317  NaN  1.11  8.33   4630.0  2035.0  NaN  NaN  NaN  NaN  NaN  NaN  1.12
# 68318  NaN  1.32  3.60  10430.0  3130.0  NaN  NaN  NaN  NaN  NaN  NaN  1.34
# 68319  NaN  1.47  2.93  10430.0  4630.0  NaN  NaN  NaN  NaN  NaN  NaN  1.47
# 68320  NaN  1.20  5.13   9300.0  4635.0  NaN  NaN  NaN  NaN  NaN  NaN  1.24
# 68321  NaN  1.85  2.07  10430.0  9300.0  NaN  NaN  NaN  NaN  NaN  NaN  1.87
#
#        MaxL  AvgW  AvgL  BFEW  BFEL  MaxWin  MaxLoss  AvgWin  AvgLoss  \
# 68317  8.60  1.09  7.53   NaN   NaN    1.11     8.33   1.105    7.665
# 68318  3.90  1.29  3.58   NaN   NaN    1.32     3.60   1.285    3.600
# 68319  3.05  1.42  2.85   NaN   NaN    1.47     2.93   1.435    2.865
# 68320  5.25  1.17  4.98   NaN   NaN    1.20     5.13   1.185    4.940
# 68321  2.07  1.82  1.98   NaN   NaN    1.85     2.07   1.840    2.035
#
#            PlayerA      PlayerB  RankA  RankB  RankDiff  WinnerBinary  \
# 68317   Cobolli F.  Djokovic N.   24.0    6.0      18.0             0
# 68318   Shelton B.    Sinner J.   10.0    1.0       9.0             0
# 68319  Djokovic N.    Sinner J.    6.0    1.0       5.0             0
# 68320   Alcaraz C.     Fritz T.    2.0    5.0      -3.0             1
# 68321   Alcaraz C.    Sinner J.    2.0    1.0       1.0             0
#
#        MaxOddsPlayerA  MaxOddsPlayerB  AvgOddsPlayerA  AvgOddsPlayerB  \
# 68317            8.60            1.12            7.53            1.09
# 68318            3.90            1.34            3.58            1.29
# 68319            3.05            1.47            2.85            1.42
# 68320            1.24            5.25            1.17            4.98
# 68321            2.07            1.87            1.98            1.82
#
#        H2H_A_wins  H2H_B_wins  H2H_Diff  WinsA  LossesA  WinsB  LossesB  \
# 68317           0           1        -1     59       49   1093      215
# 68318           1           5        -4     93       65    272       86
# 68319           4           4         0   1094      215    273       86
# 68320           1           0         1    239       59    289      189
# 68321           8           4         4    240       59    274       86
#
#        WinRateA_cum  WinRateB_cum  Form10A  Form10B  RestDaysA  RestDaysB  \
# 68317      0.546296      0.835627      0.7      0.9          2          2
# 68318      0.588608      0.759777      0.6      0.8          2          2
# 68319      0.835752      0.760446      0.9      0.8          2          2
# 68320      0.802013      0.604603      1.0      0.9          3          3
# 68321      0.802676      0.761111      1.0      0.8          2          2
#
#          DiffWR  DiffForm  DiffRest  LogRankDiff  H2HDiff  ProbA_odds  \
# 68317 -0.289331      -0.2         0     1.386294       -1    0.116279
# 68318 -0.171169      -0.2         0     2.302585       -4    0.256410
# 68319  0.075307       0.1         0     1.791759        0    0.327869
# 68320  0.197411       0.1         0    -0.916291        1    0.806452
# 68321  0.041564       0.2         0     0.693147        4    0.483092
#
#        ProbB_odds  OddsProbDiff  WinRateA_x_Rank  WinRateB_x_Rank  \
# 68317    0.892857     -0.776578         0.022762         0.139271
# 68318    0.746269     -0.489858         0.058861         0.759777
# 68319    0.680272     -0.352403         0.139292         0.760446
# 68320    0.190476      0.615975         0.401007         0.120921
# 68321    0.534759     -0.051668         0.401338         0.761111
#
#        EfficiencyDiff  EloA_Global  EloB_Global  EloA_Surface  EloB_Surface  \
# 68317       -0.116509  1788.861188  2026.536109   1556.528325   1975.161612
# 68318       -0.700916  1786.399787  2185.560132   1541.645698   1688.214627
# 68319       -0.621154  2033.029427  2188.482031   1977.139810   1695.432680
# 68320        0.280086  2162.047337  1922.449366   1797.524462   1731.007990
# 68321       -0.359773  2168.483549  2197.765504   1807.254728   1715.473177
#
#        EloDiff_Global  EloDiff_Surface
# 68317     -237.674922      -418.633287
# 68318     -399.160345      -146.568929
# 68319     -155.452604       281.707130
# 68320      239.597971        66.516471
# 68321      -29.281955        91.781551

# %%
from collections import defaultdict
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import brier_score_loss
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split, TimeSeriesSplit

features = [
    'LogRankDiff',      # ranking
    'DiffWR',           # diferencia de winrate históric en herva
    'DiffForm',         # últims 10
    'H2HDiff',          # head-to-head
    'OddsProbDiff',     # diferencia de probabilitat implícita de quotas
    'DiffRest',         # dies de rest
    'EfficiencyDiff',   # winrate / rank → jugador que rendeix per sobre del seu ranking
    'RankDiff',         # diferencia de ranking
    'EloDiff_Global',   # diferencia de elo global
    'EloDiff_Surface'   # diferencia de elo en superfície
]

df = df.sort_values("Date", ascending=True).reset_index(drop=True)

#X_train, X_test, y_train, y_test = train_test_split(df[features], df['WinnerBinary'], test_size=0.2, random_state=42)
X = df[features]
y = df["WinnerBinary"]
split_idx = int(len(df) * 0.8)
X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = XGBClassifier(
    n_estimators=500,                    # Nombre total d'arbres (boosting rounds) que es construiran. 500 és un valor força alt, bo per a un bon rendiment si es controla l'overfitting.
    max_depth=6,                         # Profunditat màxima de cada arbre. 6 és un valor moderat: permet interaccions complexes sense fer els arbres excessivament profunds.
    learning_rate=0.02,                  # Taxa d'aprenentatge (eta). 0.02 és bastant baixa → aprenentatge lent i estable, ideal quan tens molts estimators (500).
    subsample=0.85,                      # Percentatge de mostres (files) que s'utilitzen per entrenar cada arbre. 0.85 = 85% → ajuda a reduir overfitting i afegeix variància (com bagging).
    colsample_bytree=0.85,               # Percentatge de columnes (variables) que s'agafen aleatòriament per cada arbre. 85% → també redueix overfitting i millora la generalització.
    min_child_weight=5,                  # Suma mínima del pes Hessiana en un node fill. Valors >1 fan el model més conservador: evita dividir nodes amb poca informació.
    gamma=0.1,                           # Minimització mínima de la funció de pèrdua necessària per fer una partició addicional (regularització per poda). 0.1 afavoreix arbres més simples.
    reg_alpha=0.1,                       # Terme de regularització L1 sobre els pesos de les fulles. Ajuda a fer sparseness i és útil quan hi ha moltes variables irrellevants.
    reg_lambda=1.0,                      # Terme de regularització L2 (més suau que L1). 1.0 és el valor per defecte i sol funcionar bé en la majoria de casos.
    random_state=42,                     # Llavor per a la reproductibilitat dels resultats (aleatorietat controlada).
    n_jobs=-1,                           # Utilitza tots els nuclis disponibles del processador per entrenar en paral·lel → molt més ràpid.
    eval_metric='logloss'                # Mètrica d'avaluació durant l'entrenament (per classificació binària/multiclasse). 'logloss' = logarithmic loss (cross-entropy).
)

tscv = TimeSeriesSplit(n_splits=5)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob_model_con_tscv = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob_model_con_tscv)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 0.6768
# Brier Score: 0.2034
#               precision    recall  f1-score   support
#
#            0     0.6753    0.6317    0.6528       744
#            1     0.6780    0.7186    0.6977       803
#
#     accuracy                         0.6768      1547
#    macro avg     0.6767    0.6751    0.6752      1547
# weighted avg     0.6767    0.6768    0.6761      1547
#
# ================================================================================

# %%
import shap
xgb_model = model.calibrated_classifiers_[0].estimator

explainer = shap.TreeExplainer(xgb_model)
shap_values = explainer.shap_values(X_train_sc)
shap.summary_plot(shap_values, X_train, plot_type="bar")

# %% [markdown]
# ---

# %%
from collections import defaultdict

# ============================
# 1. MAPEO SUPERFICIES SI ESTÁN NUMERIZADAS
# ============================

# Si Surface es numérica (LabelEncoder), necesitamos mapearlo a strings
surface_map = {
    0: "Hard",
    1: "Clay",
    2: "Grass",
    3: "Carpet"
}

# Detectar si Surface es numérica
if np.issubdtype(df["Surface"].dtype, np.number):
    df["SurfaceText"] = df["Surface"].map(surface_map)
else:
    df["SurfaceText"] = df["Surface"]

# ============================
# 2. ORDEN CORRECTO DE RONDAS
# ============================

round_order = {
    "1st Round": 1,
    "2nd Round": 2,
    "3rd Round": 3,
    "4th Round": 4,
    "Round of 16": 5,
    "Quarterfinals": 6,
    "Semifinals": 7,
    "The Final": 8
}

df["RoundOrder"] = df["Round"].map(round_order)

# Ordenar completamente en orden real cronológico
df = df.sort_values(["Date", "Tournament", "RoundOrder"]).reset_index(drop=True)

# ============================
# 3. CONFIGURACIÓN DEL ELO
# ============================

ELO_START = 1500
DECAY_GLOBAL = 0.9995
DECAY_SURFACE = 0.999

def dynamic_k(diff):
    """K depende de diferencia de Elo (más cerca → más grande K)."""
    if diff < 25:
        return 40
    elif diff < 75:
        return 32
    elif diff < 150:
        return 24
    else:
        return 16

# Importancia del torneo
tournament_weights = {
    "ATP250": 1.00,
    "ATP500": 1.10,
    "Masters 1000": 1.20,
    "Grand Slam": 1.30,
    "International": 1.00   # por compatibilidad con tus datos antiguos
}

# ============================
# 4. INICIALIZAR ELO
# ============================

elo_global = defaultdict(lambda: ELO_START)
elo_surface = defaultdict(lambda: {"Hard": ELO_START, "Clay": ELO_START, "Grass": ELO_START, "Carpet": ELO_START})

# Columnas de salida
df["EloA_Global"] = 0.0
df["EloB_Global"] = 0.0
df["EloA_Surface"] = 0.0
df["EloB_Surface"] = 0.0

# ============================
# 5. EXPECTED SCORE
# ============================

def expected_score(r1, r2):
    return 1 / (1 + 10 ** ((r2 - r1) / 400))

# ============================
# 6. CALCULAR ELO SIN DATA LEAKAGE
# ============================

for i, row in df.iterrows():
    
    A = row["PlayerA"]
    B = row["PlayerB"]
    surf = row["SurfaceText"]
    series = row["Series"]

    # --- Decaimiento temporal (antes del partido)
    elo_global[A] *= DECAY_GLOBAL
    elo_global[B] *= DECAY_GLOBAL
    elo_surface[A][surf] *= DECAY_SURFACE
    elo_surface[B][surf] *= DECAY_SURFACE

    # --- Elo ANTES DEL PARTIDO (features pre-partido)
    eloA_g = elo_global[A]
    eloB_g = elo_global[B]
    eloA_s = elo_surface[A][surf]
    eloB_s = elo_surface[B][surf]

    df.at[i, "EloA_Global"] = eloA_g
    df.at[i, "EloB_Global"] = eloB_g
    df.at[i, "EloA_Surface"] = eloA_s
    df.at[i, "EloB_Surface"] = eloB_s

    # --- Resultado del partido
    winner = row["WinnerBinary"]
    scoreA = 1 if winner == 1 else 0
    scoreB = 1 - scoreA

    # --- Expected score
    expA_g = expected_score(eloA_g, eloB_g)
    expA_s = expected_score(eloA_s, eloB_s)

    # --- K dinámico + importancia de torneo
    diff = abs(eloA_g - eloB_g)
    K = dynamic_k(diff)
    weight = tournament_weights.get(series, 1.00)
    K_final = K * weight

    # --- Actualización GLOBAL
    elo_global[A] = eloA_g + K_final * (scoreA - expA_g)
    elo_global[B] = eloB_g + K_final * (scoreB - (1 - expA_g))

    # --- Actualización SUPERFICIE
    elo_surface[A][surf] = eloA_s + K_final * (scoreA - expA_s)
    elo_surface[B][surf] = eloB_s + K_final * (scoreB - (1 - expA_s))

# ============================
# 7. DIFERENCIAS FINALES COMO FEATURES
# ============================

df["EloDiff_Global"] = df["EloA_Global"] - df["EloB_Global"]
df["EloDiff_Surface"] = df["EloA_Surface"] - df["EloB_Surface"]

df.head()
# Out:
#    ATP Location        Tournament        Date         Series  Court  Surface  \
# 0   33    Halle  Gerry Weber Open  2000-06-12  International      1        2
# 1   33    Halle  Gerry Weber Open  2000-06-12  International      1        2
# 2   33    Halle  Gerry Weber Open  2000-06-12  International      1        2
# 3   33    Halle  Gerry Weber Open  2000-06-12  International      1        2
# 4   33    Halle  Gerry Weber Open  2000-06-12  International      1        2
#
#        Round  Best of         Winner         Loser  WRank LRank   W1   L1  \
# 0  1st Round      3.0     Federer R.    Clement A.   38.0    57  6.0  4.0
# 1  1st Round      3.0  Kafelnikov Y.    Vicente F.    5.0    29  6.0  7.0
# 2  1st Round      3.0     Larsson M.  Ferrero J.C.   49.0    12  6.0  3.0
# 3  1st Round      3.0        Moya C.    Caratti C.   51.0   153  6.0  2.0
# 4  1st Round      3.0       Chang M.  Tillstrom M.   28.0    59  6.0  3.0
#
#     W2   L2   W3   L3  W4  L4  W5  L5  Wsets  Lsets    Comment  CBW  CBL  GBW  \
# 0  6.0  2.0  NaN  NaN NaN NaN NaN NaN    2.0    0.0  Completed  NaN  NaN  NaN
# 1  7.0  6.0  6.0  4.0 NaN NaN NaN NaN    2.0    1.0  Completed  NaN  NaN  NaN
# 2  7.0  6.0  NaN  NaN NaN NaN NaN NaN    2.0    0.0  Completed  NaN  NaN  NaN
# 3  6.0  4.0  NaN  NaN NaN NaN NaN NaN    2.0    0.0  Completed  NaN  NaN  NaN
# 4  3.0  6.0  6.0  3.0 NaN NaN NaN NaN    2.0    1.0  Completed  NaN  NaN  NaN
#
#    GBL  IWW  IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL  PSW  PSL  \
# 0  NaN  NaN  NaN  NaN  NaN    NaN    NaN   NaN   NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN    NaN    NaN   NaN   NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN    NaN    NaN   NaN   NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN    NaN    NaN   NaN   NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN    NaN    NaN   NaN   NaN  NaN  NaN  NaN  NaN
#
#    WPts  LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW  MaxL  AvgW  AvgL  BFEW  \
# 0   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN
#
#    BFEL  MaxWin  MaxLoss  AvgWin  AvgLoss        PlayerA       PlayerB  RankA  \
# 0   NaN     NaN      NaN     NaN      NaN     Clement A.    Federer R.   57.0
# 1   NaN     NaN      NaN     NaN      NaN  Kafelnikov Y.    Vicente F.    5.0
# 2   NaN     NaN      NaN     NaN      NaN   Ferrero J.C.    Larsson M.   12.0
# 3   NaN     NaN      NaN     NaN      NaN     Caratti C.       Moya C.  153.0
# 4   NaN     NaN      NaN     NaN      NaN       Chang M.  Tillstrom M.   28.0
#
#    RankB  RankDiff  WinnerBinary  MaxOddsPlayerA  MaxOddsPlayerB  \
# 0   38.0      19.0             0             NaN             NaN
# 1   29.0     -24.0             1             NaN             NaN
# 2   49.0     -37.0             0             NaN             NaN
# 3   51.0     102.0             0             NaN             NaN
# 4   59.0     -31.0             1             NaN             NaN
#
#    AvgOddsPlayerA  AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  H2H_Diff  WinsA  \
# 0             NaN             NaN           1           0         1      9
# 1             NaN             NaN           1           0         1     24
# 2             NaN             NaN           0           0         0     29
# 3             NaN             NaN           0           0         0      1
# 4             NaN             NaN           0           1        -1     16
#
#    LossesA  WinsB  LossesB  WinRateA_cum  WinRateB_cum   Form10A  Form10B  \
# 0       12     16       13      0.428571      0.551724  0.400000      0.4
# 1       14     18       16      0.631579      0.529412  0.600000      0.5
# 2       13     12        5      0.690476      0.705882  0.700000      0.6
# 3        2     15        9      0.333333      0.625000  0.333333      0.5
# 4       12     12        9      0.571429      0.571429  0.500000      0.5
#
#    RestDaysA  RestDaysB    DiffWR  DiffForm  DiffRest  LogRankDiff  H2HDiff  \
# 0         14         14 -0.123153  0.000000         0     0.405465        1
# 1         14         14  0.102167  0.100000         0    -1.757858        1
# 2         14         56 -0.015406  0.100000       -42    -1.406914        0
# 3        119         14 -0.291667 -0.166667       105     1.098612        0
# 4         14         14  0.000000  0.000000         0    -0.745333       -1
#
#    ProbA_odds  ProbB_odds  OddsProbDiff  WinRateA_x_Rank  WinRateB_x_Rank  \
# 0    0.333333    0.333333           0.0         0.007519         0.014519
# 1    0.333333    0.333333           0.0         0.126316         0.018256
# 2    0.333333    0.333333           0.0         0.057540         0.014406
# 3    0.333333    0.333333           0.0         0.002179         0.012255
# 4    0.333333    0.333333           0.0         0.020408         0.009685
#
#    EfficiencyDiff  EloA_Global  EloB_Global  EloA_Surface  EloB_Surface  \
# 0       -0.007000      1499.25      1499.25        1498.5        1498.5
# 1        0.108060      1499.25      1499.25        1498.5        1498.5
# 2        0.043134      1499.25      1499.25        1498.5        1498.5
# 3       -0.010076      1499.25      1499.25        1498.5        1498.5
# 4        0.010723      1499.25      1499.25        1498.5        1498.5
#
#    EloDiff_Global  EloDiff_Surface SurfaceText  RoundOrder
# 0             0.0              0.0       Grass           1
# 1             0.0              0.0       Grass           1
# 2             0.0              0.0       Grass           1
# 3             0.0              0.0       Grass           1
# 4             0.0              0.0       Grass           1

# %% [markdown]
# ---

# %%
from sklearn.preprocessing import LabelEncoder

le_series = LabelEncoder()
df["Series"] = le_series.fit_transform(df["Series"])

# ======== FEATURES ========
features = [
    # Diferencias estadísticas base
    'LogRankDiff',
    'DiffWR',
    'DiffForm',
    'H2HDiff',
    'OddsProbDiff',
    'DiffRest',
    'EfficiencyDiff',
    'RankDiff',

    # Elo avanzado
    'EloDiff_Global',
    'EloDiff_Surface',

    # Contexto
    'Series',       # codificada con LabelEncoder
    'RoundOrder'    # orden real de la ronda
]

# Aseguramos orden temporal
df = df.sort_values("Date", ascending=True).reset_index(drop=True)

X = df[features]
y = df["WinnerBinary"].values

n = len(df)
idx_train_end = int(n * 0.7)   # 70% train
idx_val_end   = int(n * 0.8)   # 10% val (70–80)
# 20% restante = test

X_train = X.iloc[:idx_train_end]
y_train = y[:idx_train_end]

X_val   = X.iloc[idx_train_end:idx_val_end]
y_val   = y[idx_train_end:idx_val_end]

X_test  = X.iloc[idx_val_end:]
y_test  = y[idx_val_end:]

print("Tamaños:")
print("Train:", X_train.shape, "Val:", X_val.shape, "Test:", X_test.shape)

# ======== ESCALADO (solo con TRAIN) ========
scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_val_sc   = scaler.transform(X_val)
X_test_sc  = scaler.transform(X_test)
# Out:
# Tamaños:
# Train: (5413, 12) Val: (774, 12) Test: (1547, 12)

# %%
from copy import deepcopy

# Valores a probar para número de árboles
n_estimators_grid = [200, 350, 500, 750, 1000, 1300]

results = []

for n_est in n_estimators_grid:
    print(f"\nEntrenando modelo con n_estimators = {n_est}")

    model_tmp = XGBClassifier(
        n_estimators=n_est,
        max_depth=6,
        learning_rate=0.02,
        subsample=0.85,
        colsample_bytree=0.85,
        min_child_weight=5,
        gamma=0.1,
        reg_alpha=0.1,
        reg_lambda=1.0,
        random_state=42,
        n_jobs=-1,
        eval_metric="logloss"
    )

    model_tmp.fit(X_train_sc, y_train)

    prob_val = model_tmp.predict_proba(X_val_sc)[:, 1]
    pred_val = (prob_val >= 0.5).astype(int)

    acc_val = accuracy_score(y_val, pred_val)
    brier_val = brier_score_loss(y_val, prob_val)

    results.append((n_est, acc_val, brier_val))
    print(f"VAL → ACC={acc_val:.4f}, BRIER={brier_val:.4f}")

# Elegir el mejor por Brier y, en empate, por accuracy
results_sorted = sorted(results, key=lambda x: (x[2], -x[1]))
best_n, best_acc_val, best_brier_val = results_sorted[0]

print("\n==============================")
print("MEJOR n_estimators EN VALIDACIÓN:")
print(f"n_estimators={best_n}, ACC_VAL={best_acc_val:.4f}, BRIER_VAL={best_brier_val:.4f}")
print("==============================")
# Out:
# Entrenando modelo con n_estimators = 200
# VAL → ACC=0.6835, BRIER=0.2068
#
# Entrenando modelo con n_estimators = 350
# VAL → ACC=0.6886, BRIER=0.2092
#
# Entrenando modelo con n_estimators = 500
# VAL → ACC=0.6899, BRIER=0.2109
#
# Entrenando modelo con n_estimators = 750
# VAL → ACC=0.6835, BRIER=0.2148
#
# Entrenando modelo con n_estimators = 1000
# VAL → ACC=0.6809, BRIER=0.2177
#
# Entrenando modelo con n_estimators = 1300
# VAL → ACC=0.6757, BRIER=0.2218
#
# ==============================
# MEJOR n_estimators EN VALIDACIÓN:
# n_estimators=200, ACC_VAL=0.6835, BRIER_VAL=0.2068
# ==============================

# %%
# ======== REENTRENAR SCALER EN TRAIN+VAL ========
X_train_val = pd.concat([X_train, X_val], axis=0)
y_train_val = np.concatenate([y_train, y_val])

scaler_final = StandardScaler()
X_train_val_sc = scaler_final.fit_transform(X_train_val)
X_test_sc_final = scaler_final.transform(X_test)

# ======== MODELO XGBOOST FINAL (SIN CALIBRACIÓN) ========
base_model_final = XGBClassifier(
    n_estimators=best_n,
    max_depth=6,
    learning_rate=0.02,
    subsample=0.85,
    colsample_bytree=0.85,
    min_child_weight=5,
    gamma=0.1,
    reg_alpha=0.1,
    reg_lambda=1.0,
    random_state=42,
    n_jobs=-1,
    eval_metric="logloss"
)

base_model_final.fit(X_train_val_sc, y_train_val)

# ======== EVALUACIÓN SIN CALIBRACIÓN ========
prob_test_base = base_model_final.predict_proba(X_test_sc_final)[:, 1]
pred_test_base = (prob_test_base >= 0.5).astype(int)

acc_base = accuracy_score(y_test, pred_test_base)
brier_base = brier_score_loss(y_test, prob_test_base)

print("\n===== RESULTADOS SIN CALIBRACIÓN =====")
print(f"Accuracy TEST: {acc_base:.4f}")
print(f"Brier TEST:    {brier_base:.4f}")
print(classification_report(y_test, pred_test_base, digits=4))
print("=======================================")
# Out:
# ===== RESULTADOS SIN CALIBRACIÓN =====
# Accuracy TEST: 0.6690
# Brier TEST:    0.2042
#               precision    recall  f1-score   support
#
#            0     0.6593    0.6452    0.6522       744
#            1     0.6777    0.6912    0.6843       803
#
#     accuracy                         0.6690      1547
#    macro avg     0.6685    0.6682    0.6683      1547
# weighted avg     0.6688    0.6690    0.6689      1547
#
# =======================================

# %%
# ======== CALIBRACIÓN ISOTÓNICA SOBRE TRAIN+VAL ========
cal_model = CalibratedClassifierCV(
    estimator=deepcopy(base_model_final),
    method="isotonic",
    cv=5
)

cal_model.fit(X_train_val_sc, y_train_val)

prob_test_cal = cal_model.predict_proba(X_test_sc_final)[:, 1]
pred_test_cal = (prob_test_cal >= 0.5).astype(int)

acc_cal = accuracy_score(y_test, pred_test_cal)
brier_cal = brier_score_loss(y_test, prob_test_cal)

print("\n===== RESULTADOS CON CALIBRACIÓN ISOTÓNICA =====")
print(f"Accuracy TEST: {acc_cal:.4f}")
print(f"Brier TEST:    {brier_cal:.4f}")
print(classification_report(y_test, pred_test_cal, digits=4))
print("================================================")
# Out:
# ===== RESULTADOS CON CALIBRACIÓN ISOTÓNICA =====
# Accuracy TEST: 0.6742
# Brier TEST:    0.2028
#               precision    recall  f1-score   support
#
#            0     0.6695    0.6371    0.6529       744
#            1     0.6782    0.7086    0.6931       803
#
#     accuracy                         0.6742      1547
#    macro avg     0.6738    0.6728    0.6730      1547
# weighted avg     0.6740    0.6742    0.6737      1547
#
# ================================================

# %% [markdown]
# ---

# %%
from lightgbm import LGBMClassifier

features = [
    # Diferencias estadísticas base
    'LogRankDiff',
    'DiffWR',
    'DiffForm',
    'H2HDiff',
    'OddsProbDiff',
    'DiffRest',
    'EfficiencyDiff',
    'RankDiff',

    # Elo avanzado
    'EloDiff_Global',
    'EloDiff_Surface',

    # Contexto
    'Series',       # codificada con LabelEncoder
    'RoundOrder'    # orden real de la ronda
]

# Aseguramos orden temporal
df = df.sort_values("Date", ascending=True).reset_index(drop=True)

X = df[features]
y = df["WinnerBinary"].values

n = len(df)
idx_train_end = int(n * 0.7)   # 70% train
idx_val_end   = int(n * 0.8)   # +10% val

X_train = X.iloc[:idx_train_end]
y_train = y[:idx_train_end]

X_val   = X.iloc[idx_train_end:idx_val_end]
y_val   = y[idx_train_end:idx_val_end]

X_test  = X.iloc[idx_val_end:]
y_test  = y[idx_val_end:]

print("Tamaños:")
print("Train:", X_train.shape, "Val:", X_val.shape, "Test:", X_test.shape)
# Out:
# Tamaños:
# Train: (5413, 12) Val: (774, 12) Test: (1547, 12)

# %%
param_grid = [
    # (num_leaves, learning_rate, n_estimators, min_data_in_leaf, feature_fraction, bagging_fraction)
    (31,  0.05, 400, 30, 0.9, 0.9),
    (31,  0.03, 800, 30, 0.9, 0.9),
    (63,  0.03, 800, 50, 0.9, 0.9),
    (63,  0.02, 1200, 50, 0.9, 0.8),
    (127, 0.02, 1400, 80, 0.8, 0.8),
]

results = []

for (num_leaves, lr, n_estimators, min_data, feat_frac, bag_frac) in param_grid:
    print(f"\nEntrenando LGBM con: "
          f"num_leaves={num_leaves}, lr={lr}, n_estimators={n_estimators}, "
          f"min_data_in_leaf={min_data}, feature_fraction={feat_frac}, bagging_fraction={bag_frac}")

    lgbm = LGBMClassifier(
        objective='binary',
        num_leaves=num_leaves,
        learning_rate=lr,
        n_estimators=n_estimators,
        min_data_in_leaf=min_data,
        feature_fraction=feat_frac,
        bagging_fraction=bag_frac,
        bagging_freq=1,
        subsample_for_bin=200000,
        random_state=42,
        n_jobs=-1
    )

    lgbm.fit(X_train, y_train)

    prob_val = lgbm.predict_proba(X_val)[:, 1]
    pred_val = (prob_val >= 0.5).astype(int)

    acc_val = accuracy_score(y_val, pred_val)
    brier_val = brier_score_loss(y_val, prob_val)

    results.append({
        "num_leaves": num_leaves,
        "learning_rate": lr,
        "n_estimators": n_estimators,
        "min_data_in_leaf": min_data,
        "feature_fraction": feat_frac,
        "bagging_fraction": bag_frac,
        "acc_val": acc_val,
        "brier_val": brier_val
    })

    print(f"VAL → ACC={acc_val:.4f}, BRIER={brier_val:.4f}")

# Elegir el mejor: minimizamos Brier, y en empate maximizamos ACC
results_sorted = sorted(results, key=lambda r: (r["brier_val"], -r["acc_val"]))
best = results_sorted[0]

print("\n=============== MEJOR CONFIGURACIÓN EN VALIDACIÓN ===============")
print(f"num_leaves={best['num_leaves']}, "
      f"lr={best['learning_rate']}, "
      f"n_estimators={best['n_estimators']}, "
      f"min_data_in_leaf={best['min_data_in_leaf']}, "
      f"feature_fraction={best['feature_fraction']}, "
      f"bagging_fraction={best['bagging_fraction']}")
print(f"ACC_VAL={best['acc_val']:.4f}, BRIER_VAL={best['brier_val']:.4f}")
print("=================================================================")
# Out:
# Entrenando LGBM con: num_leaves=31, lr=0.05, n_estimators=400, min_data_in_leaf=30, feature_fraction=0.9, bagging_fraction=0.9
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 2728, number of negative: 2685
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000294 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2170
# [LightGBM] [Info] Number of data points in the train set: 5413, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503972 -> initscore=0.015888
# [LightGBM] [Info] Start training from score 0.015888
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# VAL → ACC=0.6615, BRIER=0.2234
#
# Entrenando LGBM con: num_leaves=31, lr=0.03, n_estimators=800, min_data_in_leaf=30, feature_fraction=0.9, bagging_fraction=0.9
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 2728, number of negative: 2685
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000350 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2170
# [LightGBM] [Info] Number of data points in the train set: 5413, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503972 -> initscore=0.015888
# [LightGBM] [Info] Start training from score 0.015888
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# VAL → ACC=0.6705, BRIER=0.2254
#
# Entrenando LGBM con: num_leaves=63, lr=0.03, n_estimators=800, min_data_in_leaf=50, feature_fraction=0.9, bagging_fraction=0.9
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 2728, number of negative: 2685
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000255 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2170
# [LightGBM] [Info] Number of data points in the train set: 5413, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503972 -> initscore=0.015888
# [LightGBM] [Info] Start training from score 0.015888
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# VAL → ACC=0.6499, BRIER=0.2430
#
# Entrenando LGBM con: num_leaves=63, lr=0.02, n_estimators=1200, min_data_in_leaf=50, feature_fraction=0.9, bagging_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 2728, number of negative: 2685
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000218 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2170
# [LightGBM] [Info] Number of data points in the train set: 5413, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503972 -> initscore=0.015888
# [LightGBM] [Info] Start training from score 0.015888
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# VAL → ACC=0.6550, BRIER=0.2382
#
# Entrenando LGBM con: num_leaves=127, lr=0.02, n_estimators=1400, min_data_in_leaf=80, feature_fraction=0.8, bagging_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=80, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=80, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 2728, number of negative: 2685
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000243 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2170
# [LightGBM] [Info] Number of data points in the train set: 5413, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503972 -> initscore=0.015888
# [LightGBM] [Info] Start training from score 0.015888
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_data_in_leaf is set=80, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# VAL → ACC=0.6563, BRIER=0.2300
#
# =============== MEJOR CONFIGURACIÓN EN VALIDACIÓN ===============
# num_leaves=31, lr=0.05, n_estimators=400, min_data_in_leaf=30, feature_fraction=0.9, bagging_fraction=0.9
# ACC_VAL=0.6615, BRIER_VAL=0.2234
# =================================================================

# %%
# Unimos train + val para entrenar el modelo final
X_train_val = pd.concat([X_train, X_val], axis=0)
y_train_val = np.concatenate([y_train, y_val])

best_lgbm = LGBMClassifier(
    objective='binary',
    num_leaves=best['num_leaves'],
    learning_rate=best['learning_rate'],
    n_estimators=best['n_estimators'],
    min_data_in_leaf=best['min_data_in_leaf'],
    feature_fraction=best['feature_fraction'],
    bagging_fraction=best['bagging_fraction'],
    bagging_freq=1,
    subsample_for_bin=200000,
    random_state=42,
    n_jobs=-1
)

best_lgbm.fit(X_train_val, y_train_val)

# Evaluación en TEST
prob_test = best_lgbm.predict_proba(X_test)[:, 1]
pred_test = (prob_test >= 0.5).astype(int)

acc_test = accuracy_score(y_test, pred_test)
brier_test = brier_score_loss(y_test, prob_test)

print("\n===== RESULTADOS LGBM EN TEST (SIN CALIBRAR) =====")
print(f"Accuracy TEST: {acc_test:.4f}")
print(f"Brier TEST:    {brier_test:.4f}")
print(classification_report(y_test, pred_test, digits=4))
print("==================================================")
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 3132, number of negative: 3055
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000389 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2172
# [LightGBM] [Info] Number of data points in the train set: 6187, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.506223 -> initscore=0.024892
# [LightGBM] [Info] Start training from score 0.024892
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#
# ===== RESULTADOS LGBM EN TEST (SIN CALIBRAR) =====
# Accuracy TEST: 0.6529
# Brier TEST:    0.2187
#               precision    recall  f1-score   support
#
#            0     0.6444    0.6210    0.6324       744
#            1     0.6602    0.6824    0.6712       803
#
#     accuracy                         0.6529      1547
#    macro avg     0.6523    0.6517    0.6518      1547
# weighted avg     0.6526    0.6529    0.6525      1547
#
# ==================================================

# %%
from sklearn.calibration import CalibratedClassifierCV
from copy import deepcopy

cal_lgbm = CalibratedClassifierCV(
    estimator=deepcopy(best_lgbm),
    method="isotonic",
    cv=5
)

cal_lgbm.fit(X_train_val, y_train_val)

prob_test_cal = cal_lgbm.predict_proba(X_test)[:, 1]
pred_test_cal = (prob_test_cal >= 0.5).astype(int)

acc_test_cal = accuracy_score(y_test, pred_test_cal)
brier_test_cal = brier_score_loss(y_test, prob_test_cal)

print("\n===== RESULTADOS LGBM EN TEST (CALIBRADO ISOTÓNICO) =====")
print(f"Accuracy TEST: {acc_test_cal:.4f}")
print(f"Brier TEST:    {brier_test_cal:.4f}")
print(classification_report(y_test, pred_test_cal, digits=4))
print("=========================================================")
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 2505, number of negative: 2444
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000248 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2153
# [LightGBM] [Info] Number of data points in the train set: 4949, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.506163 -> initscore=0.024653
# [LightGBM] [Info] Start training from score 0.024653
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 2505, number of negative: 2444
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000256 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2160
# [LightGBM] [Info] Number of data points in the train set: 4949, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.506163 -> initscore=0.024653
# [LightGBM] [Info] Start training from score 0.024653
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 2506, number of negative: 2444
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000252 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2159
# [LightGBM] [Info] Number of data points in the train set: 4950, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.506263 -> initscore=0.025052
# [LightGBM] [Info] Start training from score 0.025052
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 2506, number of negative: 2444
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000416 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2163
# [LightGBM] [Info] Number of data points in the train set: 4950, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.506263 -> initscore=0.025052
# [LightGBM] [Info] Start training from score 0.025052
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 2506, number of negative: 2444
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000350 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2165
# [LightGBM] [Info] Number of data points in the train set: 4950, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.506263 -> initscore=0.025052
# [LightGBM] [Info] Start training from score 0.025052
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#
# ===== RESULTADOS LGBM EN TEST (CALIBRADO ISOTÓNICO) =====
# Accuracy TEST: 0.6613
# Brier TEST:    0.2069
#               precision    recall  f1-score   support
#
#            0     0.6562    0.6210    0.6381       744
#            1     0.6655    0.6986    0.6817       803
#
#     accuracy                         0.6613      1547
#    macro avg     0.6609    0.6598    0.6599      1547
# weighted avg     0.6610    0.6613    0.6607      1547
#
# =========================================================

# %%
df.tail()
# Out:
#       ATP Location Tournament        Date  Series  Court  Surface  \
# 7729   36   London  Wimbledon  2025-07-09       2      1        2
# 7730   36   London  Wimbledon  2025-07-09       2      1        2
# 7731   36   London  Wimbledon  2025-07-11       2      1        2
# 7732   36   London  Wimbledon  2025-07-11       2      1        2
# 7733   36   London  Wimbledon  2025-07-13       2      1        2
#
#               Round  Best of       Winner        Loser  WRank LRank   W1   L1  \
# 7729  Quarterfinals      5.0  Djokovic N.   Cobolli F.    6.0  24.0  6.0  7.0
# 7730  Quarterfinals      5.0    Sinner J.   Shelton B.    1.0  10.0  7.0  6.0
# 7731     Semifinals      5.0   Alcaraz C.     Fritz T.    2.0   5.0  6.0  4.0
# 7732     Semifinals      5.0    Sinner J.  Djokovic N.    1.0   6.0  6.0  3.0
# 7733      The Final      5.0    Sinner J.   Alcaraz C.    1.0   2.0  4.0  6.0
#
#        W2   L2   W3   L3   W4   L4  W5  L5  Wsets  Lsets    Comment  CBW  CBL  \
# 7729  6.0  2.0  7.0  5.0  6.0  4.0 NaN NaN    3.0    1.0  Completed  NaN  NaN
# 7730  6.0  4.0  6.0  4.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN
# 7731  5.0  7.0  6.0  3.0  7.0  6.0 NaN NaN    3.0    1.0  Completed  NaN  NaN
# 7732  6.0  3.0  6.0  4.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN
# 7733  6.0  4.0  6.0  4.0  6.0  4.0 NaN NaN    3.0    1.0  Completed  NaN  NaN
#
#       GBW  GBL  IWW  IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW  \
# 7729  NaN  NaN  NaN  NaN  NaN  NaN   1.10   7.00   NaN   NaN  NaN  NaN  1.11
# 7730  NaN  NaN  NaN  NaN  NaN  NaN   1.25   3.60   NaN   NaN  NaN  NaN  1.32
# 7731  NaN  NaN  NaN  NaN  NaN  NaN   1.17   4.75   NaN   NaN  NaN  NaN  1.20
# 7732  NaN  NaN  NaN  NaN  NaN  NaN   1.40   2.80   NaN   NaN  NaN  NaN  1.47
# 7733  NaN  NaN  NaN  NaN  NaN  NaN   1.83   2.00   NaN   NaN  NaN  NaN  1.85
#
#        PSL     WPts    LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW  MaxL  AvgW  \
# 7729  8.33   4630.0  2035.0  NaN  NaN  NaN  NaN  NaN  NaN  1.12  8.60  1.09
# 7730  3.60  10430.0  3130.0  NaN  NaN  NaN  NaN  NaN  NaN  1.34  3.90  1.29
# 7731  5.13   9300.0  4635.0  NaN  NaN  NaN  NaN  NaN  NaN  1.24  5.25  1.17
# 7732  2.93  10430.0  4630.0  NaN  NaN  NaN  NaN  NaN  NaN  1.47  3.05  1.42
# 7733  2.07  10430.0  9300.0  NaN  NaN  NaN  NaN  NaN  NaN  1.87  2.07  1.82
#
#       AvgL  BFEW  BFEL  MaxWin  MaxLoss  AvgWin  AvgLoss      PlayerA  \
# 7729  7.53   NaN   NaN    1.11     8.33   1.105    7.665   Cobolli F.
# 7730  3.58   NaN   NaN    1.32     3.60   1.285    3.600   Shelton B.
# 7731  4.98   NaN   NaN    1.20     5.13   1.185    4.940   Alcaraz C.
# 7732  2.85   NaN   NaN    1.47     2.93   1.435    2.865  Djokovic N.
# 7733  1.98   NaN   NaN    1.85     2.07   1.840    2.035   Alcaraz C.
#
#           PlayerB  RankA  RankB  RankDiff  WinnerBinary  MaxOddsPlayerA  \
# 7729  Djokovic N.   24.0    6.0      18.0             0            8.60
# 7730    Sinner J.   10.0    1.0       9.0             0            3.90
# 7731     Fritz T.    2.0    5.0      -3.0             1            1.24
# 7732    Sinner J.    6.0    1.0       5.0             0            3.05
# 7733    Sinner J.    2.0    1.0       1.0             0            2.07
#
#       MaxOddsPlayerB  AvgOddsPlayerA  AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  \
# 7729            1.12            7.53            1.09           0           1
# 7730            1.34            3.58            1.29           1           5
# 7731            5.25            1.17            4.98           1           0
# 7732            1.47            2.85            1.42           4           4
# 7733            1.87            1.98            1.82           8           4
#
#       H2H_Diff  WinsA  LossesA  WinsB  LossesB  WinRateA_cum  WinRateB_cum  \
# 7729        -1     59       49   1093      215      0.546296      0.835627
# 7730        -4     93       65    272       86      0.588608      0.759777
# 7731         1    239       59    289      189      0.802013      0.604603
# 7732         0   1094      215    273       86      0.835752      0.760446
# 7733         4    240       59    274       86      0.802676      0.761111
#
#       Form10A  Form10B  RestDaysA  RestDaysB    DiffWR  DiffForm  DiffRest  \
# 7729      0.7      0.9          2          2 -0.289331      -0.2         0
# 7730      0.6      0.8          2          2 -0.171169      -0.2         0
# 7731      1.0      0.9          3          3  0.197411       0.1         0
# 7732      0.9      0.8          2          2  0.075307       0.1         0
# 7733      1.0      0.8          2          2  0.041564       0.2         0
#
#       LogRankDiff  H2HDiff  ProbA_odds  ProbB_odds  OddsProbDiff  \
# 7729     1.386294       -1    0.116279    0.892857     -0.776578
# 7730     2.302585       -4    0.256410    0.746269     -0.489858
# 7731    -0.916291        1    0.806452    0.190476      0.615975
# 7732     1.791759        0    0.327869    0.680272     -0.352403
# 7733     0.693147        4    0.483092    0.534759     -0.051668
#
#       WinRateA_x_Rank  WinRateB_x_Rank  EfficiencyDiff  EloA_Global  \
# 7729         0.022762         0.139271       -0.116509  1585.915415
# 7730         0.058861         0.759777       -0.700916  1551.763916
# 7731         0.401007         0.120921        0.280086  1821.105118
# 7732         0.139292         0.760446       -0.621154  1940.668719
# 7733         0.401338         0.761111       -0.359773  1831.888904
#
#       EloB_Global  EloA_Surface  EloB_Surface  EloDiff_Global  \
# 7729  1939.233116   1569.343906   1860.199075     -353.317701
# 7730  1688.748267   1529.518201   1653.339587     -136.984350
# 7731  1732.370096   1780.072422   1691.427815       88.735023
# 7732  1697.648428   1861.618917   1661.940358      243.020291
# 7733  1713.473179   1789.984640   1676.058329      118.415725
#
#       EloDiff_Surface SurfaceText  RoundOrder
# 7729      -290.855169       Grass           6
# 7730      -123.821386       Grass           6
# 7731        88.644606       Grass           7
# 7732       199.678559       Grass           7
# 7733       113.926311       Grass           8

# %% [markdown]
# ---

# %%
train = df[df['Date'] < '2025-06-29'].copy()
test = df[(df['Date'] >= '2025-06-29') & (df['Date'] <= '2025-07-13')].copy()
train.tail()
# Out:
#       ATP    Location                Tournament        Date  Series  Court  \
# 7602   34  Eastbourne  Eastbourne International  2025-06-27       0      1
# 7603   35    Mallorca    Mallorca Championships  2025-06-27       0      1
# 7604   35    Mallorca    Mallorca Championships  2025-06-27       0      1
# 7605   34  Eastbourne  Eastbourne International  2025-06-28       0      1
# 7606   35    Mallorca    Mallorca Championships  2025-06-28       0      1
#
#       Surface       Round  Best of         Winner               Loser  WRank  \
# 7602        2  Semifinals      3.0    Brooksby J.          Humbert U.  149.0
# 7603        2  Semifinals      3.0      Moutet C.        Michelsen A.   83.0
# 7604        2  Semifinals      3.0  Griekspoor T.  Auger-Aliassime F.   34.0
# 7605        2   The Final      3.0       Fritz T.         Brooksby J.    5.0
# 7606        2   The Final      3.0  Griekspoor T.           Moutet C.   34.0
#
#       LRank   W1   L1   W2   L2   W3   L3  W4  L4  W5  L5  Wsets  Lsets  \
# 7602   20.0  6.0  7.0  6.0  4.0  6.0  4.0 NaN NaN NaN NaN    2.0    1.0
# 7603   33.0  6.0  4.0  7.0  6.0  NaN  NaN NaN NaN NaN NaN    2.0    0.0
# 7604   27.0  6.0  4.0  6.0  4.0  NaN  NaN NaN NaN NaN NaN    2.0    0.0
# 7605  149.0  7.0  5.0  6.0  1.0  NaN  NaN NaN NaN NaN NaN    2.0    0.0
# 7606   83.0  7.0  5.0  7.0  6.0  NaN  NaN NaN NaN NaN NaN    2.0    0.0
#
#         Comment  CBW  CBL  GBW  GBL  IWW  IWL  SBW  SBL  B365W  B365L  B&WW  \
# 7602  Completed  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   2.80   1.44   NaN
# 7603  Completed  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   2.40   1.57   NaN
# 7604  Completed  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   2.20   1.67   NaN
# 7605  Completed  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.30   3.60   NaN
# 7606  Completed  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.57   2.30   NaN
#
#       B&WL  EXW  EXL   PSW   PSL    WPts    LPts  UBW  UBL  LBW  LBL  SJW  \
# 7602   NaN  NaN  NaN  2.87  1.48   405.0  2195.0  NaN  NaN  NaN  NaN  NaN
# 7603   NaN  NaN  NaN  2.52  1.60   739.0  1620.0  NaN  NaN  NaN  NaN  NaN
# 7604   NaN  NaN  NaN  2.30  1.69  1535.0  1775.0  NaN  NaN  NaN  NaN  NaN
# 7605   NaN  NaN  NaN  1.30  3.89  4635.0   405.0  NaN  NaN  NaN  NaN  NaN
# 7606   NaN  NaN  NaN  1.59  2.46  1535.0   739.0  NaN  NaN  NaN  NaN  NaN
#
#       SJL  MaxW  MaxL  AvgW  AvgL  BFEW  BFEL  MaxWin  MaxLoss  AvgWin  \
# 7602  NaN  2.92  1.51  2.76  1.44   NaN   NaN    2.87     1.48   2.835
# 7603  NaN  2.52  1.66  2.39  1.56   NaN   NaN    2.52     1.60   2.460
# 7604  NaN  2.32  1.74  2.18  1.67   NaN   NaN    2.30     1.69   2.250
# 7605  NaN  1.31  4.10  1.28  3.64   NaN   NaN    1.30     3.89   1.300
# 7606  NaN  1.65  2.50  1.56  2.39   NaN   NaN    1.59     2.46   1.580
#
#       AvgLoss             PlayerA        PlayerB  RankA  RankB  RankDiff  \
# 7602    1.460         Brooksby J.     Humbert U.  149.0   20.0     129.0
# 7603    1.585        Michelsen A.      Moutet C.   33.0   83.0     -50.0
# 7604    1.680  Auger-Aliassime F.  Griekspoor T.   27.0   34.0      -7.0
# 7605    3.745         Brooksby J.       Fritz T.  149.0    5.0     144.0
# 7606    2.380       Griekspoor T.      Moutet C.   34.0   83.0     -49.0
#
#       WinnerBinary  MaxOddsPlayerA  MaxOddsPlayerB  AvgOddsPlayerA  \
# 7602             1            2.92            1.51            2.76
# 7603             0            1.66            2.52            1.56
# 7604             0            1.74            2.32            1.67
# 7605             0            4.10            1.31            3.64
# 7606             1            1.65            2.50            1.56
#
#       AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  H2H_Diff  WinsA  LossesA  WinsB  \
# 7602            1.44           0           1        -1     57       39    148
# 7603            2.39           0           0         0     55       49     77
# 7604            2.18           1           0         1    223      148    105
# 7605            1.28           1           1         0     58       39    283
# 7606            2.39           0           0         0    106       94     78
#
#       LossesB  WinRateA_cum  WinRateB_cum  Form10A  Form10B  RestDaysA  \
# 7602      130      0.593750      0.532374      0.8      0.6          1
# 7603      102      0.528846      0.430168      0.5      0.6          1
# 7604       94      0.601078      0.527638      0.6      0.7          1
# 7605      189      0.597938      0.599576      0.8      0.7          1
# 7606      102      0.530000      0.433333      0.7      0.7          1
#
#       RestDaysB    DiffWR  DiffForm  DiffRest  LogRankDiff  H2HDiff  \
# 7602          1  0.061376       0.2         0     2.008214       -1
# 7603          1  0.098679      -0.1         0    -0.922333        0
# 7604          1  0.073440      -0.1         0    -0.230524        1
# 7605          1 -0.001638       0.1         0     3.394508        0
# 7606          1  0.096667       0.0         0    -0.892480        0
#
#       ProbA_odds  ProbB_odds  OddsProbDiff  WinRateA_x_Rank  WinRateB_x_Rank  \
# 7602    0.342466    0.662252     -0.319786         0.003985         0.026619
# 7603    0.602410    0.396825      0.205584         0.016026         0.005183
# 7604    0.574713    0.431034      0.143678         0.022262         0.015519
# 7605    0.243902    0.763359     -0.519456         0.004013         0.119915
# 7606    0.606061    0.400000      0.206061         0.015588         0.005221
#
#       EfficiencyDiff  EloA_Global  EloB_Global  EloA_Surface  EloB_Surface  \
# 7602       -0.022634  1547.382539  1578.021479   1528.754762   1543.804755
# 7603        0.010843  1581.879754  1508.011997   1555.383863   1483.945010
# 7604        0.006743  1580.733744  1584.770096   1546.867135   1558.348816
# 7605       -0.115902  1564.007473  1687.802223   1543.901959   1648.838114
# 7606        0.010367  1603.735487  1526.599706   1576.110430   1501.686108
#
#       EloDiff_Global  EloDiff_Surface SurfaceText  RoundOrder
# 7602      -30.638940       -15.049993       Grass           7
# 7603       73.867757        71.438853       Grass           7
# 7604       -4.036352       -11.481682       Grass           7
# 7605     -123.794750      -104.936155       Grass           8
# 7606       77.135780        74.424322       Grass           8

# %%
print("Mida train: ", len(train))
print("Mida test: ", len(test))
# Out:
# Mida train:  7607
# Mida test:  127

# %%
# First round 
first_round = test[test['Round'] == '1st Round']
# Second round
second_round = test[test['Round'] == '2nd Round']
# Third round
third_round = test[test['Round'] == '3rd Round']
# Fourth round
fourth_round = test[test['Round'] == '4th Round']
# Quarter finals
quarter_finals = test[test['Round'] == 'Quarterfinals']
# Semi finals
semi_finals = test[test['Round'] == 'Semifinals']
# Finals
finals = test[test['Round'] == 'The Final']

print("Mida first round: ", len(first_round))
print("Mida second round: ", len(second_round))
print("Mida third round: ", len(third_round))
print("Mida fourth round: ", len(fourth_round))
print("Mida quarter finals: ", len(quarter_finals))
print("Mida semi finals: ", len(semi_finals))
print("Mida finals: ", len(finals))
# Out:
# Mida first round:  64
# Mida second round:  32
# Mida third round:  16
# Mida fourth round:  8
# Mida quarter finals:  4
# Mida semi finals:  2
# Mida finals:  1

# %% [markdown]
# ## First Round

# %%
features = [
    # Diferencias estadísticas base
    'LogRankDiff',
    'DiffWR',
    'DiffForm',
    'H2HDiff',
    'OddsProbDiff',
    'DiffRest',
    'EfficiencyDiff',
    'RankDiff',

    # Elo avanzado
    'EloDiff_Global',
    'EloDiff_Surface',

    # Contexto
    'Series',       # codificada con LabelEncoder
    'RoundOrder'    # orden real de la ronda
]

df = df.sort_values("Date", ascending=True).reset_index(drop=True)

X_train = train[features].fillna(0)
X_test = first_round[features].fillna(0)
y_train = train['WinnerBinary']
y_test = first_round['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = XGBClassifier(
    n_estimators=500,                    # Nombre total d'arbres (boosting rounds) que es construiran. 500 és un valor força alt, bo per a un bon rendiment si es controla l'overfitting.
    max_depth=6,                         # Profunditat màxima de cada arbre. 6 és un valor moderat: permet interaccions complexes sense fer els arbres excessivament profunds.
    learning_rate=0.02,                  # Taxa d'aprenentatge (eta). 0.02 és bastant baixa → aprenentatge lent i estable, ideal quan tens molts estimators (500).
    subsample=0.85,                      # Percentatge de mostres (files) que s'utilitzen per entrenar cada arbre. 0.85 = 85% → ajuda a reduir overfitting i afegeix variància (com bagging).
    colsample_bytree=0.85,               # Percentatge de columnes (variables) que s'agafen aleatòriament per cada arbre. 85% → també redueix overfitting i millora la generalització.
    min_child_weight=5,                  # Suma mínima del pes Hessiana en un node fill. Valors >1 fan el model més conservador: evita dividir nodes amb poca informació.
    gamma=0.1,                           # Minimització mínima de la funció de pèrdua necessària per fer una partició addicional (regularització per poda). 0.1 afavoreix arbres més simples.
    reg_alpha=0.1,                       # Terme de regularització L1 sobre els pesos de les fulles. Ajuda a fer sparseness i és útil quan hi ha moltes variables irrellevants.
    reg_lambda=1.0,                      # Terme de regularització L2 (més suau que L1). 1.0 és el valor per defecte i sol funcionar bé en la majoria de casos.
    random_state=42,                     # Llavor per a la reproductibilitat dels resultats (aleatorietat controlada).
    n_jobs=-1,                           # Utilitza tots els nuclis disponibles del processador per entrenar en paral·lel → molt més ràpid.
    eval_metric='logloss'                # Mètrica d'avaluació durant l'entrenament (per classificació binària/multiclasse). 'logloss' = logarithmic loss (cross-entropy).
)

tscv = TimeSeriesSplit(n_splits=5)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 0.6562
# Brier Score: 0.2387
#               precision    recall  f1-score   support
#
#            0     0.6562    0.6562    0.6562        32
#            1     0.6562    0.6562    0.6562        32
#
#     accuracy                         0.6562        64
#    macro avg     0.6562    0.6562    0.6562        64
# weighted avg     0.6562    0.6562    0.6562        64
#
# ================================================================================

# %%
from IPython.display import display

def analyze_predictions(
    df,
    y_true,
    y_pred,
    y_prob,
    date_col="Date",
    player_a_col="PlayerA",
    player_b_col="PlayerB",
    true_col_name="WinnerBinary"
):
    """
    Analiza predicciones fila a fila, mostrando:
      - Fecha, jugadores, etiqueta real, predicción, probabilidad
      - Resumen de aciertos/fallos
      - Tabla de predicciones fallidas

    Parámetros
    ----------
    df : pd.DataFrame
        DataFrame original (por ejemplo, first_round).
    y_true : array-like
        Valores verdaderos (mismo orden que df).
    y_pred : array-like
        Predicciones (0/1) alineadas con y_true.
    y_prob : array-like
        Probabilidad predicha de la clase positiva (mismo orden).
    date_col, player_a_col, player_b_col : str
        Nombres de columnas en df para mostrar contexto.
    true_col_name : str
        Nombre con el que quieres que aparezca la columna de verdad en el output.

    Returns
    -------
    results_df : pd.DataFrame
        DataFrame con todas las filas y columnas extra (Predicted, Probability, Correct, Result).
    failed_df : pd.DataFrame
        Subconjunto con solo las predicciones fallidas.
    """

    # Copia de las columnas de contexto
    results_df = df[[date_col, player_a_col, player_b_col]].copy()
    results_df[true_col_name] = y_true

    # Añadir predicciones y probabilidades
    results_df["Predicted"] = y_pred
    results_df["Probability"] = y_prob

    # Aciertos / fallos
    results_df["Correct"] = (results_df[true_col_name] == results_df["Predicted"])
    results_df["Result"] = results_df["Correct"].map({True: "✓ Correct", False: "✗ Failed"})

    # Resumen global
    total = len(results_df)
    correct = results_df["Correct"].sum()
    incorrect = total - correct
    acc = correct / total if total > 0 else 0.0

    print("RESULTADOS DETALLADOS POR FILA:")
    print("=" * 100)
    print(f"\nTotal de predicciones: {total}")
    print(f"Correctas: {correct} ({acc*100:.2f}%)")
    print(f"Fallidas: {incorrect} ({(1-acc)*100:.2f}%)")
    print("\n" + "=" * 100 + "\n")

    # Mostrar todas las filas
    pd.set_option("display.max_rows", None)
    pd.set_option("display.width", None)
    pd.set_option("display.max_columns", None)

    display(results_df[[date_col, player_a_col, player_b_col,
                        true_col_name, "Predicted", "Probability", "Result"]])

    # Mostrar solo fallos
    print("\n" + "=" * 100)
    print("PREDICCIONES FALLIDAS:")
    print("=" * 100)
    failed_df = results_df[~results_df["Correct"]]

    if len(failed_df) > 0:
        display(failed_df[[date_col, player_a_col, player_b_col,
                           true_col_name, "Predicted", "Probability"]])
    else:
        print("¡Todas las predicciones han sido correctas!")

    return results_df, failed_df

# %%
results_df, failed_df = analyze_predictions(
    df=first_round,
    y_true=first_round["WinnerBinary"].values,
    y_pred=pred,
    y_prob=prob,
    date_col="Date",
    player_a_col="PlayerA",
    player_b_col="PlayerB",
    true_col_name="WinnerBinary"
)
# Out:
# RESULTADOS DETALLADOS POR FILA:
# ====================================================================================================
#
# Total de predicciones: 64
# Correctas: 42 (65.62%)
# Fallidas: 22 (34.38%)
#
# ====================================================================================================
#             Date               PlayerA               PlayerB  WinnerBinary  \
# 7607  2025-06-30            Kopriva V.           Thompson J.             0
# 7608  2025-06-30               Fery A.            Popyrin A.             1
# 7609  2025-06-30              Quinn E.             Searle H.             1
# 7610  2025-06-30              Jarry N.               Rune H.             1
# 7611  2025-06-30  Davidovich Fokina A.               Holt B.             1
# 7612  2025-06-30           Bellucci M.           Crawford O.             1
# 7613  2025-06-30    Auger-Aliassime F.          Duckworth J.             1
# 7614  2025-06-30         Berrettini M.          Majchrzak K.             0
# 7615  2025-06-30              Garin C.            Rodesch C.             1
# 7616  2025-06-30             Borges N.          Cerundolo F.             1
# 7617  2025-06-30            Darderi L.          Safiullin R.             1
# 7618  2025-06-30            Misolic F.           Struff J.L.             0
# 7619  2025-06-30              Bergs Z.             Harris L.             0
# 7620  2025-06-30            Alcaraz C.            Fognini F.             1
# 7621  2025-06-30            Dellien H.            Lehecka J.             0
# 7622  2025-06-30        Basavareddy N.               Tien L.             0
# 7623  2025-06-30      Bautista Agut R.             Norrie C.             0
# 7624  2025-06-30           Brooksby J.         Griekspoor T.             1
# 7625  2025-06-30              Bonzi B.           Medvedev D.             1
# 7626  2025-06-30          Khachanov K.           McDonald M.             1
# 7627  2025-06-30             Moller E.             Tiafoe F.             0
# 7628  2025-06-30           Fearnley J.            Fonseca J.             0
# 7629  2025-06-30           Altmaier D.             Diallo G.             0
# 7630  2025-06-30              Royer V.          Tsitsipas S.             1
# 7631  2025-06-30              Riedi L.             Tarvet O.             0
# 7632  2025-06-30              Djere L.             Rublev A.             0
# 7633  2025-06-30             Harris B.            Lajovic D.             1
# 7634  2025-06-30          Mannarino A.          O Connell C.             1
# 7635  2025-07-01             Monday J.               Paul T.             0
# 7636  2025-07-01         Etcheverry T.   Pinnington Jones J.             0
# 7637  2025-07-01              Halys Q.           Holmgren A.             0
# 7638  2025-07-01              Nardi L.             Sinner J.             0
# 7639  2025-07-01             Opelka R.         Shevchenko A.             1
# 7640  2025-07-01              Faria J.             Sonego L.             0
# 7641  2025-07-01          Loffhagen G.           Martinez P.             0
# 7642  2025-07-01               Baez S.             Draper J.             0
# 7643  2025-07-01            Dzumhur D.             Machac T.             0
# 7644  2025-07-01         Medjedovic H.              Ofner S.             0
# 7645  2025-07-01    Carballes Baena R.          De Minaur A.             0
# 7646  2025-07-01           Marozsan F.             McCabe J.             1
# 7647  2025-07-01           Comesana F.             Moutet C.             0
# 7648  2025-07-01           Dimitrov G.           Nishioka Y.             1
# 7649  2025-07-01       Basilashvili N.            Musetti L.             1
# 7650  2025-07-01              Cilic M.          Collignon R.             1
# 7651  2025-07-01               Bolt A.            Shelton B.             0
# 7652  2025-07-01        Rinderknech A.             Zverev A.             1
# 7653  2025-07-01            Arnaldi M.  Van De Zandschulp B.             0
# 7654  2025-07-01            Humbert U.            Monfils G.             0
# 7655  2025-07-01             Navone M.         Shapovalov D.             1
# 7656  2025-07-01           Djokovic N.             Muller A.             1
# 7657  2025-07-01             Bublik A.              Munar J.             0
# 7658  2025-07-01             Goffin D.           Hijikata R.             0
# 7659  2025-07-01          Fucsovics M.          Kovacevic A.             1
# 7660  2025-07-01             Cazaux A.             Walton A.             1
# 7661  2025-07-01            Tseng C.H.              Vukic A.             0
# 7662  2025-07-01         Kecmanovic M.          Michelsen A.             1
# 7663  2025-07-01          Mochizuki S.           Zeppieri G.             1
# 7664  2025-07-01              Giron M.      Ugo Carabelli C.             1
# 7665  2025-07-01             Gaston H.             Mensik J.             0
# 7666  2025-07-01              Fritz T.            Mpetshi G.             1
# 7667  2025-07-01            Cobolli F.           Zhukayev B.             1
# 7668  2025-07-01            De Jong J.            Eubanks C.             1
# 7669  2025-07-01             Clarke J.              Evans D.             0
# 7674  2025-07-02                 Bu Y.          Nakashima B.             0
#
#       Predicted  Probability     Result
# 7607          0     0.223571  ✓ Correct
# 7608          0     0.246168   ✗ Failed
# 7609          1     0.743769  ✓ Correct
# 7610          0     0.214550   ✗ Failed
# 7611          1     0.738274  ✓ Correct
# 7612          1     0.632940  ✓ Correct
# 7613          1     0.704406  ✓ Correct
# 7614          1     0.854999   ✗ Failed
# 7615          1     0.541340  ✓ Correct
# 7616          0     0.405323   ✗ Failed
# 7617          0     0.210085   ✗ Failed
# 7618          0     0.251329  ✓ Correct
# 7619          1     0.690833   ✗ Failed
# 7620          1     0.928853  ✓ Correct
# 7621          0     0.005000  ✓ Correct
# 7622          0     0.261875  ✓ Correct
# 7623          1     0.596858   ✗ Failed
# 7624          0     0.297094   ✗ Failed
# 7625          0     0.009255   ✗ Failed
# 7626          1     0.561618  ✓ Correct
# 7627          0     0.031478  ✓ Correct
# 7628          0     0.379632  ✓ Correct
# 7629          0     0.206905  ✓ Correct
# 7630          0     0.242321   ✗ Failed
# 7631          1     0.576880   ✗ Failed
# 7632          0     0.375822  ✓ Correct
# 7633          1     0.766700  ✓ Correct
# 7634          1     0.670242  ✓ Correct
# 7635          0     0.005000  ✓ Correct
# 7636          1     0.744454   ✗ Failed
# 7637          1     0.814479   ✗ Failed
# 7638          0     0.047222  ✓ Correct
# 7639          1     0.738274  ✓ Correct
# 7640          0     0.163335  ✓ Correct
# 7641          1     0.725827   ✗ Failed
# 7642          0     0.005000  ✓ Correct
# 7643          0     0.167744  ✓ Correct
# 7644          1     0.663490   ✗ Failed
# 7645          0     0.051478  ✓ Correct
# 7646          1     0.688130  ✓ Correct
# 7647          0     0.322928  ✓ Correct
# 7648          1     0.578510  ✓ Correct
# 7649          0     0.238453   ✗ Failed
# 7650          1     0.898889  ✓ Correct
# 7651          0     0.183868  ✓ Correct
# 7652          0     0.080236   ✗ Failed
# 7653          1     0.648203   ✗ Failed
# 7654          1     0.676231   ✗ Failed
# 7655          0     0.140101   ✗ Failed
# 7656          1     0.927884  ✓ Correct
# 7657          1     0.713091   ✗ Failed
# 7658          0     0.467230  ✓ Correct
# 7659          1     0.669093  ✓ Correct
# 7660          1     0.581358  ✓ Correct
# 7661          0     0.324343  ✓ Correct
# 7662          0     0.348643   ✗ Failed
# 7663          1     0.709351  ✓ Correct
# 7664          1     0.896866  ✓ Correct
# 7665          0     0.061589  ✓ Correct
# 7666          1     0.890766  ✓ Correct
# 7667          1     0.700245  ✓ Correct
# 7668          1     0.613971  ✓ Correct
# 7669          0     0.106033  ✓ Correct
# 7674          0     0.200857  ✓ Correct
# ====================================================================================================
# PREDICCIONES FALLIDAS:
# ====================================================================================================
#             Date           PlayerA               PlayerB  WinnerBinary  \
# 7608  2025-06-30           Fery A.            Popyrin A.             1
# 7610  2025-06-30          Jarry N.               Rune H.             1
# 7614  2025-06-30     Berrettini M.          Majchrzak K.             0
# 7616  2025-06-30         Borges N.          Cerundolo F.             1
# 7617  2025-06-30        Darderi L.          Safiullin R.             1
# 7619  2025-06-30          Bergs Z.             Harris L.             0
# 7623  2025-06-30  Bautista Agut R.             Norrie C.             0
# 7624  2025-06-30       Brooksby J.         Griekspoor T.             1
# 7625  2025-06-30          Bonzi B.           Medvedev D.             1
# 7630  2025-06-30          Royer V.          Tsitsipas S.             1
# 7631  2025-06-30          Riedi L.             Tarvet O.             0
# 7636  2025-07-01     Etcheverry T.   Pinnington Jones J.             0
# 7637  2025-07-01          Halys Q.           Holmgren A.             0
# 7641  2025-07-01      Loffhagen G.           Martinez P.             0
# 7644  2025-07-01     Medjedovic H.              Ofner S.             0
# 7649  2025-07-01   Basilashvili N.            Musetti L.             1
# 7652  2025-07-01    Rinderknech A.             Zverev A.             1
# 7653  2025-07-01        Arnaldi M.  Van De Zandschulp B.             0
# 7654  2025-07-01        Humbert U.            Monfils G.             0
# 7655  2025-07-01         Navone M.         Shapovalov D.             1
# 7657  2025-07-01         Bublik A.              Munar J.             0
# 7662  2025-07-01     Kecmanovic M.          Michelsen A.             1
#
#       Predicted  Probability
# 7608          0     0.246168
# 7610          0     0.214550
# 7614          1     0.854999
# 7616          0     0.405323
# 7617          0     0.210085
# 7619          1     0.690833
# 7623          1     0.596858
# 7624          0     0.297094
# 7625          0     0.009255
# 7630          0     0.242321
# 7631          1     0.576880
# 7636          1     0.744454
# 7637          1     0.814479
# 7641          1     0.725827
# 7644          1     0.663490
# 7649          0     0.238453
# 7652          0     0.080236
# 7653          1     0.648203
# 7654          1     0.676231
# 7655          0     0.140101
# 7657          1     0.713091
# 7662          0     0.348643

# %%
import shap

xgb_model = model.calibrated_classifiers_[0].estimator

explainer = shap.TreeExplainer(xgb_model)
shap_values = explainer.shap_values(X_train_sc)
shap.summary_plot(shap_values, X_train, plot_type="bar")

# %% [markdown]
# ---
#
# ## Second Round

# %%
# Actualizar el conjunt de entrenament: afegir first_round al train actual
train_second_round = pd.concat([first_round, train], ignore_index=True)

print(f"Mida del train original: {len(train_second_round) - len(first_round)}")
print(f"Mida de first_round afegir: {len(first_round)}")
print(f"Mida del nou train: {len(train_second_round)}")
print(f"\nTrain actualizat correctament. Llest per la següent fase.")

train_second_round.head()
# Out:
# Mida del train original: 7607
# Mida de first_round afegir: 64
# Mida del nou train: 7671
#
# Train actualizat correctament. Llest per la següent fase.
#    ATP Location Tournament        Date  Series  Court  Surface      Round  \
# 0   36   London  Wimbledon  2025-06-30       2      1        2  1st Round
# 1   36   London  Wimbledon  2025-06-30       2      1        2  1st Round
# 2   36   London  Wimbledon  2025-06-30       2      1        2  1st Round
# 3   36   London  Wimbledon  2025-06-30       2      1        2  1st Round
# 4   36   London  Wimbledon  2025-06-30       2      1        2  1st Round
#
#    Best of                Winner       Loser  WRank  LRank   W1   L1   W2  \
# 0      5.0           Thompson J.  Kopriva V.   44.0   78.0  3.0  6.0  4.0
# 1      5.0               Fery A.  Popyrin A.  461.0   22.0  6.0  4.0  6.0
# 2      5.0              Quinn E.   Searle H.   89.0  421.0  4.0  6.0  6.0
# 3      5.0              Jarry N.     Rune H.  143.0    8.0  4.0  6.0  4.0
# 4      5.0  Davidovich Fokina A.     Holt B.   27.0   99.0  6.0  2.0  6.0
#
#     L2   W3   L3   W4   L4   W5   L5  Wsets  Lsets    Comment  CBW  CBL  GBW  \
# 0  6.0  6.0  3.0  7.0  6.0  6.0  1.0    3.0    2.0  Completed  NaN  NaN  NaN
# 1  1.0  4.0  6.0  6.0  4.0  NaN  NaN    3.0    1.0  Completed  NaN  NaN  NaN
# 2  2.0  7.0  6.0  6.0  2.0  NaN  NaN    3.0    1.0  Completed  NaN  NaN  NaN
# 3  6.0  7.0  5.0  6.0  3.0  6.0  4.0    3.0    2.0  Completed  NaN  NaN  NaN
# 4  4.0  7.0  5.0  NaN  NaN  NaN  NaN    3.0    0.0  Completed  NaN  NaN  NaN
#
#    GBL  IWW  IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW   PSL  \
# 0  NaN  NaN  NaN  NaN  NaN   1.40   3.00   NaN   NaN  NaN  NaN  1.43  3.03
# 1  NaN  NaN  NaN  NaN  NaN   4.33   1.22   NaN   NaN  NaN  NaN  4.45  1.24
# 2  NaN  NaN  NaN  NaN  NaN   1.44   2.80   NaN   NaN  NaN  NaN  1.47  2.85
# 3  NaN  NaN  NaN  NaN  NaN   3.75   1.29   NaN   NaN  NaN  NaN  3.76  1.30
# 4  NaN  NaN  NaN  NaN  NaN   1.22   4.33   NaN   NaN  NaN  NaN  1.23  4.58
#
#      WPts    LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW  MaxL  AvgW  AvgL  BFEW  \
# 0  1200.0   757.0  NaN  NaN  NaN  NaN  NaN  NaN  1.43  3.35  1.38  3.02   NaN
# 1    91.0  2140.0  NaN  NaN  NaN  NaN  NaN  NaN  4.50  1.28  4.02  1.24   NaN
# 2   682.0   106.0  NaN  NaN  NaN  NaN  NaN  NaN  1.48  2.94  1.44  2.75   NaN
# 3   418.0  3530.0  NaN  NaN  NaN  NaN  NaN  NaN  4.00  1.32  3.65  1.28   NaN
# 4  1845.0   600.0  NaN  NaN  NaN  NaN  NaN  NaN  1.26  4.70  1.22  4.28   NaN
#
#    BFEL  MaxWin  MaxLoss  AvgWin  AvgLoss               PlayerA      PlayerB  \
# 0   NaN    1.43     3.03   1.415    3.015            Kopriva V.  Thompson J.
# 1   NaN    4.45     1.24   4.390    1.230               Fery A.   Popyrin A.
# 2   NaN    1.47     2.85   1.455    2.825              Quinn E.    Searle H.
# 3   NaN    3.76     1.30   3.755    1.295              Jarry N.      Rune H.
# 4   NaN    1.23     4.58   1.225    4.455  Davidovich Fokina A.      Holt B.
#
#    RankA  RankB  RankDiff  WinnerBinary  MaxOddsPlayerA  MaxOddsPlayerB  \
# 0   78.0   44.0      34.0             0            3.35            1.43
# 1  461.0   22.0     439.0             1            4.50            1.28
# 2   89.0  421.0    -332.0             1            1.48            2.94
# 3  143.0    8.0     135.0             1            4.00            1.32
# 4   27.0   99.0     -72.0             1            1.26            4.70
#
#    AvgOddsPlayerA  AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  H2H_Diff  WinsA  \
# 0            3.02            1.38           0           0         0     10
# 1            4.02            1.24           0           0         0      0
# 2            1.44            2.75           0           0         0      8
# 3            3.65            1.28           0           1        -1    105
# 4            1.22            4.28           1           0         1    136
#
#    LossesA  WinsB  LossesB  WinRateA_cum  WinRateB_cum  Form10A  Form10B  \
# 0       15    144      165      0.400000      0.466019      0.5      0.3
# 1        2    100      122      0.000000      0.450450      0.0      0.6
# 2       16      0        2      0.333333      0.000000      0.4      0.0
# 3      110    157       93      0.488372      0.628000      0.3      0.6
# 4      127      3       11      0.517110      0.214286      0.5      0.1
#
#    RestDaysA  RestDaysB    DiffWR  DiffForm  DiffRest  LogRankDiff  H2HDiff  \
# 0         33         13 -0.066019       0.2        20     0.572519        0
# 1        364         12 -0.450450      -0.6       352     3.042356        0
# 2          6        363  0.333333       0.4      -357    -1.553996        0
# 3         18         10 -0.139628      -0.3         8     2.883403       -1
# 4          3          5  0.302825       0.4        -2    -1.299283        1
#
#    ProbA_odds  ProbB_odds  OddsProbDiff  WinRateA_x_Rank  WinRateB_x_Rank  \
# 0    0.298507    0.699301     -0.400793         0.005128         0.010591
# 1    0.222222    0.781250     -0.559028         0.000000         0.020475
# 2    0.675676    0.340136      0.335540         0.003745         0.000000
# 3    0.250000    0.757576     -0.507576         0.003415         0.078500
# 4    0.793651    0.212766      0.580885         0.019152         0.002165
#
#    EfficiencyDiff  EloA_Global  EloB_Global  EloA_Surface  EloB_Surface  \
# 0       -0.005463  1497.005114  1550.908994   1494.770521   1515.474145
# 1       -0.020475  1462.430240  1456.675127   1457.941218   1435.397399
# 2        0.003745  1506.589713  1458.328160   1498.630216   1453.024868
# 3       -0.075085  1487.444561  1588.522383   1464.371133   1565.198244
# 4        0.016988  1475.748612  1497.861910   1456.604103   1493.767005
#
#    EloDiff_Global  EloDiff_Surface SurfaceText  RoundOrder
# 0      -53.903880       -20.703625       Grass           1
# 1        5.755114        22.543819       Grass           1
# 2       48.261553        45.605348       Grass           1
# 3     -101.077822      -100.827111       Grass           1
# 4      -22.113298       -37.162902       Grass           1

# %%
X_train = train_second_round[features].fillna(0)
X_test = second_round[features].fillna(0)
y_train = train_second_round['WinnerBinary']
y_test = second_round['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = XGBClassifier(
    n_estimators=500,                    # Nombre total d'arbres (boosting rounds) que es construiran. 500 és un valor força alt, bo per a un bon rendiment si es controla l'overfitting.
    max_depth=6,                         # Profunditat màxima de cada arbre. 6 és un valor moderat: permet interaccions complexes sense fer els arbres excessivament profunds.
    learning_rate=0.02,                  # Taxa d'aprenentatge (eta). 0.02 és bastant baixa → aprenentatge lent i estable, ideal quan tens molts estimators (500).
    subsample=0.85,                      # Percentatge de mostres (files) que s'utilitzen per entrenar cada arbre. 0.85 = 85% → ajuda a reduir overfitting i afegeix variància (com bagging).
    colsample_bytree=0.85,               # Percentatge de columnes (variables) que s'agafen aleatòriament per cada arbre. 85% → també redueix overfitting i millora la generalització.
    min_child_weight=5,                  # Suma mínima del pes Hessiana en un node fill. Valors >1 fan el model més conservador: evita dividir nodes amb poca informació.
    gamma=0.1,                           # Minimització mínima de la funció de pèrdua necessària per fer una partició addicional (regularització per poda). 0.1 afavoreix arbres més simples.
    reg_alpha=0.1,                       # Terme de regularització L1 sobre els pesos de les fulles. Ajuda a fer sparseness i és útil quan hi ha moltes variables irrellevants.
    reg_lambda=1.0,                      # Terme de regularització L2 (més suau que L1). 1.0 és el valor per defecte i sol funcionar bé en la majoria de casos.
    random_state=42,                     # Llavor per a la reproductibilitat dels resultats (aleatorietat controlada).
    n_jobs=-1,                           # Utilitza tots els nuclis disponibles del processador per entrenar en paral·lel → molt més ràpid.
    eval_metric='logloss'                # Mètrica d'avaluació durant l'entrenament (per classificació binària/multiclasse). 'logloss' = logarithmic loss (cross-entropy).
)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 0.7188
# Brier Score: 0.2185
#               precision    recall  f1-score   support
#
#            0     0.5882    0.8333    0.6897        12
#            1     0.8667    0.6500    0.7429        20
#
#     accuracy                         0.7188        32
#    macro avg     0.7275    0.7417    0.7163        32
# weighted avg     0.7623    0.7188    0.7229        32
#
# ================================================================================

# %%
results_df, failed_df = analyze_predictions(
    df=second_round,
    y_true=second_round["WinnerBinary"].values,
    y_pred=pred,
    y_prob=prob,
    date_col="Date",
    player_a_col="PlayerA",
    player_b_col="PlayerB",
    true_col_name="WinnerBinary"
)
# Out:
# RESULTADOS DETALLADOS POR FILA:
# ====================================================================================================
#
# Total de predicciones: 32
# Correctas: 23 (71.88%)
# Fallidas: 9 (28.12%)
#
# ====================================================================================================
#             Date               PlayerA               PlayerB  WinnerBinary  \
# 7670  2025-07-02             Borges N.             Harris B.             1
# 7671  2025-07-02           Brooksby J.            Fonseca J.             0
# 7672  2025-07-02              Bonzi B.           Thompson J.             0
# 7673  2025-07-02             Diallo G.              Fritz T.             0
# 7675  2025-07-02              Jarry N.               Tien L.             1
# 7676  2025-07-02          Khachanov K.          Mochizuki S.             1
# 7677  2025-07-02            Alcaraz C.             Tarvet O.             1
# 7678  2025-07-02          Majchrzak K.              Quinn E.             1
# 7679  2025-07-02           Bellucci M.            Lehecka J.             1
# 7680  2025-07-02          Mannarino A.              Royer V.             1
# 7681  2025-07-02             Harris L.             Rublev A.             0
# 7682  2025-07-02             Norrie C.             Tiafoe F.             1
# 7683  2025-07-03          Nakashima B.             Opelka R.             1
# 7684  2025-07-03             Cazaux A.          De Minaur A.             0
# 7685  2025-07-03              Cilic M.             Draper J.             1
# 7686  2025-07-03    Auger-Aliassime F.           Struff J.L.             0
# 7687  2025-07-03            De Jong J.         Kecmanovic M.             0
# 7688  2025-07-03             Sinner J.              Vukic A.             1
# 7689  2025-07-03              Garin C.        Rinderknech A.             0
# 7690  2025-07-03              Ofner S.               Paul T.             1
# 7691  2025-07-03           Holmgren A.             Machac T.             1
# 7692  2025-07-03           Dimitrov G.             Moutet C.             1
# 7693  2025-07-03              Giron M.             Mensik J.             0
# 7694  2025-07-03           Djokovic N.              Evans D.             1
# 7695  2025-07-03            Cobolli F.   Pinnington Jones J.             1
# 7696  2025-07-03           Marozsan F.              Munar J.             0
# 7697  2025-07-03  Davidovich Fokina A.  Van De Zandschulp B.             1
# 7698  2025-07-03           Martinez P.             Navone M.             1
# 7699  2025-07-03            Darderi L.               Fery A.             1
# 7700  2025-07-03       Basilashvili N.             Sonego L.             0
# 7702  2025-07-04          Fucsovics M.            Monfils G.             1
# 7703  2025-07-04           Hijikata R.            Shelton B.             0
#
#       Predicted  Probability     Result
# 7670          1     0.658560  ✓ Correct
# 7671          0     0.313855  ✓ Correct
# 7672          1     0.613034   ✗ Failed
# 7673          0     0.212849  ✓ Correct
# 7675          1     0.594737  ✓ Correct
# 7676          1     0.915190  ✓ Correct
# 7677          1     0.745963  ✓ Correct
# 7678          0     0.489529   ✗ Failed
# 7679          0     0.083545   ✗ Failed
# 7680          1     0.691189  ✓ Correct
# 7681          0     0.291186  ✓ Correct
# 7682          0     0.445280   ✗ Failed
# 7683          1     0.638928  ✓ Correct
# 7684          0     0.037538  ✓ Correct
# 7685          0     0.170706   ✗ Failed
# 7686          1     0.694223   ✗ Failed
# 7687          0     0.274561  ✓ Correct
# 7688          1     0.961936  ✓ Correct
# 7689          0     0.412935  ✓ Correct
# 7690          0     0.160053   ✗ Failed
# 7691          0     0.301927   ✗ Failed
# 7692          1     0.638928  ✓ Correct
# 7693          0     0.414283  ✓ Correct
# 7694          1     0.930533  ✓ Correct
# 7695          1     0.741982  ✓ Correct
# 7696          0     0.496725  ✓ Correct
# 7697          1     0.763238  ✓ Correct
# 7698          0     0.410369   ✗ Failed
# 7699          1     0.530910  ✓ Correct
# 7700          0     0.386971  ✓ Correct
# 7702          1     0.535531  ✓ Correct
# 7703          0     0.425766  ✓ Correct
# ====================================================================================================
# PREDICCIONES FALLIDAS:
# ====================================================================================================
#             Date             PlayerA      PlayerB  WinnerBinary  Predicted  \
# 7672  2025-07-02            Bonzi B.  Thompson J.             0          1
# 7678  2025-07-02        Majchrzak K.     Quinn E.             1          0
# 7679  2025-07-02         Bellucci M.   Lehecka J.             1          0
# 7682  2025-07-02           Norrie C.    Tiafoe F.             1          0
# 7685  2025-07-03            Cilic M.    Draper J.             1          0
# 7686  2025-07-03  Auger-Aliassime F.  Struff J.L.             0          1
# 7690  2025-07-03            Ofner S.      Paul T.             1          0
# 7691  2025-07-03         Holmgren A.    Machac T.             1          0
# 7698  2025-07-03         Martinez P.    Navone M.             1          0
#
#       Probability
# 7672     0.613034
# 7678     0.489529
# 7679     0.083545
# 7682     0.445280
# 7685     0.170706
# 7686     0.694223
# 7690     0.160053
# 7691     0.301927
# 7698     0.410369

# %% [markdown]
# ---
#
# ## Third Round

# %%
# Actualizar el conjunto de entrenamiento: añadir first_round al train actual
train_third_round = pd.concat([second_round, train_second_round], ignore_index=True)

print(f"Tamaño del train original: {len(train_third_round) - len(second_round)}")
print(f"Tamaño de first_round añadido: {len(second_round)}")
print(f"Tamaño del nuevo train: {len(train_third_round)}")
print(f"\nTrain actualizado correctamente. Listo para la siguiente fase.")

train_third_round.head()
# Out:
# Tamaño del train original: 7671
# Tamaño de first_round añadido: 32
# Tamaño del nuevo train: 7703
#
# Train actualizado correctamente. Listo para la siguiente fase.
#    ATP Location Tournament        Date  Series  Court  Surface      Round  \
# 0   36   London  Wimbledon  2025-07-02       2      1        2  2nd Round
# 1   36   London  Wimbledon  2025-07-02       2      1        2  2nd Round
# 2   36   London  Wimbledon  2025-07-02       2      1        2  2nd Round
# 3   36   London  Wimbledon  2025-07-02       2      1        2  2nd Round
# 4   36   London  Wimbledon  2025-07-02       2      1        2  2nd Round
#
#    Best of       Winner        Loser  WRank  LRank   W1   L1   W2   L2   W3  \
# 0      5.0    Borges N.    Harris B.   37.0  151.0  6.0  3.0  6.0  4.0  7.0
# 1      5.0   Fonseca J.  Brooksby J.   54.0  101.0  6.0  4.0  5.0  7.0  6.0
# 2      5.0  Thompson J.     Bonzi B.   44.0   64.0  7.0  5.0  6.0  7.0  4.0
# 3      5.0     Fritz T.    Diallo G.    5.0   40.0  3.0  6.0  6.0  3.0  7.0
# 4      5.0     Jarry N.      Tien L.  143.0   62.0  6.0  2.0  6.0  2.0  6.0
#
#     L3   W4   L4   W5   L5  Wsets  Lsets    Comment  CBW  CBL  GBW  GBL  IWW  \
# 0  6.0  NaN  NaN  NaN  NaN    3.0    0.0  Completed  NaN  NaN  NaN  NaN  NaN
# 1  2.0  6.0  4.0  NaN  NaN    3.0    1.0  Completed  NaN  NaN  NaN  NaN  NaN
# 2  6.0  6.0  2.0  6.0  4.0    3.0    2.0  Completed  NaN  NaN  NaN  NaN  NaN
# 3  6.0  4.0  6.0  6.0  3.0    3.0    2.0  Completed  NaN  NaN  NaN  NaN  NaN
# 4  3.0  NaN  NaN  NaN  NaN    3.0    0.0  Completed  NaN  NaN  NaN  NaN  NaN
#
#    IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW   PSL    WPts  \
# 0  NaN  NaN  NaN   1.53   2.50   NaN   NaN  NaN  NaN  1.58  2.56  1400.0
# 1  NaN  NaN  NaN   1.44   2.80   NaN   NaN  NaN  NaN  1.45  3.00  1016.0
# 2  NaN  NaN  NaN   2.50   1.53   NaN   NaN  NaN  NaN  2.46  1.62  1200.0
# 3  NaN  NaN  NaN   1.30   3.60   NaN   NaN  NaN  NaN  1.32  3.76  4635.0
# 4  NaN  NaN  NaN   1.67   2.20   NaN   NaN  NaN  NaN  1.76  2.20   418.0
#
#      LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW  MaxL  AvgW  AvgL  BFEW  BFEL  \
# 0   383.0  NaN  NaN  NaN  NaN  NaN  NaN  1.60  2.62  1.56  2.40   NaN   NaN
# 1   577.0  NaN  NaN  NaN  NaN  NaN  NaN  1.49  3.00  1.45  2.76   NaN   NaN
# 2   930.0  NaN  NaN  NaN  NaN  NaN  NaN  2.66  1.62  2.52  1.52   NaN   NaN
# 3  1322.0  NaN  NaN  NaN  NaN  NaN  NaN  1.36  3.90  1.30  3.50   NaN   NaN
# 4   940.0  NaN  NaN  NaN  NaN  NaN  NaN  1.77  2.24  1.68  2.18   NaN   NaN
#
#    MaxWin  MaxLoss  AvgWin  AvgLoss      PlayerA      PlayerB  RankA  RankB  \
# 0    1.58     2.56   1.555    2.530    Borges N.    Harris B.   37.0  151.0
# 1    1.45     3.00   1.445    2.900  Brooksby J.   Fonseca J.  101.0   54.0
# 2    2.50     1.62   2.480    1.575     Bonzi B.  Thompson J.   64.0   44.0
# 3    1.32     3.76   1.310    3.680    Diallo G.     Fritz T.   40.0    5.0
# 4    1.76     2.20   1.715    2.200     Jarry N.      Tien L.  143.0   62.0
#
#    RankDiff  WinnerBinary  MaxOddsPlayerA  MaxOddsPlayerB  AvgOddsPlayerA  \
# 0    -114.0             1            1.60            2.62            1.56
# 1      47.0             0            3.00            1.49            2.76
# 2      20.0             0            1.62            2.66            1.52
# 3      35.0             0            3.90            1.36            3.50
# 4      81.0             1            1.77            2.24            1.68
#
#    AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  H2H_Diff  WinsA  LossesA  WinsB  \
# 0            2.40           0           0         0     57       64     10
# 1            1.45           0           0         0     59       40     19
# 2            2.52           0           0         0     52       68    145
# 3            1.30           0           0         0     26       23    285
# 4            2.18           0           0         0    106      110     14
#
#    LossesB  WinRateA_cum  WinRateB_cum  Form10A  Form10B  RestDaysA  \
# 0       11      0.471074      0.476190      0.6      0.3          2
# 1       16      0.595960      0.542857      0.7      0.5          2
# 2      165      0.433333      0.467742      0.3      0.4          2
# 3      189      0.530612      0.601266      0.8      0.9          2
# 4       18      0.490741      0.437500      0.4      0.5          2
#
#    RestDaysB    DiffWR  DiffForm  DiffRest  LogRankDiff  H2HDiff  ProbA_odds  \
# 0          2 -0.005116       0.3         0    -1.406362        0    0.625000
# 1          2  0.053102       0.2         0     0.626136        0    0.333333
# 2          2 -0.034409      -0.1         0     0.374693        0    0.617284
# 3          1 -0.070654      -0.1         1     2.079442        0    0.256410
# 4          2  0.053241      -0.1         0     0.835710        0    0.564972
#
#    ProbB_odds  OddsProbDiff  WinRateA_x_Rank  WinRateB_x_Rank  EfficiencyDiff  \
# 0    0.381679      0.243321         0.012732         0.003154        0.009578
# 1    0.671141     -0.337808         0.005901         0.010053       -0.004152
# 2    0.375940      0.241344         0.006771         0.010630       -0.003860
# 3    0.735294     -0.478884         0.013265         0.120253       -0.106988
# 4    0.446429      0.118543         0.003432         0.007056       -0.003625
#
#    EloA_Global  EloB_Global  EloA_Surface  EloB_Surface  EloDiff_Global  \
# 0  1443.366752  1525.854230   1428.866318   1509.300230      -82.487478
# 1  1578.723846  1490.010182   1556.106132   1482.365395       88.713664
# 2  1461.272702  1567.723311   1441.917075   1533.501106     -106.450609
# 3  1555.889530  1699.103584   1538.636656   1659.642294     -143.214054
# 4  1506.705418  1525.875603   1482.890986   1517.575855      -19.170186
#
#    EloDiff_Surface SurfaceText  RoundOrder
# 0       -80.433911       Grass           2
# 1        73.740737       Grass           2
# 2       -91.584030       Grass           2
# 3      -121.005638       Grass           2
# 4       -34.684869       Grass           2

# %%
X_train = train_third_round[features].fillna(0)
X_test = third_round[features].fillna(0)
y_train = train_third_round['WinnerBinary']
y_test = third_round['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = XGBClassifier(
    n_estimators=500,                    # Nombre total d'arbres (boosting rounds) que es construiran. 500 és un valor força alt, bo per a un bon rendiment si es controla l'overfitting.
    max_depth=6,                         # Profunditat màxima de cada arbre. 6 és un valor moderat: permet interaccions complexes sense fer els arbres excessivament profunds.
    learning_rate=0.02,                  # Taxa d'aprenentatge (eta). 0.02 és bastant baixa → aprenentatge lent i estable, ideal quan tens molts estimators (500).
    subsample=0.85,                      # Percentatge de mostres (files) que s'utilitzen per entrenar cada arbre. 0.85 = 85% → ajuda a reduir overfitting i afegeix variància (com bagging).
    colsample_bytree=0.85,               # Percentatge de columnes (variables) que s'agafen aleatòriament per cada arbre. 85% → també redueix overfitting i millora la generalització.
    min_child_weight=5,                  # Suma mínima del pes Hessiana en un node fill. Valors >1 fan el model més conservador: evita dividir nodes amb poca informació.
    gamma=0.1,                           # Minimització mínima de la funció de pèrdua necessària per fer una partició addicional (regularització per poda). 0.1 afavoreix arbres més simples.
    reg_alpha=0.1,                       # Terme de regularització L1 sobre els pesos de les fulles. Ajuda a fer sparseness i és útil quan hi ha moltes variables irrellevants.
    reg_lambda=1.0,                      # Terme de regularització L2 (més suau que L1). 1.0 és el valor per defecte i sol funcionar bé en la majoria de casos.
    random_state=42,                     # Llavor per a la reproductibilitat dels resultats (aleatorietat controlada).
    n_jobs=-1,                           # Utilitza tots els nuclis disponibles del processador per entrenar en paral·lel → molt més ràpid.
    eval_metric='logloss'                # Mètrica d'avaluació durant l'entrenament (per classificació binària/multiclasse). 'logloss' = logarithmic loss (cross-entropy).
)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 0.7500
# Brier Score: 0.1578
#               precision    recall  f1-score   support
#
#            0     0.7778    0.7778    0.7778         9
#            1     0.7143    0.7143    0.7143         7
#
#     accuracy                         0.7500        16
#    macro avg     0.7460    0.7460    0.7460        16
# weighted avg     0.7500    0.7500    0.7500        16
#
# ================================================================================

# %%
results_df, failed_df = analyze_predictions(
    df=third_round,
    y_true=third_round["WinnerBinary"].values,
    y_pred=pred,
    y_prob=prob,
    date_col="Date",
    player_a_col="PlayerA",
    player_b_col="PlayerB",
    true_col_name="WinnerBinary"
)
# Out:
# RESULTADOS DETALLADOS POR FILA:
# ====================================================================================================
#
# Total de predicciones: 16
# Correctas: 12 (75.00%)
# Fallidas: 4 (25.00%)
#
# ====================================================================================================
#             Date               PlayerA         PlayerB  WinnerBinary  \
# 7701  2025-07-04            Darderi L.     Thompson J.             0
# 7704  2025-07-04             Borges N.    Khachanov K.             0
# 7705  2025-07-04          Majchrzak K.  Rinderknech A.             1
# 7706  2025-07-04  Davidovich Fokina A.        Fritz T.             0
# 7707  2025-07-04            Alcaraz C.     Struff J.L.             1
# 7708  2025-07-04           Bellucci M.       Norrie C.             0
# 7709  2025-07-04          Mannarino A.       Rublev A.             0
# 7710  2025-07-04            Fonseca J.        Jarry N.             0
# 7711  2025-07-05            Cobolli F.       Mensik J.             1
# 7712  2025-07-05          Nakashima B.       Sonego L.             0
# 7713  2025-07-05          De Minaur A.     Holmgren A.             1
# 7714  2025-07-05          Fucsovics M.      Shelton B.             0
# 7715  2025-07-05           Dimitrov G.        Ofner S.             1
# 7716  2025-07-05              Cilic M.        Munar J.             1
# 7717  2025-07-05           Martinez P.       Sinner J.             0
# 7718  2025-07-05           Djokovic N.   Kecmanovic M.             1
#
#       Predicted  Probability     Result
# 7701          0     0.384932  ✓ Correct
# 7704          0     0.366365  ✓ Correct
# 7705          0     0.445872   ✗ Failed
# 7706          0     0.292478  ✓ Correct
# 7707          1     0.950917  ✓ Correct
# 7708          0     0.306775  ✓ Correct
# 7709          0     0.355816  ✓ Correct
# 7710          1     0.736691   ✗ Failed
# 7711          0     0.378058   ✗ Failed
# 7712          1     0.690729   ✗ Failed
# 7713          1     0.897242  ✓ Correct
# 7714          0     0.242251  ✓ Correct
# 7715          1     0.811667  ✓ Correct
# 7716          1     0.662385  ✓ Correct
# 7717          0     0.035207  ✓ Correct
# 7718          1     0.988624  ✓ Correct
# ====================================================================================================
# PREDICCIONES FALLIDAS:
# ====================================================================================================
#             Date       PlayerA         PlayerB  WinnerBinary  Predicted  \
# 7705  2025-07-04  Majchrzak K.  Rinderknech A.             1          0
# 7710  2025-07-04    Fonseca J.        Jarry N.             0          1
# 7711  2025-07-05    Cobolli F.       Mensik J.             1          0
# 7712  2025-07-05  Nakashima B.       Sonego L.             0          1
#
#       Probability
# 7705     0.445872
# 7710     0.736691
# 7711     0.378058
# 7712     0.690729

# %% [markdown]
# ---
#
# ## Fourth Round

# %%
# Actualizar el conjunto de entrenamiento: añadir first_round al train actual
train_fourth_round = pd.concat([third_round, train_third_round], ignore_index=True)

print(f"Tamaño del train original: {len(train_fourth_round) - len(third_round)}")
print(f"Tamaño de first_round añadido: {len(third_round)}")
print(f"Tamaño del nuevo train: {len(train_fourth_round)}")
print(f"\nTrain actualizado correctamente. Listo para la siguiente fase.")

train_fourth_round.head()
# Out:
# Tamaño del train original: 7703
# Tamaño de first_round añadido: 16
# Tamaño del nuevo train: 7719
#
# Train actualizado correctamente. Listo para la siguiente fase.
#    ATP Location Tournament        Date  Series  Court  Surface      Round  \
# 0   36   London  Wimbledon  2025-07-04       2      1        2  3rd Round
# 1   36   London  Wimbledon  2025-07-04       2      1        2  3rd Round
# 2   36   London  Wimbledon  2025-07-04       2      1        2  3rd Round
# 3   36   London  Wimbledon  2025-07-04       2      1        2  3rd Round
# 4   36   London  Wimbledon  2025-07-04       2      1        2  3rd Round
#
#    Best of        Winner                 Loser  WRank  LRank   W1   L1   W2  \
# 0      5.0   Thompson J.            Darderi L.   44.0   59.0  6.0  4.0  6.0
# 1      5.0  Khachanov K.             Borges N.   20.0   37.0  7.0  6.0  4.0
# 2      5.0  Majchrzak K.        Rinderknech A.  109.0   72.0  6.0  3.0  7.0
# 3      5.0      Fritz T.  Davidovich Fokina A.    5.0   27.0  6.0  4.0  6.0
# 4      5.0    Alcaraz C.           Struff J.L.    2.0  125.0  6.0  1.0  3.0
#
#     L2   W3   L3   W4   L4   W5   L5  Wsets  Lsets    Comment  CBW  CBL  GBW  \
# 0  4.0  3.0  6.0  6.0  3.0  NaN  NaN    3.0    1.0  Completed  NaN  NaN  NaN
# 1  6.0  4.0  6.0  6.0  3.0  7.0  6.0    3.0    2.0  Completed  NaN  NaN  NaN
# 2  6.0  7.0  6.0  NaN  NaN  NaN  NaN    3.0    0.0  Completed  NaN  NaN  NaN
# 3  3.0  6.0  7.0  6.0  1.0  NaN  NaN    3.0    1.0  Completed  NaN  NaN  NaN
# 4  6.0  6.0  3.0  6.0  4.0  NaN  NaN    3.0    1.0  Completed  NaN  NaN  NaN
#
#    GBL  IWW  IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW    PSL  \
# 0  NaN  NaN  NaN  NaN  NaN   1.67   2.10   NaN   NaN  NaN  NaN  1.79   2.15
# 1  NaN  NaN  NaN  NaN  NaN   1.40   3.00   NaN   NaN  NaN  NaN  1.44   3.03
# 2  NaN  NaN  NaN  NaN  NaN   1.91   1.90   NaN   NaN  NaN  NaN  2.07   1.85
# 3  NaN  NaN  NaN  NaN  NaN   1.25   3.75   NaN   NaN  NaN  NaN  1.30   3.92
# 4  NaN  NaN  NaN  NaN  NaN   1.04  11.00   NaN   NaN  NaN  NaN  1.05  15.53
#
#      WPts    LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW   MaxL  AvgW   AvgL  \
# 0  1200.0   989.0  NaN  NaN  NaN  NaN  NaN  NaN  1.82   2.20  1.71   2.11
# 1  2240.0  1400.0  NaN  NaN  NaN  NaN  NaN  NaN  1.48   3.05  1.41   2.89
# 2   527.0   873.0  NaN  NaN  NaN  NaN  NaN  NaN  2.10   1.90  2.00   1.80
# 3  4635.0  1845.0  NaN  NaN  NaN  NaN  NaN  NaN  1.34   3.92  1.28   3.66
# 4  9300.0   475.0  NaN  NaN  NaN  NaN  NaN  NaN  1.05  18.00  1.03  12.61
#
#    BFEW  BFEL  MaxWin  MaxLoss  AvgWin  AvgLoss               PlayerA  \
# 0   NaN   NaN    1.79     2.15   1.730    2.125            Darderi L.
# 1   NaN   NaN    1.44     3.03   1.420    3.015             Borges N.
# 2   NaN   NaN    2.07     1.90   1.990    1.875          Majchrzak K.
# 3   NaN   NaN    1.30     3.92   1.275    3.835  Davidovich Fokina A.
# 4   NaN   NaN    1.05    15.53   1.045   13.265            Alcaraz C.
#
#           PlayerB  RankA  RankB  RankDiff  WinnerBinary  MaxOddsPlayerA  \
# 0     Thompson J.   59.0   44.0      15.0             0            2.20
# 1    Khachanov K.   37.0   20.0      17.0             0            3.05
# 2  Rinderknech A.  109.0   72.0      37.0             1            2.10
# 3        Fritz T.   27.0    5.0      22.0             0            3.92
# 4     Struff J.L.    2.0  125.0    -123.0             1            1.05
#
#    MaxOddsPlayerB  AvgOddsPlayerA  AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  \
# 0            1.82            2.11            1.71           0           0
# 1            1.48            2.89            1.41           0           1
# 2            1.90            2.00            1.80           0           0
# 3            1.34            3.66            1.28           3           2
# 4           18.00            1.03           12.61           3           1
#
#    H2H_Diff  WinsA  LossesA  WinsB  LossesB  WinRateA_cum  WinRateB_cum  \
# 0         0     41       43    146      165      0.488095      0.469453
# 1        -1     58       64    285      205      0.475410      0.581633
# 2         0     24       35     81       95      0.406780      0.460227
# 3         1    138      127    286      189      0.520755      0.602105
# 4         2    236       59    208      241      0.800000      0.463252
#
#    Form10A  Form10B  RestDaysA  RestDaysB    DiffWR  DiffForm  DiffRest  \
# 0      0.4      0.5          1          2  0.018642      -0.1        -1
# 1      0.6      0.7          2          2 -0.106223      -0.1         0
# 2      0.5      0.6          2          1 -0.053448      -0.1         1
# 3      0.7      0.9          1          2 -0.081351      -0.2        -1
# 4      1.0      0.4          2          1  0.336748       0.6         1
#
#    LogRankDiff  H2HDiff  ProbA_odds  ProbB_odds  OddsProbDiff  \
# 0     0.293348        0    0.454545    0.549451     -0.094905
# 1     0.615186       -1    0.327869    0.675676     -0.347807
# 2     0.414682        0    0.476190    0.526316     -0.050125
# 3     1.686399        1    0.255102    0.746269     -0.491167
# 4    -4.135167        2    0.952381    0.055556      0.896825
#
#    WinRateA_x_Rank  WinRateB_x_Rank  EfficiencyDiff  EloA_Global  EloB_Global  \
# 0         0.008273         0.010669       -0.002397  1490.838344  1577.898444
# 1         0.012849         0.029082       -0.016233  1461.871117  1607.720098
# 2         0.003732         0.006392       -0.002660  1495.034389  1496.385048
# 3         0.019287         0.120421       -0.101134  1528.970909  1707.759945
# 4         0.400000         0.003706        0.396294  1808.905182  1557.455951
#
#    EloA_Surface  EloB_Surface  EloDiff_Global  EloDiff_Surface SurfaceText  \
# 0   1476.793472   1543.536533      -87.060100       -66.743062       Grass
# 1   1446.566653   1573.316186     -145.848980      -126.749534       Grass
# 2   1481.576308   1471.275067       -1.350659        10.301241       Grass
# 3   1509.092212   1668.348596     -178.789036      -159.256383       Grass
# 4   1770.114390   1525.673558      251.449231       244.440832       Grass
#
#    RoundOrder
# 0           3
# 1           3
# 2           3
# 3           3
# 4           3

# %%
X_train = train_fourth_round[features].fillna(0)
X_test = fourth_round[features].fillna(0)
y_train = train_fourth_round['WinnerBinary']
y_test = fourth_round['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = XGBClassifier(
    n_estimators=500,                    # Nombre total d'arbres (boosting rounds) que es construiran. 500 és un valor força alt, bo per a un bon rendiment si es controla l'overfitting.
    max_depth=6,                         # Profunditat màxima de cada arbre. 6 és un valor moderat: permet interaccions complexes sense fer els arbres excessivament profunds.
    learning_rate=0.02,                  # Taxa d'aprenentatge (eta). 0.02 és bastant baixa → aprenentatge lent i estable, ideal quan tens molts estimators (500).
    subsample=0.85,                      # Percentatge de mostres (files) que s'utilitzen per entrenar cada arbre. 0.85 = 85% → ajuda a reduir overfitting i afegeix variància (com bagging).
    colsample_bytree=0.85,               # Percentatge de columnes (variables) que s'agafen aleatòriament per cada arbre. 85% → també redueix overfitting i millora la generalització.
    min_child_weight=5,                  # Suma mínima del pes Hessiana en un node fill. Valors >1 fan el model més conservador: evita dividir nodes amb poca informació.
    gamma=0.1,                           # Minimització mínima de la funció de pèrdua necessària per fer una partició addicional (regularització per poda). 0.1 afavoreix arbres més simples.
    reg_alpha=0.1,                       # Terme de regularització L1 sobre els pesos de les fulles. Ajuda a fer sparseness i és útil quan hi ha moltes variables irrellevants.
    reg_lambda=1.0,                      # Terme de regularització L2 (més suau que L1). 1.0 és el valor per defecte i sol funcionar bé en la majoria de casos.
    random_state=42,                     # Llavor per a la reproductibilitat dels resultats (aleatorietat controlada).
    n_jobs=-1,                           # Utilitza tots els nuclis disponibles del processador per entrenar en paral·lel → molt més ràpid.
    eval_metric='logloss'                # Mètrica d'avaluació durant l'entrenament (per classificació binària/multiclasse). 'logloss' = logarithmic loss (cross-entropy).
)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 0.7500
# Brier Score: 0.1340
#               precision    recall  f1-score   support
#
#            0     1.0000    0.5000    0.6667         4
#            1     0.6667    1.0000    0.8000         4
#
#     accuracy                         0.7500         8
#    macro avg     0.8333    0.7500    0.7333         8
# weighted avg     0.8333    0.7500    0.7333         8
#
# ================================================================================

# %%
results_df, failed_df = analyze_predictions(
    df=fourth_round,
    y_true=fourth_round["WinnerBinary"].values,
    y_pred=pred,
    y_prob=prob,
    date_col="Date",
    player_a_col="PlayerA",
    player_b_col="PlayerB",
    true_col_name="WinnerBinary"
)
# Out:
# RESULTADOS DETALLADOS POR FILA:
# ====================================================================================================
#
# Total de predicciones: 8
# Correctas: 6 (75.00%)
# Fallidas: 2 (25.00%)
#
# ====================================================================================================
#             Date       PlayerA       PlayerB  WinnerBinary  Predicted  \
# 7719  2025-07-06    Alcaraz C.     Rublev A.             1          1
# 7720  2025-07-06  Khachanov K.  Majchrzak K.             1          1
# 7721  2025-07-06      Jarry N.     Norrie C.             0          1
# 7722  2025-07-06      Fritz T.   Thompson J.             1          1
# 7723  2025-07-07      Cilic M.    Cobolli F.             0          1
# 7724  2025-07-07    Shelton B.     Sonego L.             1          1
# 7725  2025-07-07   Dimitrov G.     Sinner J.             0          0
# 7726  2025-07-07  De Minaur A.   Djokovic N.             0          0
#
#       Probability     Result
# 7719     0.994118  ✓ Correct
# 7720     0.668462  ✓ Correct
# 7721     0.527664   ✗ Failed
# 7722     0.941669  ✓ Correct
# 7723     0.673318   ✗ Failed
# 7724     0.634776  ✓ Correct
# 7725     0.063651  ✓ Correct
# 7726     0.299660  ✓ Correct
# ====================================================================================================
# PREDICCIONES FALLIDAS:
# ====================================================================================================
#             Date   PlayerA     PlayerB  WinnerBinary  Predicted  Probability
# 7721  2025-07-06  Jarry N.   Norrie C.             0          1     0.527664
# 7723  2025-07-07  Cilic M.  Cobolli F.             0          1     0.673318

# %% [markdown]
# ---
#
# ## Quarter Finals

# %%
# Actualizar el conjunto de entrenamiento: añadir first_round al train actual
train_quarter_finals = pd.concat([fourth_round, train_fourth_round], ignore_index=True)

print(f"Tamaño del train original: {len(train_quarter_finals) - len(fourth_round)}")
print(f"Tamaño de first_round añadido: {len(fourth_round)}")
print(f"Tamaño del nuevo train: {len(train_quarter_finals)}")
print(f"\nTrain actualizado correctamente. Listo para la siguiente fase.")

train_quarter_finals.head()
# Out:
# Tamaño del train original: 7719
# Tamaño de first_round añadido: 8
# Tamaño del nuevo train: 7727
#
# Train actualizado correctamente. Listo para la siguiente fase.
#    ATP Location Tournament        Date  Series  Court  Surface      Round  \
# 0   36   London  Wimbledon  2025-07-06       2      1        2  4th Round
# 1   36   London  Wimbledon  2025-07-06       2      1        2  4th Round
# 2   36   London  Wimbledon  2025-07-06       2      1        2  4th Round
# 3   36   London  Wimbledon  2025-07-06       2      1        2  4th Round
# 4   36   London  Wimbledon  2025-07-07       2      1        2  4th Round
#
#    Best of        Winner         Loser  WRank  LRank   W1   L1   W2   L2   W3  \
# 0      5.0    Alcaraz C.     Rublev A.    2.0   14.0  6.0  7.0  6.0  3.0  6.0
# 1      5.0  Khachanov K.  Majchrzak K.   20.0  109.0  6.0  4.0  6.0  2.0  6.0
# 2      5.0     Norrie C.      Jarry N.   61.0  143.0  6.0  3.0  7.0  6.0  6.0
# 3      5.0      Fritz T.   Thompson J.    5.0   44.0  6.0  1.0  3.0  0.0  NaN
# 4      5.0    Cobolli F.      Cilic M.   24.0   83.0  6.0  4.0  6.0  4.0  6.0
#
#     L3   W4   L4   W5   L5  Wsets  Lsets    Comment  CBW  CBL  GBW  GBL  IWW  \
# 0  4.0  6.0  4.0  NaN  NaN    3.0    1.0  Completed  NaN  NaN  NaN  NaN  NaN
# 1  3.0  NaN  NaN  NaN  NaN    3.0    0.0  Completed  NaN  NaN  NaN  NaN  NaN
# 2  7.0  6.0  7.0  6.0  3.0    3.0    2.0  Completed  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN    1.0    0.0    Retired  NaN  NaN  NaN  NaN  NaN
# 4  7.0  7.0  6.0  NaN  NaN    3.0    1.0  Completed  NaN  NaN  NaN  NaN  NaN
#
#    IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW   PSL    WPts  \
# 0  NaN  NaN  NaN   1.08   7.00   NaN   NaN  NaN  NaN  1.10  8.57  9300.0
# 1  NaN  NaN  NaN   1.36   3.20   NaN   NaN  NaN  NaN  1.38  3.36  2240.0
# 2  NaN  NaN  NaN   1.83   1.91   NaN   NaN  NaN  NaN  1.87  2.04   952.0
# 3  NaN  NaN  NaN   1.14   5.50   NaN   NaN  NaN  NaN  1.15  6.36  4635.0
# 4  NaN  NaN  NaN   1.83   2.00   NaN   NaN  NaN  NaN  1.88  2.03  2035.0
#
#      LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW  MaxL  AvgW  AvgL  BFEW  BFEL  \
# 0  2920.0  NaN  NaN  NaN  NaN  NaN  NaN  1.11  9.40  1.09  7.50   NaN   NaN
# 1   527.0  NaN  NaN  NaN  NaN  NaN  NaN  1.40  3.40  1.35  3.19   NaN   NaN
# 2   418.0  NaN  NaN  NaN  NaN  NaN  NaN  2.10  2.08  1.84  1.96   NaN   NaN
# 3  1200.0  NaN  NaN  NaN  NaN  NaN  NaN  1.16  6.80  1.14  5.64   NaN   NaN
# 4   722.0  NaN  NaN  NaN  NaN  NaN  NaN  1.89  2.10  1.79  2.01   NaN   NaN
#
#    MaxWin  MaxLoss  AvgWin  AvgLoss       PlayerA       PlayerB  RankA  RankB  \
# 0    1.10     8.57   1.090    7.785    Alcaraz C.     Rublev A.    2.0   14.0
# 1    1.38     3.36   1.370    3.280  Khachanov K.  Majchrzak K.   20.0  109.0
# 2    1.87     2.04   1.850    1.975      Jarry N.     Norrie C.  143.0   61.0
# 3    1.15     6.36   1.145    5.930      Fritz T.   Thompson J.    5.0   44.0
# 4    1.88     2.03   1.855    2.015      Cilic M.    Cobolli F.   83.0   24.0
#
#    RankDiff  WinnerBinary  MaxOddsPlayerA  MaxOddsPlayerB  AvgOddsPlayerA  \
# 0     -12.0             1            1.11            9.40            1.09
# 1     -89.0             1            1.40            3.40            1.35
# 2      82.0             0            2.08            2.10            1.96
# 3     -39.0             1            1.16            6.80            1.14
# 4      59.0             0            2.10            1.89            2.01
#
#    AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  H2H_Diff  WinsA  LossesA  WinsB  \
# 0            7.50           2           1         1    237       59    337
# 1            3.19           3           0         3    286      205     25
# 2            1.84           1           0         1    108      110    215
# 3            5.64           1           1         0    287      189    147
# 4            1.79           0           2        -2    556      323     58
#
#    LossesB  WinRateA_cum  WinRateB_cum  Form10A  Form10B  RestDaysA  \
# 0      188      0.800676      0.641905      1.0      0.7          2
# 1       35      0.582485      0.416667      0.7      0.6          2
# 2      156      0.495413      0.579515      0.5      0.6          2
# 3      165      0.602941      0.471154      0.9      0.5          2
# 4       49      0.632537      0.542056      0.5      0.7          2
#
#    RestDaysB    DiffWR  DiffForm  DiffRest  LogRankDiff  H2HDiff  ProbA_odds  \
# 0          2  0.158771       0.3         0    -1.945910        1    0.900901
# 1          2  0.165818       0.1         0    -1.695616        3    0.714286
# 2          2 -0.084102      -0.1         0     0.851971        1    0.480769
# 3          2  0.131787       0.4         0    -2.174752        0    0.862069
# 4          2  0.090481      -0.2         0     1.240787       -2    0.476190
#
#    ProbB_odds  OddsProbDiff  WinRateA_x_Rank  WinRateB_x_Rank  EfficiencyDiff  \
# 0    0.106383      0.794518         0.400338         0.045850        0.354487
# 1    0.294118      0.420168         0.029124         0.003823        0.025302
# 2    0.476190      0.004579         0.003464         0.009500       -0.006036
# 3    0.147059      0.715010         0.120588         0.010708        0.109880
# 4    0.529101     -0.052910         0.007621         0.022586       -0.014965
#
#    EloA_Global  EloB_Global  EloA_Surface  EloB_Surface  EloDiff_Global  \
# 0  1811.958925  1649.303628   1772.431327   1614.953967      162.655297
# 1  1616.322216  1520.374896   1581.881337   1505.298845       95.947320
# 2  1556.753588  1604.802715   1533.665233   1569.465233      -48.049127
# 3  1712.378734  1588.874387   1672.615199   1554.619894      123.504347
# 4  1767.584060  1570.980643   1705.444237   1556.305961      196.603417
#
#    EloDiff_Surface SurfaceText  RoundOrder
# 0       157.477361       Grass           4
# 1        76.582492       Grass           4
# 2       -35.800000       Grass           4
# 3       117.995306       Grass           4
# 4       149.138276       Grass           4

# %%
X_train = train_quarter_finals[features].fillna(0)
X_test = quarter_finals[features].fillna(0)
y_train = train_quarter_finals['WinnerBinary']
y_test = quarter_finals['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = XGBClassifier(
    n_estimators=500,                    # Nombre total d'arbres (boosting rounds) que es construiran. 500 és un valor força alt, bo per a un bon rendiment si es controla l'overfitting.
    max_depth=6,                         # Profunditat màxima de cada arbre. 6 és un valor moderat: permet interaccions complexes sense fer els arbres excessivament profunds.
    learning_rate=0.02,                  # Taxa d'aprenentatge (eta). 0.02 és bastant baixa → aprenentatge lent i estable, ideal quan tens molts estimators (500).
    subsample=0.85,                      # Percentatge de mostres (files) que s'utilitzen per entrenar cada arbre. 0.85 = 85% → ajuda a reduir overfitting i afegeix variància (com bagging).
    colsample_bytree=0.85,               # Percentatge de columnes (variables) que s'agafen aleatòriament per cada arbre. 85% → també redueix overfitting i millora la generalització.
    min_child_weight=5,                  # Suma mínima del pes Hessiana en un node fill. Valors >1 fan el model més conservador: evita dividir nodes amb poca informació.
    gamma=0.1,                           # Minimització mínima de la funció de pèrdua necessària per fer una partició addicional (regularització per poda). 0.1 afavoreix arbres més simples.
    reg_alpha=0.1,                       # Terme de regularització L1 sobre els pesos de les fulles. Ajuda a fer sparseness i és útil quan hi ha moltes variables irrellevants.
    reg_lambda=1.0,                      # Terme de regularització L2 (més suau que L1). 1.0 és el valor per defecte i sol funcionar bé en la majoria de casos.
    random_state=42,                     # Llavor per a la reproductibilitat dels resultats (aleatorietat controlada).
    n_jobs=-1,                           # Utilitza tots els nuclis disponibles del processador per entrenar en paral·lel → molt més ràpid.
    eval_metric='logloss'                # Mètrica d'avaluació durant l'entrenament (per classificació binària/multiclasse). 'logloss' = logarithmic loss (cross-entropy).
)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 1.0000
# Brier Score: 0.0384
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000         2
#            1     1.0000    1.0000    1.0000         2
#
#     accuracy                         1.0000         4
#    macro avg     1.0000    1.0000    1.0000         4
# weighted avg     1.0000    1.0000    1.0000         4
#
# ================================================================================

# %% [markdown]
# ---
#
# ## Semi Finals

# %%
# Actualizar el conjunto de entrenamiento: añadir first_round al train actual
train_semi_finals = pd.concat([quarter_finals, train_quarter_finals], ignore_index=True)

print(f"Tamaño del train original: {len(train_semi_finals) - len(quarter_finals)}")
print(f"Tamaño de first_round añadido: {len(quarter_finals)}")
print(f"Tamaño del nuevo train: {len(train_semi_finals)}")
print(f"\nTrain actualizado correctamente. Listo para la siguiente fase.")

train_semi_finals.head()
# Out:
# Tamaño del train original: 7727
# Tamaño de first_round añadido: 4
# Tamaño del nuevo train: 7731
#
# Train actualizado correctamente. Listo para la siguiente fase.
#    ATP Location Tournament        Date  Series  Court  Surface          Round  \
# 0   36   London  Wimbledon  2025-07-08       2      1        2  Quarterfinals
# 1   36   London  Wimbledon  2025-07-08       2      1        2  Quarterfinals
# 2   36   London  Wimbledon  2025-07-09       2      1        2  Quarterfinals
# 3   36   London  Wimbledon  2025-07-09       2      1        2  Quarterfinals
# 4   36   London  Wimbledon  2025-07-06       2      1        2      4th Round
#
#    Best of       Winner         Loser  WRank LRank   W1   L1   W2   L2   W3  \
# 0      5.0   Alcaraz C.     Norrie C.    2.0  61.0  6.0  2.0  6.0  3.0  6.0
# 1      5.0     Fritz T.  Khachanov K.    5.0  20.0  6.0  3.0  6.0  4.0  1.0
# 2      5.0  Djokovic N.    Cobolli F.    6.0  24.0  6.0  7.0  6.0  2.0  7.0
# 3      5.0    Sinner J.    Shelton B.    1.0  10.0  7.0  6.0  6.0  4.0  6.0
# 4      5.0   Alcaraz C.     Rublev A.    2.0  14.0  6.0  7.0  6.0  3.0  6.0
#
#     L3   W4   L4  W5  L5  Wsets  Lsets    Comment  CBW  CBL  GBW  GBL  IWW  \
# 0  3.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN  NaN  NaN
# 1  6.0  7.0  6.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN  NaN  NaN
# 2  5.0  6.0  4.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN  NaN  NaN
# 3  4.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN  NaN  NaN
# 4  4.0  6.0  4.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN  NaN  NaN
#
#    IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW    PSL     WPts  \
# 0  NaN  NaN  NaN   1.06   9.00   NaN   NaN  NaN  NaN  1.07  10.89   9300.0
# 1  NaN  NaN  NaN   1.29   3.75   NaN   NaN  NaN  NaN  1.29   4.06   4635.0
# 2  NaN  NaN  NaN   1.10   7.00   NaN   NaN  NaN  NaN  1.11   8.33   4630.0
# 3  NaN  NaN  NaN   1.25   3.60   NaN   NaN  NaN  NaN  1.32   3.60  10430.0
# 4  NaN  NaN  NaN   1.08   7.00   NaN   NaN  NaN  NaN  1.10   8.57   9300.0
#
#      LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW  MaxL  AvgW  AvgL  BFEW  BFEL  \
# 0   952.0  NaN  NaN  NaN  NaN  NaN  NaN  1.07  13.5  1.05  9.96   NaN   NaN
# 1  2240.0  NaN  NaN  NaN  NaN  NaN  NaN  1.31   4.2  1.27  3.76   NaN   NaN
# 2  2035.0  NaN  NaN  NaN  NaN  NaN  NaN  1.12   8.6  1.09  7.53   NaN   NaN
# 3  3130.0  NaN  NaN  NaN  NaN  NaN  NaN  1.34   3.9  1.29  3.58   NaN   NaN
# 4  2920.0  NaN  NaN  NaN  NaN  NaN  NaN  1.11   9.4  1.09  7.50   NaN   NaN
#
#    MaxWin  MaxLoss  AvgWin  AvgLoss     PlayerA       PlayerB  RankA  RankB  \
# 0    1.07    10.89   1.065    9.945  Alcaraz C.     Norrie C.    2.0   61.0
# 1    1.29     4.06   1.290    3.905    Fritz T.  Khachanov K.    5.0   20.0
# 2    1.11     8.33   1.105    7.665  Cobolli F.   Djokovic N.   24.0    6.0
# 3    1.32     3.60   1.285    3.600  Shelton B.     Sinner J.   10.0    1.0
# 4    1.10     8.57   1.090    7.785  Alcaraz C.     Rublev A.    2.0   14.0
#
#    RankDiff  WinnerBinary  MaxOddsPlayerA  MaxOddsPlayerB  AvgOddsPlayerA  \
# 0     -59.0             1            1.07           13.50            1.05
# 1     -15.0             1            1.31            4.20            1.27
# 2      18.0             0            8.60            1.12            7.53
# 3       9.0             0            3.90            1.34            3.58
# 4     -12.0             1            1.11            9.40            1.09
#
#    AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  H2H_Diff  WinsA  LossesA  WinsB  \
# 0            9.96           4           2         2    238       59    216
# 1            3.76           0           1        -1    288      189    287
# 2            1.09           0           1        -1     59       49   1093
# 3            1.29           1           5        -4     93       65    272
# 4            7.50           2           1         1    237       59    337
#
#    LossesB  WinRateA_cum  WinRateB_cum  Form10A  Form10B  RestDaysA  \
# 0      156      0.801347      0.580645      1.0      0.7          2
# 1      205      0.603774      0.583333      0.9      0.8          2
# 2      215      0.546296      0.835627      0.7      0.9          2
# 3       86      0.588608      0.759777      0.6      0.8          2
# 4      188      0.800676      0.641905      1.0      0.7          2
#
#    RestDaysB    DiffWR  DiffForm  DiffRest  LogRankDiff  H2HDiff  ProbA_odds  \
# 0          2  0.220702       0.3         0    -3.417727        2    0.934579
# 1          2  0.020440       0.1         0    -1.386294       -1    0.763359
# 2          2 -0.289331      -0.2         0     1.386294       -1    0.116279
# 3          2 -0.171169      -0.2         0     2.302585       -4    0.256410
# 4          2  0.158771       0.3         0    -1.945910        1    0.900901
#
#    ProbB_odds  OddsProbDiff  WinRateA_x_Rank  WinRateB_x_Rank  EfficiencyDiff  \
# 0    0.074074      0.860505         0.400673         0.009519        0.391155
# 1    0.238095      0.525264         0.120755         0.029167        0.091588
# 2    0.892857     -0.776578         0.022762         0.139271       -0.116509
# 3    0.746269     -0.489858         0.058861         0.759777       -0.700916
# 4    0.106383      0.794518         0.400338         0.045850        0.354487
#
#    EloA_Global  EloB_Global  EloA_Surface  EloB_Surface  EloDiff_Global  \
# 0  1816.908221  1621.932975   1776.637363   1586.541410      194.975246
# 1  1721.794354  1626.906557   1681.428764   1592.503282       94.887798
# 2  1585.915415  1939.233116   1569.343906   1860.199075     -353.317701
# 3  1551.763916  1688.748267   1529.518201   1653.339587     -136.984350
# 4  1811.958925  1649.303628   1772.431327   1614.953967      162.655297
#
#    EloDiff_Surface SurfaceText  RoundOrder
# 0       190.095953       Grass           6
# 1        88.925482       Grass           6
# 2      -290.855169       Grass           6
# 3      -123.821386       Grass           6
# 4       157.477361       Grass           4

# %%
scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = XGBClassifier(
    n_estimators=500,                    # Nombre total d'arbres (boosting rounds) que es construiran. 500 és un valor força alt, bo per a un bon rendiment si es controla l'overfitting.
    max_depth=6,                         # Profunditat màxima de cada arbre. 6 és un valor moderat: permet interaccions complexes sense fer els arbres excessivament profunds.
    learning_rate=0.02,                  # Taxa d'aprenentatge (eta). 0.02 és bastant baixa → aprenentatge lent i estable, ideal quan tens molts estimators (500).
    subsample=0.85,                      # Percentatge de mostres (files) que s'utilitzen per entrenar cada arbre. 0.85 = 85% → ajuda a reduir overfitting i afegeix variància (com bagging).
    colsample_bytree=0.85,               # Percentatge de columnes (variables) que s'agafen aleatòriament per cada arbre. 85% → també redueix overfitting i millora la generalització.
    min_child_weight=5,                  # Suma mínima del pes Hessiana en un node fill. Valors >1 fan el model més conservador: evita dividir nodes amb poca informació.
    gamma=0.1,                           # Minimització mínima de la funció de pèrdua necessària per fer una partició addicional (regularització per poda). 0.1 afavoreix arbres més simples.
    reg_alpha=0.1,                       # Terme de regularització L1 sobre els pesos de les fulles. Ajuda a fer sparseness i és útil quan hi ha moltes variables irrellevants.
    reg_lambda=1.0,                      # Terme de regularització L2 (més suau que L1). 1.0 és el valor per defecte i sol funcionar bé en la majoria de casos.
    random_state=42,                     # Llavor per a la reproductibilitat dels resultats (aleatorietat controlada).
    n_jobs=-1,                           # Utilitza tots els nuclis disponibles del processador per entrenar en paral·lel → molt més ràpid.
    eval_metric='logloss'                # Mètrica d'avaluació durant l'entrenament (per classificació binària/multiclasse). 'logloss' = logarithmic loss (cross-entropy).
)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 1.0000
# Brier Score: 0.0384
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000         2
#            1     1.0000    1.0000    1.0000         2
#
#     accuracy                         1.0000         4
#    macro avg     1.0000    1.0000    1.0000         4
# weighted avg     1.0000    1.0000    1.0000         4
#
# ================================================================================

# %% [markdown]
# ---
#
# ## Final

# %%
# Actualizar el conjunto de entrenamiento: añadir first_round al train actual
train_final = pd.concat([semi_finals, train_semi_finals], ignore_index=True)

print(f"Tamaño del train original: {len(train_final) - len(train_semi_finals)}")
print(f"Tamaño de first_round añadido: {len(train_semi_finals)}")
print(f"Tamaño del nuevo train: {len(train_final)}")
print(f"\nTrain actualizado correctamente. Listo para la siguiente fase.")

train_final.head()
# Out:
# Tamaño del train original: 2
# Tamaño de first_round añadido: 7731
# Tamaño del nuevo train: 7733
#
# Train actualizado correctamente. Listo para la siguiente fase.
#    ATP Location Tournament        Date  Series  Court  Surface          Round  \
# 0   36   London  Wimbledon  2025-07-11       2      1        2     Semifinals
# 1   36   London  Wimbledon  2025-07-11       2      1        2     Semifinals
# 2   36   London  Wimbledon  2025-07-08       2      1        2  Quarterfinals
# 3   36   London  Wimbledon  2025-07-08       2      1        2  Quarterfinals
# 4   36   London  Wimbledon  2025-07-09       2      1        2  Quarterfinals
#
#    Best of       Winner         Loser  WRank LRank   W1   L1   W2   L2   W3  \
# 0      5.0   Alcaraz C.      Fritz T.    2.0   5.0  6.0  4.0  5.0  7.0  6.0
# 1      5.0    Sinner J.   Djokovic N.    1.0   6.0  6.0  3.0  6.0  3.0  6.0
# 2      5.0   Alcaraz C.     Norrie C.    2.0  61.0  6.0  2.0  6.0  3.0  6.0
# 3      5.0     Fritz T.  Khachanov K.    5.0  20.0  6.0  3.0  6.0  4.0  1.0
# 4      5.0  Djokovic N.    Cobolli F.    6.0  24.0  6.0  7.0  6.0  2.0  7.0
#
#     L3   W4   L4  W5  L5  Wsets  Lsets    Comment  CBW  CBL  GBW  GBL  IWW  \
# 0  3.0  7.0  6.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN  NaN  NaN
# 1  4.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN  NaN  NaN
# 2  3.0  NaN  NaN NaN NaN    3.0    0.0  Completed  NaN  NaN  NaN  NaN  NaN
# 3  6.0  7.0  6.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN  NaN  NaN
# 4  5.0  6.0  4.0 NaN NaN    3.0    1.0  Completed  NaN  NaN  NaN  NaN  NaN
#
#    IWL  SBW  SBL  B365W  B365L  B&WW  B&WL  EXW  EXL   PSW    PSL     WPts  \
# 0  NaN  NaN  NaN   1.17   4.75   NaN   NaN  NaN  NaN  1.20   5.13   9300.0
# 1  NaN  NaN  NaN   1.40   2.80   NaN   NaN  NaN  NaN  1.47   2.93  10430.0
# 2  NaN  NaN  NaN   1.06   9.00   NaN   NaN  NaN  NaN  1.07  10.89   9300.0
# 3  NaN  NaN  NaN   1.29   3.75   NaN   NaN  NaN  NaN  1.29   4.06   4635.0
# 4  NaN  NaN  NaN   1.10   7.00   NaN   NaN  NaN  NaN  1.11   8.33   4630.0
#
#      LPts  UBW  UBL  LBW  LBL  SJW  SJL  MaxW   MaxL  AvgW  AvgL  BFEW  BFEL  \
# 0  4635.0  NaN  NaN  NaN  NaN  NaN  NaN  1.24   5.25  1.17  4.98   NaN   NaN
# 1  4630.0  NaN  NaN  NaN  NaN  NaN  NaN  1.47   3.05  1.42  2.85   NaN   NaN
# 2   952.0  NaN  NaN  NaN  NaN  NaN  NaN  1.07  13.50  1.05  9.96   NaN   NaN
# 3  2240.0  NaN  NaN  NaN  NaN  NaN  NaN  1.31   4.20  1.27  3.76   NaN   NaN
# 4  2035.0  NaN  NaN  NaN  NaN  NaN  NaN  1.12   8.60  1.09  7.53   NaN   NaN
#
#    MaxWin  MaxLoss  AvgWin  AvgLoss      PlayerA       PlayerB  RankA  RankB  \
# 0    1.20     5.13   1.185    4.940   Alcaraz C.      Fritz T.    2.0    5.0
# 1    1.47     2.93   1.435    2.865  Djokovic N.     Sinner J.    6.0    1.0
# 2    1.07    10.89   1.065    9.945   Alcaraz C.     Norrie C.    2.0   61.0
# 3    1.29     4.06   1.290    3.905     Fritz T.  Khachanov K.    5.0   20.0
# 4    1.11     8.33   1.105    7.665   Cobolli F.   Djokovic N.   24.0    6.0
#
#    RankDiff  WinnerBinary  MaxOddsPlayerA  MaxOddsPlayerB  AvgOddsPlayerA  \
# 0      -3.0             1            1.24            5.25            1.17
# 1       5.0             0            3.05            1.47            2.85
# 2     -59.0             1            1.07           13.50            1.05
# 3     -15.0             1            1.31            4.20            1.27
# 4      18.0             0            8.60            1.12            7.53
#
#    AvgOddsPlayerB  H2H_A_wins  H2H_B_wins  H2H_Diff  WinsA  LossesA  WinsB  \
# 0            4.98           1           0         1    239       59    289
# 1            1.42           4           4         0   1094      215    273
# 2            9.96           4           2         2    238       59    216
# 3            3.76           0           1        -1    288      189    287
# 4            1.09           0           1        -1     59       49   1093
#
#    LossesB  WinRateA_cum  WinRateB_cum  Form10A  Form10B  RestDaysA  \
# 0      189      0.802013      0.604603      1.0      0.9          3
# 1       86      0.835752      0.760446      0.9      0.8          2
# 2      156      0.801347      0.580645      1.0      0.7          2
# 3      205      0.603774      0.583333      0.9      0.8          2
# 4      215      0.546296      0.835627      0.7      0.9          2
#
#    RestDaysB    DiffWR  DiffForm  DiffRest  LogRankDiff  H2HDiff  ProbA_odds  \
# 0          3  0.197411       0.1         0    -0.916291        1    0.806452
# 1          2  0.075307       0.1         0     1.791759        0    0.327869
# 2          2  0.220702       0.3         0    -3.417727        2    0.934579
# 3          2  0.020440       0.1         0    -1.386294       -1    0.763359
# 4          2 -0.289331      -0.2         0     1.386294       -1    0.116279
#
#    ProbB_odds  OddsProbDiff  WinRateA_x_Rank  WinRateB_x_Rank  EfficiencyDiff  \
# 0    0.190476      0.615975         0.401007         0.120921        0.280086
# 1    0.680272     -0.352403         0.139292         0.760446       -0.621154
# 2    0.074074      0.860505         0.400673         0.009519        0.391155
# 3    0.238095      0.525264         0.120755         0.029167        0.091588
# 4    0.892857     -0.776578         0.022762         0.139271       -0.116509
#
#    EloA_Global  EloB_Global  EloA_Surface  EloB_Surface  EloDiff_Global  \
# 0  1821.105118  1732.370096   1780.072422   1691.427815       88.735023
# 1  1940.668719  1697.648428   1861.618917   1661.940358      243.020291
# 2  1816.908221  1621.932975   1776.637363   1586.541410      194.975246
# 3  1721.794354  1626.906557   1681.428764   1592.503282       94.887798
# 4  1585.915415  1939.233116   1569.343906   1860.199075     -353.317701
#
#    EloDiff_Surface SurfaceText  RoundOrder
# 0        88.644606       Grass           7
# 1       199.678559       Grass           7
# 2       190.095953       Grass           6
# 3        88.925482       Grass           6
# 4      -290.855169       Grass           6

# %%
X_train = train_final[features].fillna(0)
X_test = finals[features].fillna(0)
y_train = train_final['WinnerBinary']
y_test = finals['WinnerBinary']

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

base_model = XGBClassifier(
    n_estimators=500,                    # Nombre total d'arbres (boosting rounds) que es construiran. 500 és un valor força alt, bo per a un bon rendiment si es controla l'overfitting.
    max_depth=6,                         # Profunditat màxima de cada arbre. 6 és un valor moderat: permet interaccions complexes sense fer els arbres excessivament profunds.
    learning_rate=0.02,                  # Taxa d'aprenentatge (eta). 0.02 és bastant baixa → aprenentatge lent i estable, ideal quan tens molts estimators (500).
    subsample=0.85,                      # Percentatge de mostres (files) que s'utilitzen per entrenar cada arbre. 0.85 = 85% → ajuda a reduir overfitting i afegeix variància (com bagging).
    colsample_bytree=0.85,               # Percentatge de columnes (variables) que s'agafen aleatòriament per cada arbre. 85% → també redueix overfitting i millora la generalització.
    min_child_weight=5,                  # Suma mínima del pes Hessiana en un node fill. Valors >1 fan el model més conservador: evita dividir nodes amb poca informació.
    gamma=0.1,                           # Minimització mínima de la funció de pèrdua necessària per fer una partició addicional (regularització per poda). 0.1 afavoreix arbres més simples.
    reg_alpha=0.1,                       # Terme de regularització L1 sobre els pesos de les fulles. Ajuda a fer sparseness i és útil quan hi ha moltes variables irrellevants.
    reg_lambda=1.0,                      # Terme de regularització L2 (més suau que L1). 1.0 és el valor per defecte i sol funcionar bé en la majoria de casos.
    random_state=42,                     # Llavor per a la reproductibilitat dels resultats (aleatorietat controlada).
    n_jobs=-1,                           # Utilitza tots els nuclis disponibles del processador per entrenar en paral·lel → molt més ràpid.
    eval_metric='logloss'                # Mètrica d'avaluació durant l'entrenament (per classificació binària/multiclasse). 'logloss' = logarithmic loss (cross-entropy).
)

model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
model.fit(X_train_sc, y_train)

pred = model.predict(X_test_sc)
prob = model.predict_proba(X_test_sc)[:, 1]
acc = accuracy_score(y_test, pred)
brier = brier_score_loss(y_test, prob)

print("\n" + "="*80)
print(f"ACCURACY FINAL TEST CRONOLÓGIC: {acc:.4f}")
print(f"Brier Score: {brier:.4f}")
print(classification_report(y_test, pred, digits=4))
print("="*80)
# Out:
# ================================================================================
# ACCURACY FINAL TEST CRONOLÓGIC: 0.0000
# Brier Score: 0.3227
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000       1.0
#            1     0.0000    0.0000    0.0000       0.0
#
#     accuracy                         0.0000       1.0
#    macro avg     0.0000    0.0000    0.0000       1.0
# weighted avg     0.0000    0.0000    0.0000       1.0
#
# ================================================================================
# c:\Users\ikerr\Code\TFG\Program\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ikerr\Code\TFG\Program\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ikerr\Code\TFG\Program\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ikerr\Code\TFG\Program\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ikerr\Code\TFG\Program\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ikerr\Code\TFG\Program\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
